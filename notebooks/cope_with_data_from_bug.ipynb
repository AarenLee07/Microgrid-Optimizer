# %%
import pandas as pd
import os

# %%
folder_list=[
    r"L:\Coding_project\Energy_grid_new\output\experiments\thesis_topic1",
    r"L:\Coding_project\Energy_grid_new\output\experiments\thesis_topic2",
    r"L:\Coding_project\Energy_grid_new\output\experiments\thesis_topic3",
]
fn_list=[]
for folder in folder_list:
    list=os.listdir(folder)
    for i in list:
        fn_list.append(folder+'\\'+i)

# %%
fn_list.pop()
# Out:
# 'L:\\Coding_project\\Energy_grid_new\\output\\experiments\\thesis_topic3\\~$6h-bat-12months-0.6dc-minimize-cap.xlsx'

# %%
fn_list
# Out:
# ['L:\\Coding_project\\Energy_grid_new\\output\\experiments\\thesis_topic1\\6h-bat-12months-0.6dc.xlsx',
#  'L:\\Coding_project\\Energy_grid_new\\output\\experiments\\thesis_topic1\\6h-bat-12months-0dc.xlsx',
#  'L:\\Coding_project\\Energy_grid_new\\output\\experiments\\thesis_topic1\\6h-bat-52weeks-0.6dc.xlsx',
#  'L:\\Coding_project\\Energy_grid_new\\output\\experiments\\thesis_topic1\\6h-bat-52weeks-0dc.xlsx',
#  'L:\\Coding_project\\Energy_grid_new\\output\\experiments\\thesis_topic2\\6h-bat-6months-disturbance-type-visual.xlsx',
#  'L:\\Coding_project\\Energy_grid_new\\output\\experiments\\thesis_topic2\\6h-bat-6months-disturbance-type.xlsx',
#  'L:\\Coding_project\\Energy_grid_new\\output\\experiments\\thesis_topic2\\6h-bat-6weeks-disturbance-type-debug.xlsx',
#  'L:\\Coding_project\\Energy_grid_new\\output\\experiments\\thesis_topic2\\6h-bat-6weeks-disturbance-type.xlsx',
# ...

# %%
def recal_bat_e_tou(fn):
    df=pd.read_excel(fn, sheet_name="Sheet1")
    print(df.info())
    #assert isinstance(df["bat_e_terminal_revenue"].dtypes,float)
    #assert isinstance(df["OPEX"].dtypes,float)
    #assert isinstance(df["days"].dtypes,float)
    
    df["OPEX"]=df["OPEX"]+df["bat_e_terminal_revenue"]-df["bat_e_terminal_revenue"]/df["days"]
    pd.DataFrame(df).to_excel(fn)

# %%
fn_list=[
     'L:\\Coding_project\\Energy_grid_new\\output\\experiments\\thesis_topic3\\6h-bat-12months-0.6dc-minimize-cap.xlsx',
 'L:\\Coding_project\\Energy_grid_new\\output\\experiments\\thesis_topic3\\6h-bat-12months-0.6dc-shift-0.05.xlsx',
 'L:\\Coding_project\\Energy_grid_new\\output\\experiments\\thesis_topic3\\6h-bat-12months-0.6dc-shift-0.1.xlsx',
 'L:\\Coding_project\\Energy_grid_new\\output\\experiments\\thesis_topic3\\6h-bat-12months-0.6dc-shift-0.15.xlsx',
 'L:\\Coding_project\\Energy_grid_new\\output\\experiments\\thesis_topic3\\6h-bat-12months-0.6dc-shift-0.2.xlsx',
 'L:\\Coding_project\\Energy_grid_new\\output\\experiments\\thesis_topic3\\6h-bat-12months-0.6dc-shift-0.25.xlsx',
 'L:\\Coding_project\\Energy_grid_new\\output\\experiments\\thesis_topic3\\6h-bat-12months-0.6dc-shift-0.3.xlsx',
 'L:\\Coding_project\\Energy_grid_new\\output\\experiments\\thesis_topic3\\6h-bat-12months-0.6dc-shift-0.35.xlsx',
 'L:\\Coding_project\\Energy_grid_new\\output\\experiments\\thesis_topic3\\6h-bat-12months-0.6dc-shift-0.4.xlsx',
 'L:\\Coding_project\\Energy_grid_new\\output\\experiments\\thesis_topic3\\6h-bat-12months-0.6dc-shift.xlsx',
 'L:\\Coding_project\\Energy_grid_new\\output\\experiments\\thesis_topic3\\6h-bat-6months-disturbance-type.xlsx',
 'L:\\Coding_project\\Energy_grid_new\\output\\experiments\\thesis_topic3\\6h-bat-6weeks-disturbance-type-debug2.xlsx',
 'L:\\Coding_project\\Energy_grid_new\\output\\experiments\\thesis_topic3\\6h-bat-6weeks-disturbance-type.xlsx',
 'L:\\Coding_project\\Energy_grid_new\\output\\experiments\\thesis_topic3\\6h-bat-6weeks-disturbance-type2-del-dup.xlsx']

# %%
for fn in fn_list:
    recal_bat_e_tou(fn=fn)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 56 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      72 non-null     int64
#  1   status                  72 non-null     object
#  2   bld                     72 non-null     object
#  3   pv                      72 non-null     object
#  4   ev                      72 non-null     object
#  5   method                  72 non-null     object
#  6   strategy                72 non-null     object
#  7   B_kWh                   72 non-null     int64
#  8   pred_model              72 non-null     object
#  9   deg_model_opt           72 non-null     object
#  10  deg_model               72 non-null     object
#  11  start                   72 non-null     object
#  12  end                     72 non-null     object
#  13  month_of_year           72 non-null     int64
# ...
