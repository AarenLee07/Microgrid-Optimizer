# %%
import os
import sys
src_path = sys.path[0].replace("figures", "src")
# data_path = sys.path[0].replace("notebooks", "data")
if src_path not in sys.path:
    sys.path.append(src_path)

out_path = sys.path[0].replace("figures", "output")

import warnings
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from datetime import datetime, timedelta

from profile_extraction import ProfileExtraction
from data_loader import UCSD_dataloader
from utils.plot_utils import *
customize_plt() # customize plt configs, see plot_utils

exp_suffix = "May2023_2"
exp_folder = os.path.join(out_path, "experiments", exp_suffix)
if not os.path.exists(exp_folder):
    os.makedirs(exp_folder)
assert os.path.exists(exp_folder)

# %%
log_fn = "LOG-MPC_MSC_varied_building.xlsx"
log_df = pd.read_excel(os.path.join(exp_folder, log_fn), index_col=0)
exp_name = "MPC-demo"
log_df.head(100)
# turn id from float into str
#log_df['id']=log_df['id'].astype('int').astype('str')
# Out:
#      status              bld       pv      ev method strategy  B_kWh
# id
# 1.0       D          Hopkins  Hopkins   OSLER    MPC  optimal  350.0  \
# 2.0       D          Hopkins  Hopkins   OSLER    MPC  optimal  350.0
# 3.0       R          Hopkins  Hopkins   OSLER    MPC  optimal  350.0
# 4.0       D          Hopkins  Hopkins   OSLER    MPC  optimal  350.0
# 5.0       D          Hopkins  Hopkins   OSLER    MPC  optimal  350.0
# ...     ...              ...      ...     ...    ...      ...    ...
# 79.0      D    MusicBuilding   Gilman  GILMAN    MPC  optimal  350.0
# 80.0      D  StudentServices   Gilman  GILMAN    MPC  optimal  350.0
# 81.0      D  StudentServices   Gilman  GILMAN    MPC  optimal  350.0
# 82.0      D  StudentServices   Gilman  GILMAN    MPC  optimal  350.0
# 83.0      R  StudentServices   Gilman  GILMAN    MPC  optimal  350.0
#
#      pred_model deg_model_opt deg_model  ...        ev_I     load_bld
# id                                       ...
# 1.0      Simple      rainflow       DOD  ...   53.714286  1382.301607  \
# 2.0          GT      rainflow       DOD  ...   53.714286  1382.301607
# 3.0      Simple   unconscious       DOD  ...         NaN          NaN
# 4.0      Simple   unconscious       DOD  ...   53.714286  1382.301607
# 5.0      Simple      rainflow       DOD  ...   53.714286  1382.301607
# ...         ...           ...       ...  ...         ...          ...
# 79.0         GT   unconscious       DOD  ...   76.714286  2311.337000
# 80.0     Simple      rainflow       DOD  ...  108.571429  3058.528536
# 81.0     Simple   unconscious       DOD  ...  108.571429  3058.528536
# 82.0         GT      rainflow       DOD  ...  108.571429  3058.528536
# 83.0         GT   unconscious       DOD  ...         NaN          NaN
#
#          load_ev     load_tot      load_pv  grid_import  grid_export
# id
# 1.0   428.661516  1810.963123   826.204336  1030.567408    47.657550  \
# 2.0   428.661516  1810.963123   826.204336  1023.652004    40.028021
# 3.0          NaN          NaN          NaN          NaN          NaN
# 4.0   428.661516  1810.963123   826.204336  1041.155392    60.480907
# 5.0   428.661516  1810.963123   826.204336  1126.397520   149.682729
# ...          ...          ...          ...          ...          ...
# 79.0  653.330952  2964.667952  1461.504289  1533.246850    31.416667
# 80.0  923.295921  3981.824457  2074.439663  2095.126928   194.330406
# 81.0  924.411046  3982.939582  2074.439663  2108.165661   197.473942
# 82.0  919.330829  3977.859365  2074.439663  2058.413097   160.832784
# 83.0         NaN          NaN          NaN          NaN          NaN
#
#       import_cost  export_revenue    grid_max
# id
# 1.0    145.954215        4.474433  159.662364
# 2.0    141.244428        3.741058  164.246932
# 3.0           NaN             NaN         NaN
# 4.0    140.609145        6.936024  216.465522
# 5.0    160.124953       28.460842  190.060978
# ...           ...             ...         ...
# 79.0   232.904037        2.717500  240.996811
# 80.0   335.676289       14.890696  298.010374
# 81.0   327.873420       15.228993  380.931433
# 82.0   327.713855       12.058197  327.231265
# 83.0          NaN             NaN         NaN
#
# [86 rows x 45 columns]

# %%
log_df.query()
