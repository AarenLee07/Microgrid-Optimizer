# %%
import os
import sys
import exp
from threading import Thread
src_path = sys.path[0].replace("exp_notebook", "src")
#replace notebook as scripts
data_path = sys.path[0].replace("exp_notebook", "data")
if src_path not in sys.path:
    sys.path.append(src_path)
out_path = sys.path[0].replace("exp_notebook", "output")
log_folder=r'L:\Coding_project\Energy_grid_new_exp_local'
#log_folder=r'D:\Codes\Energy_grid_new_exp_local'

# %%
exp_suffix = "thesis_topic1"
exp_folder = os.path.join(out_path, "experiments", exp_suffix)
debug_folder = os.path.join(out_path, "debug_test")
assert os.path.exists(exp_folder)
log_fn = os.path.join(exp_folder, "6h-bat-52weeks-0dc.xlsx")#_oneday_12months

save_path = os.path.join(log_folder,exp_suffix, "6h-bat-52weeks-0dc")
if not os.path.exists(save_path):
    os.makedirs(save_path)
assert os.path.exists(save_path)

# %%
save_path
# Out:
# 'L:\\Coding_project\\Energy_grid_new_exp_local\\thesis_topic1\\6h-bat-52weeks-0dc'

# %%
def parallel():
    class MPC_parallel(exp.MPC_ExperimentManager):
        None
    for i in range(15):
        try:
            em = MPC_parallel(log_fn=log_fn, save_path=save_path, save=True, exp_prefix="MPC")
            var_keys = [
                        "method", "strategy",
                        "pred_model", "deg_model_opt", "p_grid_max", 
                        "price_dc", "price_sell", 
                        "ev_charge_rule", 
                        "B_kWh",  "deg_model", 
                        "start", "end", 
                        "bld", "ev", "pv",
                        "disturbance_rule", "disturbance_scale"]
            em.run(keys=var_keys, num_trials=6)
        except Exception as e:
            print('Reason_out:', e)  
            print('Failed in '+str(i)+'nd trial')
            continue

# %%
t1=Thread(target=parallel)
t2=Thread(target=parallel)
t3=Thread(target=parallel)

t1.start()
t2.start()
t3.start()

t1.join()
t2.join()
t3.join()
# Out:
# l:\Coding_project\Energy_grid_new\src\data_loader.py:101: UserWarning: No ev data loaded, EIO if pred_model is Prediction
#   warnings.warn("No ev data loaded, EIO if pred_model is Prediction")
# None
# !!!!!!!!!! EV SHORT DURATION !!!!!!!!!! || drop 0 sessions
# ========================= 2019-06-17 00:00:00 =========================
# summary saved at: 2019-06-17 00:00:00
# ========================= 2019-06-17 00:00:00 =========================
# ========================= 2019-06-17 01:00:00 =========================
# ========================= 2019-06-17 02:00:00 =========================
# ========================= 2019-06-17 03:00:00 =========================
# ========================= 2019-06-17 04:00:00 =========================
# ========================= 2019-06-17 05:00:00 =========================
# ========================= 2019-06-17 06:00:00 =========================
# ========================= 2019-06-17 07:00:00 =========================
# ========================= 2019-06-17 08:00:00 =========================
# ========================= 2019-06-17 09:00:00 =========================
# ========================= 2019-06-17 10:00:00 =========================
# ========================= 2019-06-17 11:00:00 =========================
# ========================= 2019-06-17 12:00:00 =========================
# ========================= 2019-06-17 13:00:00 =========================
# ========================= 2019-06-17 14:00:00 =========================
# ========================= 2019-06-17 15:00:00 =========================
# ========================= 2019-06-17 16:00:00 =========================
# ========================= 2019-06-17 17:00:00 =========================
# ========================= 2019-06-17 18:00:00 =========================
# ========================= 2019-06-17 19:00:00 =========================
# ========================= 2019-06-17 20:00:00 =========================
# ========================= 2019-06-17 21:00:00 =========================
# ========================= 2019-06-17 22:00:00 =========================
# ========================= 2019-06-17 23:00:00 =========================
# ========================= 2019-06-18 00:00:00 =========================
# ========================= 2019-06-18 01:00:00 =========================
# ========================= 2019-06-18 02:00:00 =========================
# ========================= 2019-06-18 03:00:00 =========================
# ========================= 2019-06-18 04:00:00 =========================
# ========================= 2019-06-18 05:00:00 =========================
# ========================= 2019-06-18 06:00:00 =========================
# ========================= 2019-06-18 07:00:00 =========================
# ========================= 2019-06-18 08:00:00 =========================
# ========================= 2019-06-18 09:00:00 =========================
# ========================= 2019-06-18 10:00:00 =========================
# ========================= 2019-06-18 11:00:00 =========================
# ========================= 2019-06-18 12:00:00 =========================
# ========================= 2019-06-18 13:00:00 =========================
# ========================= 2019-06-18 14:00:00 =========================
# ========================= 2019-06-18 15:00:00 =========================
# ========================= 2019-06-18 16:00:00 =========================
# ========================= 2019-06-18 17:00:00 =========================
# ========================= 2019-06-18 18:00:00 =========================
# ========================= 2019-06-18 19:00:00 =========================
# ========================= 2019-06-18 20:00:00 =========================
# ========================= 2019-06-18 21:00:00 =========================
# ========================= 2019-06-18 22:00:00 =========================
# ========================= 2019-06-18 23:00:00 =========================
# ========================= 2019-06-19 00:00:00 =========================
# ========================= 2019-06-19 01:00:00 =========================
# ========================= 2019-06-19 02:00:00 =========================
# ========================= 2019-06-19 03:00:00 =========================
# ========================= 2019-06-19 04:00:00 =========================
# ========================= 2019-06-19 05:00:00 =========================
# ========================= 2019-06-19 06:00:00 =========================
# ========================= 2019-06-19 07:00:00 =========================
# ========================= 2019-06-19 08:00:00 =========================
# ========================= 2019-06-19 09:00:00 =========================
# ========================= 2019-06-19 10:00:00 =========================
# ========================= 2019-06-19 11:00:00 =========================
# ========================= 2019-06-19 12:00:00 =========================
# ========================= 2019-06-19 13:00:00 =========================
# ========================= 2019-06-19 14:00:00 =========================
# ========================= 2019-06-19 15:00:00 =========================
# ========================= 2019-06-19 16:00:00 =========================
# ========================= 2019-06-19 17:00:00 =========================
# ========================= 2019-06-19 18:00:00 =========================
# ========================= 2019-06-19 19:00:00 =========================
# ========================= 2019-06-19 20:00:00 =========================
# ========================= 2019-06-19 21:00:00 =========================
# ========================= 2019-06-19 22:00:00 =========================
# ========================= 2019-06-19 23:00:00 =========================
# ========================= 2019-06-20 00:00:00 =========================
# ========================= 2019-06-20 01:00:00 =========================
# ========================= 2019-06-20 02:00:00 =========================
# ========================= 2019-06-20 03:00:00 =========================
# ========================= 2019-06-20 04:00:00 =========================
# ========================= 2019-06-20 05:00:00 =========================
# ========================= 2019-06-20 06:00:00 =========================
# ========================= 2019-06-20 07:00:00 =========================
# ========================= 2019-06-20 08:00:00 =========================
# ========================= 2019-06-20 09:00:00 =========================
# ========================= 2019-06-20 10:00:00 =========================
# ========================= 2019-06-20 11:00:00 =========================
# ========================= 2019-06-20 12:00:00 =========================
# ========================= 2019-06-20 13:00:00 =========================
# ========================= 2019-06-20 14:00:00 =========================
# ========================= 2019-06-20 15:00:00 =========================
# ========================= 2019-06-20 16:00:00 =========================
# ========================= 2019-06-20 17:00:00 =========================
# ========================= 2019-06-20 18:00:00 =========================
# ========================= 2019-06-20 19:00:00 =========================
# ========================= 2019-06-20 20:00:00 =========================
# ========================= 2019-06-20 21:00:00 =========================
# ========================= 2019-06-20 22:00:00 =========================
# ========================= 2019-06-20 23:00:00 =========================
# ========================= 2019-06-21 00:00:00 =========================
# ========================= 2019-06-21 01:00:00 =========================
# ========================= 2019-06-21 02:00:00 =========================
# ========================= 2019-06-21 03:00:00 =========================
# ========================= 2019-06-21 04:00:00 =========================
# ========================= 2019-06-21 05:00:00 =========================
# ========================= 2019-06-21 06:00:00 =========================
# ========================= 2019-06-21 07:00:00 =========================
# ========================= 2019-06-21 08:00:00 =========================
# ========================= 2019-06-21 09:00:00 =========================
# ========================= 2019-06-21 10:00:00 =========================
# ========================= 2019-06-21 11:00:00 =========================
# ========================= 2019-06-21 12:00:00 =========================
# ========================= 2019-06-21 13:00:00 =========================
# ========================= 2019-06-21 14:00:00 =========================
# ========================= 2019-06-21 15:00:00 =========================
# ========================= 2019-06-21 16:00:00 =========================
# ========================= 2019-06-21 17:00:00 =========================
# ========================= 2019-06-21 18:00:00 =========================
# ========================= 2019-06-21 19:00:00 =========================
# ========================= 2019-06-21 20:00:00 =========================
# ========================= 2019-06-21 21:00:00 =========================
# ========================= 2019-06-21 22:00:00 =========================
# ========================= 2019-06-21 23:00:00 =========================
# ========================= 2019-06-22 00:00:00 =========================
# ========================= 2019-06-22 01:00:00 =========================
# ========================= 2019-06-22 02:00:00 =========================
# ========================= 2019-06-22 03:00:00 =========================
# ========================= 2019-06-22 04:00:00 =========================
# ========================= 2019-06-22 05:00:00 =========================
# ========================= 2019-06-22 06:00:00 =========================
# ========================= 2019-06-22 07:00:00 =========================
# ========================= 2019-06-22 08:00:00 =========================
# ========================= 2019-06-22 09:00:00 =========================
# ========================= 2019-06-22 10:00:00 =========================
# ========================= 2019-06-22 11:00:00 =========================
# ========================= 2019-06-22 12:00:00 =========================
# ========================= 2019-06-22 13:00:00 =========================
# ========================= 2019-06-22 14:00:00 =========================
# ========================= 2019-06-22 15:00:00 =========================
# ========================= 2019-06-22 16:00:00 =========================
# ========================= 2019-06-22 17:00:00 =========================
# ========================= 2019-06-22 18:00:00 =========================
# ========================= 2019-06-22 19:00:00 =========================
# ========================= 2019-06-22 20:00:00 =========================
# ========================= 2019-06-22 21:00:00 =========================
# ========================= 2019-06-22 22:00:00 =========================
# ========================= 2019-06-22 23:00:00 =========================
# ========================= 2019-06-23 00:00:00 =========================
# ========================= 2019-06-23 01:00:00 =========================
# ========================= 2019-06-23 02:00:00 =========================
# ========================= 2019-06-23 03:00:00 =========================
# ========================= 2019-06-23 04:00:00 =========================
# ========================= 2019-06-23 05:00:00 =========================
# ========================= 2019-06-23 06:00:00 =========================
# ========================= 2019-06-23 07:00:00 =========================
# ========================= 2019-06-23 08:00:00 =========================
# ========================= 2019-06-23 09:00:00 =========================
# ========================= 2019-06-23 10:00:00 =========================
# ========================= 2019-06-23 11:00:00 =========================
# ========================= 2019-06-23 12:00:00 =========================
# ========================= 2019-06-23 13:00:00 =========================
# ========================= 2019-06-23 14:00:00 =========================
# ========================= 2019-06-23 15:00:00 =========================
# ========================= 2019-06-23 16:00:00 =========================
# ========================= 2019-06-23 17:00:00 =========================
# ========================= 2019-06-23 18:00:00 =========================
# ========================= 2019-06-23 19:00:00 =========================
# ========================= 2019-06-23 20:00:00 =========================
# ========================= 2019-06-23 21:00:00 =========================
# ========================= 2019-06-23 22:00:00 =========================
# ========================= 2019-06-23 23:00:00 =========================
# ========================= FINISH =========================
# Done, trial 147
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
