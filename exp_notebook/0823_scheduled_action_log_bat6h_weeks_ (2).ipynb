# %%
import os
import sys
import exp
from threading import Thread
src_path = sys.path[0].replace("exp_notebook", "src")
#replace notebook as scripts
data_path = sys.path[0].replace("exp_notebook", "data")
if src_path not in sys.path:
    sys.path.append(src_path)
out_path = sys.path[0].replace("exp_notebook", "output")
log_folder=r'L:\Coding_project\Energy_grid_new_exp_local'

# %%
exp_suffix = "Aug2023_3"
exp_folder = os.path.join(out_path, "experiments", exp_suffix)
debug_folder = os.path.join(out_path, "debug_test")
assert os.path.exists(exp_folder)
log_fn = os.path.join(exp_folder, "LOG-MPC-MSC-6h-bat-3-4.xlsx")#_oneday_12months

save_path = os.path.join(log_folder,exp_suffix, "MPC-demo")
if not os.path.exists(save_path):
    os.makedirs(save_path)
assert os.path.exists(save_path)

# %%
save_path
# Out:
# 'L:\\Coding_project\\Energy_grid_new_exp_local\\Aug2023_3\\MPC-demo'

# %%
def parallel():
    class MPC_parallel(exp.MPC_ExperimentManager):
        None
    for i in range(15):
        try:
            em = MPC_parallel(log_fn=log_fn, save_path=save_path, save=True, exp_prefix="MPC")
            var_keys = [
                        "method", "strategy",
                        "pred_model", "deg_model_opt", "p_grid_max", 
                        "price_dc", "price_sell", 
                        "ev_charge_rule", 
                        "B_kWh",  "deg_model", 
                        "start", "end", 
                        "bld", "ev", "pv"]
            em.run(keys=var_keys, num_trials=6)
        except Exception as e:
            print('Reason_out:', e)  
            print('Failed in '+str(i)+'nd trial')
            continue

# %%
t1=Thread(target=parallel)
t2=Thread(target=parallel)
#t3=Thread(target=exp)

t1.start()
t2.start()
#t3.start()

t1.join()
t2.join()
#t3.join()
# Out:
# Access denied, suspending.
# l:\Coding_project\Energy_grid_new\src\data_loader.py:100: UserWarning: No ev data loaded, EIO if pred_model is Prediction
#   warnings.warn("No ev data loaded, EIO if pred_model is Prediction")
# !!!!!!!!!! EV SHORT DURATION !!!!!!!!!! || drop 0 sessions
# !!!!!!!!!! EV SHORT DURATION !!!!!!!!!! || drop 0 sessions
# l:\Coding_project\Energy_grid_new\src\data_loader.py:100: UserWarning: No ev data loaded, EIO if pred_model is Prediction
#   warnings.warn("No ev data loaded, EIO if pred_model is Prediction")
# l:\Coding_project\Energy_grid_new\src\data_loader.py:100: UserWarning: No ev data loaded, EIO if pred_model is Prediction
#   warnings.warn("No ev data loaded, EIO if pred_model is Prediction")
# l:\Coding_project\Energy_grid_new\src\data_loader.py:100: UserWarning: No ev data loaded, EIO if pred_model is Prediction
#   warnings.warn("No ev data loaded, EIO if pred_model is Prediction")
# !!!!!!!!!! EV SHORT DURATION !!!!!!!!!! || drop 0 sessions
# !!!!!!!!!! EV SHORT DURATION !!!!!!!!!! || drop 0 sessions
# Reason_out: Excel file format cannot be determined, you must specify an engine manually.
# Failed in 0nd trial
# ========================= 2019-01-01 00:00:00 =========================
# summary saved at: 2019-01-01 00:00:00
# ========================= 2019-01-01 00:00:00 =========================
# ========================= 2019-01-01 01:00:00 =========================
# ========================= 2019-01-01 02:00:00 =========================
# ========================= 2019-01-01 03:00:00 =========================
# ========================= 2019-01-01 04:00:00 =========================
# ========================= 2019-01-01 05:00:00 =========================
# l:\Coding_project\Energy_grid_new\src\data_loader.py:100: UserWarning: No ev data loaded, EIO if pred_model is Prediction
#   warnings.warn("No ev data loaded, EIO if pred_model is Prediction")
# ========================= 2019-01-01 06:00:00 =========================
# ========================= 2019-01-01 07:00:00 =========================
# !!!!!!!!!! EV SHORT DURATION !!!!!!!!!! || drop 0 sessions
# ========================= 2019-01-01 08:00:00 =========================
# ========================= 2019-01-01 09:00:00 =========================
# ========================= 2019-01-01 10:00:00 =========================
# ========================= 2019-01-01 11:00:00 =========================
# ========================= 2019-01-01 12:00:00 =========================
# ========================= 2019-01-01 13:00:00 =========================
# ========================= 2019-01-01 14:00:00 =========================
# ========================= 2019-01-01 15:00:00 =========================
# ========================= 2019-01-01 16:00:00 =========================
# ========================= 2019-01-01 17:00:00 =========================
# ========================= 2019-01-01 18:00:00 =========================
# ========================= 2019-01-01 19:00:00 =========================
# ========================= 2019-01-01 20:00:00 =========================
# ========================= 2019-01-01 21:00:00 =========================
# ========================= 2019-01-01 22:00:00 =========================
# ========================= 2019-01-01 23:00:00 =========================
# l:\Coding_project\Energy_grid_new\src\data_loader.py:100: UserWarning: No ev data loaded, EIO if pred_model is Prediction
#   warnings.warn("No ev data loaded, EIO if pred_model is Prediction")
# !!!!!!!!!! EV SHORT DURATION !!!!!!!!!! || drop 0 sessions
# l:\Coding_project\Energy_grid_new\src\data_loader.py:184: UserWarning: No EV data loaded, EIO if pred_model is Prediction.
#   warnings.warn("No EV data loaded, EIO if pred_model is Prediction.")
# ========================= 2019-01-02 00:00:00 =========================
# ========================= 2019-01-01 00:00:00 =========================
# ========================= 2019-01-02 01:00:00 =========================
# mismatch:  1.7004018000000016
# mismatch:  0.8478017999999992
# mismatch:  0.2302645000000041
# mismatch:  0.20848780000000033
# mismatch:  1.473569899999994
# mismatch:  2.476387299999999
# mismatch:  2.636552200000004
# mismatch:  3.4555977999999996
# ========================= 2019-01-02 02:00:00 =========================
# mismatch:  1.3712958999999998
# mismatch:  1.7758104999999986
# mismatch:  1.7744696999999974
# mismatch:  1.7941610000000026
# mismatch:  1.862242799999997
# mismatch:  3.0055560999999997
# mismatch:  3.054033599999997
# mismatch:  2.3331341000000023
# mismatch:  1.7669935999999993
# mismatch:  1.7940883999999997
# ========================= 2019-01-02 03:00:00 =========================
# mismatch:  2.4569170999999983
# mismatch:  2.1301230999999987
# mismatch:  3.3162591000000035
# mismatch:  2.2095885999999965
# mismatch:  2.4521412
# mismatch:  2.1413670000000025
# mismatch:  0.36042000000000485
# mismatch:  -0.13579260000000204
# p_grid in solution is higher than execution
# mismatch:  0.9378964999999937
# mismatch:  -0.2010365999999948
# p_grid in solution is higher than execution
# ========================= 2019-01-02 04:00:00 =========================
# mismatch:  0.3324472000000043
# mismatch:  -1.2107249999999965
# p_grid in solution is higher than execution
# mismatch:  -2.4083854000000002
# p_grid in solution is higher than execution
# mismatch:  -1.7050951000000012
# p_grid in solution is higher than execution
# mismatch:  -1.6609182999999987
# p_grid in solution is higher than execution
# mismatch:  -1.359788799999997
# p_grid in solution is higher than execution
# mismatch:  -1.1992635000000007
# mismatch:  -0.9185920000000038
# mismatch:  -1.2171485000000004
# mismatch:  -2.1171839000000006
# mismatch:  -2.7442279999999997
# ========================= 2019-01-02 05:00:00 =========================
# mismatch:  -2.4584209
# mismatch:  -2.5411280000000005
# mismatch:  -2.862914400000001
# mismatch:  -2.107974899999995
# mismatch:  -3.2211256000000006
# mismatch:  -3.666997500000001
# p_grid in solution is higher than execution
# mismatch:  -4.651806399999998
# p_grid in solution is higher than execution
# mismatch:  -3.915289999999999
# p_grid in solution is higher than execution
# mismatch:  -3.9204244000000017
# p_grid in solution is higher than execution
# mismatch:  -3.801231399999999
# p_grid in solution is higher than execution
# ========================= 2019-01-02 06:00:00 =========================
# mismatch:  -4.216174500000001
# p_grid in solution is higher than execution
# mismatch:  -4.207335799999996
# p_grid in solution is higher than execution
# mismatch:  -3.4417502000000013
# p_grid in solution is higher than execution
# mismatch:  -3.4520240000000015
# mismatch:  -2.878246400000002
# mismatch:  -2.763589499999995
# mismatch:  -3.5011050000000026
# mismatch:  -4.311162000000003
# mismatch:  -4.297537200000001
# mismatch:  -3.9706793999999945
# ========================= 2019-01-02 07:00:00 =========================
# mismatch:  -3.4317455000000052
# mismatch:  -4.151680800000001
# mismatch:  -4.030256900000005
# p_grid in solution is higher than execution
# mismatch:  -3.928260999999999
# p_grid in solution is higher than execution
# mismatch:  -4.224300599999999
# p_grid in solution is higher than execution
# mismatch:  -5.422659500000002
# mismatch:  -6.1586665999999965
# mismatch:  -4.416998200000002
# mismatch:  -5.100182100000005
# mismatch:  -5.137464199999997
# ========================= 2019-01-02 08:00:00 =========================
# mismatch:  -3.8714603000000025
# mismatch:  -2.5509072000000046
# mismatch:  -3.4746774000000045
# mismatch:  -3.9581726000000046
# mismatch:  -4.227134400000004
# mismatch:  -4.395557199999999
# mismatch:  -4.294499999999999
# mismatch:  -4.6538916000000015
# mismatch:  -4.137422200000003
# mismatch:  -4.093964800000002
# mismatch:  -4.281502600000003
# ========================= 2019-01-02 09:00:00 =========================
# mismatch:  -2.977273000000004
# mismatch:  -3.2291594999999944
# mismatch:  -3.5412038999999993
# mismatch:  -3.9173650000000038
# mismatch:  -3.2655385999999993
# mismatch:  -3.481345900000001
# mismatch:  -2.549342099999997
# mismatch:  -2.5901277999999976
# mismatch:  -2.307636500000001
# mismatch:  -1.7360533000000018
# mismatch:  -1.6622354000000001
# ========================= 2019-01-02 10:00:00 =========================
# mismatch:  -1.9676190000000062
# mismatch:  0.35116150000000346
# mismatch:  1.6573258999999965
# mismatch:  1.5370193999999984
# mismatch:  0.8581264000000033
# ========================= 2019-01-02 11:00:00 =========================
# ========================= 2019-01-02 12:00:00 =========================
# summary saved at: 2019-01-01 00:00:00
# ========================= 2019-01-01 00:00:00 =========================
# mismatch:  1.7004018000000016
# mismatch:  0.8478017999999992
# mismatch:  0.2302645000000041
# mismatch:  0.20848780000000033
# ========================= 2019-01-01 01:00:00 =========================
# ========================= 2019-01-02 13:00:00 =========================
# mismatch:  1.473569899999994
# mismatch:  2.476387299999999
# mismatch:  2.636552200000004
# mismatch:  3.4555977999999996
# ========================= 2019-01-01 02:00:00 =========================
# mismatch:  1.3712958999999998
# mismatch:  1.7758104999999986
# mismatch:  1.7744696999999974
# ========================= 2019-01-02 14:00:00 =========================
# mismatch:  1.7941610000000026
# ========================= 2019-01-01 03:00:00 =========================
# mismatch:  1.862242799999997
# mismatch:  3.0055560999999997
# mismatch:  3.054033599999997
# mismatch:  2.3331341000000023
# ========================= 2019-01-01 04:00:00 =========================
# mismatch:  1.7669935999999993
# mismatch:  1.7940883999999997
# mismatch:  2.4569170999999983
# mismatch:  2.1301230999999987
# ========================= 2019-01-01 05:00:00 =========================
# ========================= 2019-01-02 15:00:00 =========================
# mismatch:  3.3162591000000035
# mismatch:  2.2095885999999965
# mismatch:  2.4521412
# mismatch:  2.1413670000000025
# ========================= 2019-01-01 06:00:00 =========================
# mismatch:  0.36042000000000485
# mismatch:  -0.13579260000000204
# p_grid in solution is higher than execution
# mismatch:  0.9378964999999937
# mismatch:  -0.2010365999999948
# p_grid in solution is higher than execution
# ========================= 2019-01-01 07:00:00 =========================
# ========================= 2019-01-02 16:00:00 =========================
# mismatch:  0.3324472000000043
# mismatch:  -1.2107249999999965
# p_grid in solution is higher than execution
# mismatch:  -2.4083854000000002
# p_grid in solution is higher than execution
# mismatch:  -1.7050951000000012
# p_grid in solution is higher than execution
# ========================= 2019-01-01 08:00:00 =========================
# mismatch:  -1.6609182999999987
# p_grid in solution is higher than execution
# mismatch:  -1.359788799999997
# p_grid in solution is higher than execution
# mismatch:  -1.1992635000000007
# mismatch:  -0.9185920000000038
# ========================= 2019-01-01 09:00:00 =========================
# ========================= 2019-01-02 17:00:00 =========================
# mismatch:  -1.2171485000000004
# mismatch:  -2.1171839000000006
# mismatch:  -2.7442279999999997
# mismatch:  -2.4584209
# ========================= 2019-01-01 10:00:00 =========================
# mismatch:  -2.5411280000000005
# mismatch:  -2.862914400000001
# ========================= 2019-01-02 18:00:00 =========================
# mismatch:  -2.107974899999995
# mismatch:  -3.2211256000000006
# ========================= 2019-01-01 11:00:00 =========================
# mismatch:  -3.666997500000001
# p_grid in solution is higher than execution
# mismatch:  -4.651806399999998
# p_grid in solution is higher than execution
# mismatch:  -3.915289999999999
# p_grid in solution is higher than execution
# mismatch:  -3.9204244000000017
# p_grid in solution is higher than execution
# ========================= 2019-01-01 12:00:00 =========================
# ========================= 2019-01-02 19:00:00 =========================
# mismatch:  -3.801231399999999
# p_grid in solution is higher than execution
# mismatch:  -4.216174500000001
# p_grid in solution is higher than execution
# mismatch:  -4.207335799999996
# p_grid in solution is higher than execution
# mismatch:  -3.4417502000000013
# p_grid in solution is higher than execution
# ========================= 2019-01-01 13:00:00 =========================
# mismatch:  -3.4520240000000015
# ========================= 2019-01-02 20:00:00 =========================
# mismatch:  -2.878246400000002
# mismatch:  -2.763589499999995
# mismatch:  -3.5011050000000026
# ========================= 2019-01-01 14:00:00 =========================
# mismatch:  -4.311162000000003
# ========================= 2019-01-02 21:00:00 =========================
# mismatch:  -4.297537200000001
# mismatch:  -3.9706793999999945
# mismatch:  -3.4317455000000052
# ========================= 2019-01-01 15:00:00 =========================
# mismatch:  -4.151680800000001
# ========================= 2019-01-02 22:00:00 =========================
# mismatch:  -4.030256900000005
# p_grid in solution is higher than execution
# mismatch:  -3.928260999999999
# p_grid in solution is higher than execution
# mismatch:  -4.224300599999999
# p_grid in solution is higher than execution
# ========================= 2019-01-01 16:00:00 =========================
# ========================= 2019-01-02 23:00:00 =========================
# mismatch:  -5.422659500000002
# p_grid in solution is higher than execution
# mismatch:  -6.1586665999999965
# mismatch:  -4.416998200000002
# mismatch:  -5.100182100000005
# p_grid in solution is higher than execution
# ========================= 2019-01-01 17:00:00 =========================
# mismatch:  -5.137464199999997
# mismatch:  -3.8714603000000025
# mismatch:  -2.5509072000000046
# mismatch:  -3.4746774000000045
# ========================= 2019-01-01 18:00:00 =========================
# mismatch:  -3.9581726000000046
# mismatch:  -4.227134400000004
# mismatch:  -4.395557199999999
# mismatch:  -4.294499999999999
# ========================= 2019-01-01 19:00:00 =========================
# mismatch:  -4.6538916000000015
# mismatch:  -4.137422200000003
# mismatch:  -4.093964800000002
# mismatch:  -4.281502600000003
# ========================= 2019-01-01 20:00:00 =========================
# mismatch:  -2.977273000000004
# mismatch:  -3.2291594999999944
# mismatch:  -3.5412038999999993
# mismatch:  -3.9173650000000038
# ========================= 2019-01-01 21:00:00 =========================
# mismatch:  -3.2655385999999993
# mismatch:  -3.481345900000001
# mismatch:  -2.549342099999997
# mismatch:  -2.5901277999999976
# ========================= 2019-01-01 22:00:00 =========================
# mismatch:  -2.307636500000001
# p_grid in solution is higher than execution
# mismatch:  -1.7360533000000018
# p_grid in solution is higher than execution
# mismatch:  -1.6622354000000001
# ========================= 2019-01-03 00:00:00 =========================
# mismatch:  -1.9676190000000062
# ========================= 2019-01-01 23:00:00 =========================
# mismatch:  0.35116150000000346
# ========================= 2019-01-03 01:00:00 =========================
# mismatch:  1.6573258999999965
# mismatch:  1.5370193999999984
# mismatch:  0.8581264000000033
# ========================= 2019-01-03 02:00:00 =========================
# ========================= 2019-01-03 03:00:00 =========================
# ========================= 2019-01-03 04:00:00 =========================
# ========================= 2019-01-03 05:00:00 =========================
# ========================= 2019-01-02 00:00:00 =========================
# ========================= 2019-01-03 06:00:00 =========================
# mismatch:  -0.5974287000000018
# p_grid in solution is higher than execution
# mismatch:  1.1830918000000068
# mismatch:  2.5702704000000054
# mismatch:  3.4743226000000007
# ========================= 2019-01-02 01:00:00 =========================
# =========================mismatch:  3.1482448000000005
#  2019-01-03 07:00:00 =========================
# mismatch:  3.2157233000000005
# mismatch:  3.132607
# mismatch:  3.6143331999999972
# ========================= 2019-01-02 02:00:00 =========================
# mismatch:  3.711009400000002
# ========================= 2019-01-03 08:00:00 =========================
# mismatch:  3.451598699999998
# mismatch:  3.2386509999999973
# mismatch:  3.0526336
# ========================= 2019-01-02 03:00:00 =========================
# mismatch:  4.2100741
# ========================= 2019-01-03 09:00:00 =========================
# mismatch:  3.9458018999999993
# mismatch:  4.6119123
# mismatch:  4.1895484
# ========================= 2019-01-02 04:00:00 =========================
# mismatch:  4.689026400000003
# ========================= 2019-01-03 10:00:00 =========================
# mismatch:  5.0661289999999966
# mismatch:  5.9692109
# mismatch:  5.777569999999997
# ========================= 2019-01-02 05:00:00 =========================
# mismatch:  5.1250024
# mismatch:  6.567215400000002
# mismatch:  7.0231701000000015
# ========================= 2019-01-03 11:00:00 =========================
# mismatch:  7.9707130999999976
# ========================= 2019-01-02 06:00:00 =========================
# mismatch:  7.236131499999999
# mismatch:  13.568606799999998
# mismatch:  14.986562800000002
# p_grid in solution is higher than execution
# mismatch:  14.844571799999997
# ========================= 2019-01-02 07:00:00 =========================
# ========================= 2019-01-03 12:00:00 =========================
# mismatch:  14.209742399999996
# mismatch:  13.414326000000003
# mismatch:  14.274797100000008
# mismatch:  15.876872200000001
# ========================= 2019-01-02 08:00:00 =========================
# ========================= 2019-01-03 13:00:00 =========================
# mismatch:  16.3299666
# mismatch:  17.1433088
# mismatch:  19.793414000000006
# mismatch:  21.214786399999994
# ========================= 2019-01-02 09:00:00 =========================
# ========================= 2019-01-03 14:00:00 =========================
# mismatch:  20.567302999999995
# mismatch:  20.07358450000001
# mismatch:  20.302033299999998
# mismatch:  21.1097594
# ========================= 2019-01-02 10:00:00 =========================
# ========================= 2019-01-03 15:00:00 =========================
# mismatch:  21.521051300000003
# mismatch:  20.393583799999995
# mismatch:  22.230198200000004
# mismatch:  21.745928300000003
# ========================= 2019-01-02 11:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-01-03 16:00:00 =========================
# mismatch:  21.246781699999993
# mismatch:  21.9321337
# mismatch:  21.470121899999995
# mismatch:  23.9781021
# ========================= 2019-01-02 12:00:00 =========================
# ========================= 2019-01-03 17:00:00 =========================
# mismatch:  24.848718500000004
# mismatch:  22.752281900000007
# mismatch:  22.758913999999997
# mismatch:  21.642885900000003
# ========================= 2019-01-02 13:00:00 =========================
# ========================= 2019-01-03 18:00:00 =========================
# mismatch:  21.577847700000007
# mismatch:  20.402492700000003
# mismatch:  19.175850099999998
# mismatch:  18.7307073
# ========================= 2019-01-02 14:00:00 =========================
# ========================= 2019-01-03 19:00:00 =========================
# mismatch:  16.36661730000001
# mismatch:  16.655051200000003
# mismatch:  16.808773099999996
# mismatch:  16.063622800000005
# ========================= 2019-01-02 15:00:00 =========================
# ========================= 2019-01-03 20:00:00 =========================
# mismatch:  16.851928799999996
# mismatch:  14.457824899999999
# mismatch:  14.194575100000002
# mismatch:  14.8172936
# ========================= 2019-01-02 16:00:00 =========================
# ========================= 2019-01-03 21:00:00 =========================
# mismatch:  14.762930999999995
# mismatch:  13.168010999999993
# mismatch:  11.991404099999997
# mismatch:  11.8364275
# ========================= 2019-01-02 17:00:00 =========================
# ========================= 2019-01-03 22:00:00 =========================
