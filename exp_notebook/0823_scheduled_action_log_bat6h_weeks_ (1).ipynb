# %%
import os
import sys
import exp
from threading import Thread
src_path = sys.path[0].replace("exp_notebook", "src")
#replace notebook as scripts
data_path = sys.path[0].replace("exp_notebook", "data")
if src_path not in sys.path:
    sys.path.append(src_path)
out_path = sys.path[0].replace("exp_notebook", "output")
log_folder=r'L:\Coding_project\Energy_grid_new_exp_local'
#log_folder=r'D:\Codes\Energy_grid_new_exp_local'

# %%
exp_suffix = "Aug2023_3"
exp_folder = os.path.join(out_path, "experiments", exp_suffix)
debug_folder = os.path.join(out_path, "debug_test")
assert os.path.exists(exp_folder)
log_fn = os.path.join(exp_folder, "LOG-MPC-MSC-6h-bat-52weeks.xlsx")#_oneday_12months

save_path = os.path.join(log_folder,exp_suffix, "MPC-demo")
if not os.path.exists(save_path):
    os.makedirs(save_path)
assert os.path.exists(save_path)

# %%
save_path
# Out:
# 'D:\\Codes\\Energy_grid_new_exp_local\\Aug2023_3\\MPC-demo'

# %%
def parallel():
    class MPC_parallel(exp.MPC_ExperimentManager):
        None
    for i in range(15):
        try:
            em = MPC_parallel(log_fn=log_fn, save_path=save_path, save=True, exp_prefix="MPC")
            var_keys = [
                        "method", "strategy",
                        "pred_model", "deg_model_opt", "p_grid_max", 
                        "price_dc", "price_sell", 
                        "ev_charge_rule", 
                        "B_kWh",  "deg_model", 
                        "start", "end", 
                        "bld", "ev", "pv"]
            em.run(keys=var_keys, num_trials=6)
        except Exception as e:
            print('Reason_out:', e)  
            print('Failed in '+str(i)+'nd trial')
            continue

# %%
t1=Thread(target=parallel)
t2=Thread(target=parallel)
#t3=Thread(target=exp)

t1.start()
t2.start()
#t3.start()

t1.join()
t2.join()
#t3.join()
# Out:
# Access denied, suspending.
# d:\Codes\Energy_grid_new\src\data_loader.py:100: UserWarning: No ev data loaded, EIO if pred_model is Prediction
#   warnings.warn("No ev data loaded, EIO if pred_model is Prediction")
# d:\Codes\Energy_grid_new\src\data_loader.py:100: UserWarning: No ev data loaded, EIO if pred_model is Prediction
#   warnings.warn("No ev data loaded, EIO if pred_model is Prediction")
# !!!!!!!!!! EV SHORT DURATION !!!!!!!!!! || drop 0 sessions
# !!!!!!!!!! EV SHORT DURATION !!!!!!!!!! || drop 0 sessions
# d:\Codes\Energy_grid_new\src\data_loader.py:100: UserWarning: No ev data loaded, EIO if pred_model is Prediction
#   warnings.warn("No ev data loaded, EIO if pred_model is Prediction")
# d:\Codes\Energy_grid_new\src\data_loader.py:100: UserWarning: No ev data loaded, EIO if pred_model is Prediction
#   warnings.warn("No ev data loaded, EIO if pred_model is Prediction")
# !!!!!!!!!! EV SHORT DURATION !!!!!!!!!! || drop 0 sessions
# !!!!!!!!!! EV SHORT DURATION !!!!!!!!!! || drop 0 sessions
# Reason_out: File is not a zip file
# Failed in 0nd trial
# ========================= 2019-03-25 00:00:00 =========================
# d:\Codes\Energy_grid_new\src\data_loader.py:100: UserWarning: No ev data loaded, EIO if pred_model is Prediction
#   warnings.warn("No ev data loaded, EIO if pred_model is Prediction")
# summary saved at: 2019-03-25 00:00:00
# ========================= 2019-03-25 00:00:00 =========================
# !!!!!!!!!! EV SHORT DURATION !!!!!!!!!! || drop 0 sessions
# ========================= 2019-03-25 01:00:00 =========================
# ========================= 2019-03-25 02:00:00 =========================
# ========================= 2019-03-25 03:00:00 =========================
# ========================= 2019-03-25 04:00:00 =========================
# ========================= 2019-03-25 05:00:00 =========================
# ========================= 2019-03-25 06:00:00 =========================
# ========================= 2019-03-25 07:00:00 =========================
# ========================= 2019-03-25 08:00:00 =========================
# ========================= 2019-03-25 09:00:00 =========================
# d:\Codes\Energy_grid_new\src\data_loader.py:100: UserWarning: No ev data loaded, EIO if pred_model is Prediction
#   warnings.warn("No ev data loaded, EIO if pred_model is Prediction")
# !!!!!!!!!! EV SHORT DURATION !!!!!!!!!! || drop 0 sessions
# ========================= 2019-03-25 10:00:00 =========================
# ========================= 2019-03-25 11:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-03-25 12:00:00 =========================
# ========================= 2019-03-25 00:00:00 =========================
# ========================= 2019-03-25 13:00:00 =========================
# ========================= 2019-03-25 14:00:00 =========================
# ========================= 2019-03-25 15:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-03-25 16:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-03-25 17:00:00 =========================
# ========================= 2019-03-25 18:00:00 =========================
# ========================= 2019-03-25 19:00:00 =========================
# ========================= 2019-03-25 20:00:00 =========================
# ========================= 2019-03-25 21:00:00 =========================
# ========================= 2019-03-25 22:00:00 =========================
# ========================= 2019-03-25 23:00:00 =========================
# summary saved at: 2019-03-25 00:00:00
# ========================= 2019-03-25 00:00:00 =========================
# ========================= 2019-03-25 01:00:00 =========================
# ========================= 2019-03-25 02:00:00 =========================
# ========================= 2019-03-25 03:00:00 =========================
# ========================= 2019-03-25 04:00:00 =========================
# ========================= 2019-03-26 00:00:00 =========================
# ========================= 2019-03-25 05:00:00 =========================
# ========================= 2019-03-25 06:00:00 =========================
# ========================= 2019-03-26 01:00:00 =========================
# ========================= 2019-03-25 07:00:00 =========================
# ========================= 2019-03-26 02:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-03-25 08:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-03-25 09:00:00 =========================
# ========================= 2019-03-26 03:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-03-25 10:00:00 =========================
# ========================= 2019-03-26 04:00:00 =========================
# ========================= 2019-03-25 11:00:00 =========================
# ========================= 2019-03-26 05:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-03-25 12:00:00 =========================
# ========================= 2019-03-26 06:00:00 =========================
# ========================= 2019-03-25 13:00:00 =========================
# ========================= 2019-03-26 07:00:00 =========================
# ========================= 2019-03-25 14:00:00 =========================
# ========================= 2019-03-25 15:00:00 =========================
# ========================= 2019-03-26 08:00:00 =========================
# ========================= 2019-03-25 16:00:00 =========================
# ========================= 2019-03-25 17:00:00 =========================
# ========================= 2019-03-26 09:00:00 =========================
# ========================= 2019-03-25 18:00:00 =========================
# ========================= 2019-03-25 19:00:00 =========================
# ========================= 2019-03-26 10:00:00 =========================
# ========================= 2019-03-25 20:00:00 =========================
# ========================= 2019-03-25 21:00:00 =========================
# ========================= 2019-03-26 11:00:00 =========================
# ========================= 2019-03-25 22:00:00 =========================
# ========================= 2019-03-25 23:00:00 =========================
# ========================= 2019-03-26 12:00:00 =========================
# ========================= 2019-03-26 13:00:00 =========================
# ========================= 2019-03-26 14:00:00 =========================
# ========================= 2019-03-26 00:00:00 =========================
# ========================= 2019-03-26 01:00:00 =========================
# ========================= 2019-03-26 15:00:00 =========================
# ========================= 2019-03-26 02:00:00 =========================
# ========================= 2019-03-26 03:00:00 =========================
# ========================= 2019-03-26 16:00:00 =========================
# ========================= 2019-03-26 04:00:00 =========================
# ========================= 2019-03-26 05:00:00 =========================
# ========================= 2019-03-26 17:00:00 =========================
# ========================= 2019-03-26 06:00:00 =========================
# ========================= 2019-03-26 07:00:00 =========================
# ========================= 2019-03-26 18:00:00 =========================
# ========================= 2019-03-26 08:00:00 =========================
# ========================= 2019-03-26 09:00:00 =========================
# ========================= 2019-03-26 19:00:00 =========================
# ========================= 2019-03-26 10:00:00 =========================
# ========================= 2019-03-26 20:00:00 =========================
# ========================= 2019-03-26 11:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-03-26 12:00:00 =========================
# ========================= 2019-03-26 21:00:00 =========================
# ========================= 2019-03-26 13:00:00 =========================
# ========================= 2019-03-26 14:00:00 =========================
# ========================= 2019-03-26 22:00:00 =========================
# ========================= 2019-03-26 15:00:00 =========================
# ========================= 2019-03-26 23:00:00 =========================
# ========================= 2019-03-26 16:00:00 =========================
# ========================= 2019-03-26 17:00:00 =========================
# ========================= 2019-03-26 18:00:00 =========================
# ========================= 2019-03-26 19:00:00 =========================
# ========================= 2019-03-26 20:00:00 =========================
# ========================= 2019-03-26 21:00:00 =========================
# ========================= 2019-03-26 22:00:00 =========================
# ========================= 2019-03-26 23:00:00 =========================
# ========================= 2019-03-27 00:00:00 =========================
# ========================= 2019-03-27 01:00:00 =========================
# ========================= 2019-03-27 02:00:00 =========================
# ========================= 2019-03-27 00:00:00 =========================
# ========================= 2019-03-27 01:00:00 =========================
# ========================= 2019-03-27 03:00:00 =========================
# ========================= 2019-03-27 02:00:00 =========================
# ========================= 2019-03-27 04:00:00 =========================
# ========================= 2019-03-27 03:00:00 =========================
# ========================= 2019-03-27 04:00:00 =========================
# ========================= 2019-03-27 05:00:00 =========================
# ========================= 2019-03-27 05:00:00 =========================
# ========================= 2019-03-27 06:00:00 =========================
# ========================= 2019-03-27 06:00:00 =========================
# ========================= 2019-03-27 07:00:00 =========================
# ========================= 2019-03-27 08:00:00 =========================
# ========================= 2019-03-27 07:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-03-27 09:00:00 =========================
# ========================= 2019-03-27 08:00:00 =========================
# ========================= 2019-03-27 10:00:00 =========================
# p_grid in solution is higher than execution========================= 2019-03-27 09:00:00 =========================
#
# ========================= 2019-03-27 11:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-03-27 12:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-03-27 10:00:00 =========================
# ========================= 2019-03-27 13:00:00 =========================
# ========================= 2019-03-27 14:00:00 =========================
# ========================= 2019-03-27 11:00:00 =========================
# ========================= 2019-03-27 15:00:00 =========================
# ========================= 2019-03-27 16:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-03-27 12:00:00 =========================
# ========================= 2019-03-27 17:00:00 =========================
# ========================= 2019-03-27 18:00:00 =========================
# ========================= 2019-03-27 13:00:00 =========================
# ========================= 2019-03-27 19:00:00 =========================
# ========================= 2019-03-27 20:00:00 =========================
# ========================= 2019-03-27 14:00:00 =========================
# ========================= 2019-03-27 21:00:00 =========================
# ========================= 2019-03-27 22:00:00 =========================
# ========================= 2019-03-27 15:00:00 =========================
# ========================= 2019-03-27 23:00:00 =========================
# ========================= 2019-03-27 16:00:00 =========================
# ========================= 2019-03-27 17:00:00 =========================
# ========================= 2019-03-27 18:00:00 =========================
# ========================= 2019-03-27 19:00:00 =========================
# ========================= 2019-03-27 20:00:00 =========================
# ========================= 2019-03-28 00:00:00 =========================
# ========================= 2019-03-27 21:00:00 =========================
# ========================= 2019-03-28 01:00:00 =========================
# ========================= 2019-03-28 02:00:00 =========================
# ========================= 2019-03-27 22:00:00 =========================
# ========================= 2019-03-28 03:00:00 =========================
# ========================= 2019-03-28 04:00:00 =========================
# ========================= 2019-03-27 23:00:00 =========================
# ========================= 2019-03-28 05:00:00 =========================
# ========================= 2019-03-28 06:00:00 =========================
# ========================= 2019-03-28 07:00:00 =========================
# ========================= 2019-03-28 08:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-03-28 09:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-03-28 10:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-03-28 11:00:00 =========================
# ========================= 2019-03-28 12:00:00 =========================
# ========================= 2019-03-28 13:00:00 =========================
# ========================= 2019-03-28 14:00:00 =========================
# ========================= 2019-03-28 15:00:00 =========================
# ========================= 2019-03-28 16:00:00 =========================
# ========================= 2019-03-28 17:00:00 =========================
# ========================= 2019-03-28 18:00:00 =========================
# ========================= 2019-03-28 00:00:00 =========================
# ========================= 2019-03-28 19:00:00 =========================
# ========================= 2019-03-28 20:00:00 =========================
# ========================= 2019-03-28 01:00:00 =========================
# ========================= 2019-03-28 21:00:00 =========================
# ========================= 2019-03-28 22:00:00 =========================
# ========================= 2019-03-28 02:00:00 =========================
# ========================= 2019-03-28 23:00:00 =========================
# ========================= 2019-03-28 03:00:00 =========================
# ========================= 2019-03-28 04:00:00 =========================
# ========================= 2019-03-28 05:00:00 =========================
# ========================= 2019-03-28 06:00:00 =========================
# ========================= 2019-03-28 07:00:00 =========================
# ========================= 2019-03-28 08:00:00 =========================
# ========================= 2019-03-28 09:00:00 =========================
# ========================= 2019-03-29 00:00:00 =========================
# ========================= 2019-03-29 01:00:00 =========================
# ========================= 2019-03-28 10:00:00 =========================
# ========================= 2019-03-29 02:00:00 =========================
# ========================= 2019-03-29 03:00:00 =========================
# ========================= 2019-03-28 11:00:00 =========================
# ========================= 2019-03-29 04:00:00 =========================
# ========================= 2019-03-28 12:00:00 =========================
# ========================= 2019-03-29 05:00:00 =========================
# ========================= 2019-03-29 06:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-03-28 13:00:00 =========================
# ========================= 2019-03-29 07:00:00 =========================
# ========================= 2019-03-29 08:00:00 =========================
# ========================= 2019-03-28 14:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-03-29 09:00:00 =========================
# ========================= 2019-03-28 15:00:00 =========================
# ========================= 2019-03-29 10:00:00 =========================
# ========================= 2019-03-29 11:00:00 =========================
# ========================= 2019-03-28 16:00:00 =========================
# ========================= 2019-03-29 12:00:00 =========================
# ========================= 2019-03-28 17:00:00 =========================
# ========================= 2019-03-29 13:00:00 =========================
# ========================= 2019-03-29 14:00:00 =========================
# ========================= 2019-03-28 18:00:00 =========================
# ========================= 2019-03-29 15:00:00 =========================
# ========================= 2019-03-28 19:00:00 =========================
# ========================= 2019-03-29 16:00:00 =========================
# ========================= 2019-03-28 20:00:00 =========================
# ========================= 2019-03-29 17:00:00 =========================
# ========================= 2019-03-29 18:00:00 =========================
# ========================= 2019-03-28 21:00:00 =========================
# ========================= 2019-03-29 19:00:00 =========================
# ========================= 2019-03-28 22:00:00 =========================
# ========================= 2019-03-29 20:00:00 =========================
# ========================= 2019-03-29 21:00:00 =========================
# ========================= 2019-03-28 23:00:00 =========================
# ========================= 2019-03-29 22:00:00 =========================
# ========================= 2019-03-29 23:00:00 =========================
# ========================= 2019-03-29 00:00:00 =========================
# ========================= 2019-03-30 00:00:00 =========================
# ========================= 2019-03-29 01:00:00 =========================
# ========================= 2019-03-30 01:00:00 =========================
# ========================= 2019-03-29 02:00:00 =========================
# ========================= 2019-03-30 02:00:00 =========================
# ========================= 2019-03-30 03:00:00 =========================
# ========================= 2019-03-29 03:00:00 =========================
# ========================= 2019-03-30 04:00:00 =========================
# ========================= 2019-03-29 04:00:00 =========================
# ========================= 2019-03-30 05:00:00 =========================
# ========================= 2019-03-29 05:00:00 =========================
# ========================= 2019-03-30 06:00:00 =========================
# ========================= 2019-03-30 07:00:00 =========================
# ========================= 2019-03-29 06:00:00 =========================
# ========================= 2019-03-30 08:00:00 =========================
# ========================= 2019-03-29 07:00:00 =========================
# ========================= 2019-03-30 09:00:00 =========================
# ========================= 2019-03-30 10:00:00 =========================
# ========================= 2019-03-29 08:00:00 =========================
# ========================= 2019-03-30 11:00:00 =========================
# ========================= 2019-03-29 09:00:00 =========================
# ========================= 2019-03-30 12:00:00 =========================
# ========================= 2019-03-30 13:00:00 =========================
# ========================= 2019-03-29 10:00:00 =========================
# ========================= 2019-03-30 14:00:00 =========================
# ========================= 2019-03-29 11:00:00 =========================
# ========================= 2019-03-30 15:00:00 =========================
# ========================= 2019-03-30 16:00:00 =========================
# ========================= 2019-03-29 12:00:00 =========================
# ========================= 2019-03-30 17:00:00 =========================
# ========================= 2019-03-29 13:00:00 =========================
# ========================= 2019-03-30 18:00:00 =========================
# ========================= 2019-03-30 19:00:00 =========================
# ========================= 2019-03-29 14:00:00 =========================
# ========================= 2019-03-30 20:00:00 =========================
# ========================= 2019-03-29 15:00:00 =========================
# ========================= 2019-03-30 21:00:00 =========================
# ================================================== 2019-03-29 16:00:00 =========================
#  2019-03-30 22:00:00 =========================
# ========================= 2019-03-30 23:00:00 =========================
# ========================= 2019-03-29 17:00:00 =========================
# ========================= 2019-03-29 18:00:00 =========================
# ========================= 2019-03-29 19:00:00 =========================
# ========================= 2019-03-29 20:00:00 =========================
# ========================= 2019-03-29 21:00:00 =========================
# ========================= 2019-03-29 22:00:00 =========================
# ========================= 2019-03-29 23:00:00 =========================
# ========================= 2019-03-31 00:00:00 =========================
# ========================= 2019-03-31 01:00:00 =========================
# ========================= 2019-03-31 02:00:00 =========================
# ========================= 2019-03-31 03:00:00 =========================
# ========================= 2019-03-31 04:00:00 =========================
# ========================= 2019-03-31 05:00:00 =========================
# ========================= 2019-03-31 06:00:00 =========================
# ========================= 2019-03-31 07:00:00 =========================
# ========================= 2019-03-31 08:00:00 =========================
# ========================= 2019-03-31 09:00:00 =========================
# ========================= 2019-03-31 10:00:00 =========================
# ========================= 2019-03-31 11:00:00 =========================
# ========================= 2019-03-31 12:00:00 =========================
# ========================= 2019-03-30 00:00:00 =========================
# ========================= 2019-03-31 13:00:00 =========================
# ========================= 2019-03-30 01:00:00 =========================
# ========================= 2019-03-31 14:00:00 =========================
# ========================= 2019-03-30 02:00:00 =========================
# ========================= 2019-03-31 15:00:00 =========================
# ========================= 2019-03-31 16:00:00 =========================
# ========================= 2019-03-30 03:00:00 =========================
# ========================= 2019-03-31 17:00:00 =========================
# ========================= 2019-03-30 04:00:00 =========================
# ========================= 2019-03-31 18:00:00 =========================
# ========================= 2019-03-30 05:00:00 =========================
# ========================= 2019-03-31 19:00:00 =========================
# ========================= 2019-03-30 06:00:00 =========================
# ========================= 2019-03-31 20:00:00 =========================
# ========================= 2019-03-31 21:00:00 =========================
# ========================= 2019-03-30 07:00:00 =========================
# ========================= 2019-03-31 22:00:00 =========================
# ========================= 2019-03-30 08:00:00 =========================
# ========================= 2019-03-31 23:00:00 =========================
# ========================= 2019-03-30 09:00:00 =========================
# ========================= 2019-03-30 10:00:00 =========================
# ========================= 2019-03-30 11:00:00 =========================
# ========================= 2019-03-30 12:00:00 =========================
# ========================= 2019-03-30 13:00:00 =========================
# ========================= 2019-03-30 14:00:00 =========================
# ========================= 2019-03-30 15:00:00 =========================
# ========================= 2019-03-30 16:00:00 =========================
# ========================= 2019-03-30 17:00:00 =========================
# ========================= 2019-03-30 18:00:00 =========================
# ========================= 2019-03-30 19:00:00 =========================
# ========================= 2019-03-30 20:00:00 =========================
# ========================= FINISH =========================
# ========================= 2019-03-30 21:00:00 =========================
# ========================= 2019-03-30 22:00:00 =========================
# ========================= 2019-03-30 23:00:00 =========================
# Done, trial 65
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ========================= 2019-03-31 00:00:00 =========================
# ========================= 2019-03-31 01:00:00 =========================
# ========================= 2019-03-31 02:00:00 =========================
# ========================= 2019-03-31 03:00:00 =========================
# ========================= 2019-03-31 04:00:00 =========================
# ========================= 2019-03-31 05:00:00 =========================
# ========================= 2019-03-31 06:00:00 =========================
# ========================= 2019-03-31 07:00:00 =========================
# ========================= 2019-03-31 08:00:00 =========================
# ========================= 2019-03-31 09:00:00 =========================
# ========================= 2019-03-31 10:00:00 =========================
# ========================= 2019-03-31 11:00:00 =========================
# ========================= 2019-03-31 12:00:00 =========================
# ========================= 2019-03-31 13:00:00 =========================
# ========================= 2019-03-31 14:00:00 =========================
# ========================= 2019-03-31 15:00:00 =========================
# ========================= 2019-03-31 16:00:00 =========================
# ========================= 2019-03-31 17:00:00 =========================
# ========================= 2019-03-31 18:00:00 =========================
# ========================= 2019-03-31 19:00:00 =========================
# ========================= 2019-03-31 20:00:00 =========================
# ========================= 2019-03-31 21:00:00 =========================
# ========================= 2019-03-31 22:00:00 =========================
# ========================= 2019-03-31 23:00:00 =========================
# ========================= FINISH =========================
# Done, trial 61
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
