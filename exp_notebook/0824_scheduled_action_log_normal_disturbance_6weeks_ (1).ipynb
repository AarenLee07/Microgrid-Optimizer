# %%
import os
import sys
import exp
from threading import Thread
src_path = sys.path[0].replace("exp_notebook", "src")
#replace notebook as scripts
data_path = sys.path[0].replace("exp_notebook", "data")
if src_path not in sys.path:
    sys.path.append(src_path)
out_path = sys.path[0].replace("exp_notebook", "output")
log_folder=r'L:\Coding_project\Energy_grid_new_exp_local'
#log_folder=r'D:\Codes\Energy_grid_new_exp_local'

# %%
exp_suffix = "Aug2023_3"
exp_folder = os.path.join(out_path, "experiments", exp_suffix)
debug_folder = os.path.join(out_path, "debug_test")
assert os.path.exists(exp_folder)
log_fn = os.path.join(exp_folder, "LOG-MPC-MSC-6h-normal-disturbance-6weeks1.xlsx")#_oneday_12months

save_path = os.path.join(log_folder,exp_suffix, "MPC-disturbance")
if not os.path.exists(save_path):
    os.makedirs(save_path)
assert os.path.exists(save_path)

# %%
save_path
# Out:
# 'L:\\Coding_project\\Energy_grid_new_exp_local\\Aug2023_3\\MPC-disturbance'

# %%
def parallel():
    class MPC_parallel(exp.MPC_ExperimentManager):
        None
    for i in range(15):
        try:
            em = MPC_parallel(log_fn=log_fn, save_path=save_path, save=True, exp_prefix="MPC")
            var_keys = [
                        "method", "strategy",
                        "pred_model", "deg_model_opt", "p_grid_max", 
                        "price_dc", "price_sell", 
                        "ev_charge_rule", 
                        "B_kWh",  "deg_model", 
                        "start", "end", 
                        "bld", "ev", "pv",
                        "disturbance_scale","disturbance_rule"]
            em.run(keys=var_keys, num_trials=20)
        except Exception as e:
            print('Reason_out:', e)  
            print('Failed in '+str(i)+'nd trial')
            continue

# %%
t1=Thread(target=parallel)
#t2=Thread(target=parallel)
#t3=Thread(target=parallel)

t1.start()
#t2.start()
#t3.start()

t1.join()
#t2.join()
#t3.join()
# Out:
# l:\Coding_project\Energy_grid_new\src\data_loader.py:100: UserWarning: No ev data loaded, EIO if pred_model is Prediction
#   warnings.warn("No ev data loaded, EIO if pred_model is Prediction")
# !!!!!!!!!! EV SHORT DURATION !!!!!!!!!! || drop 0 sessions
# l:\Coding_project\Energy_grid_new\src\data_loader.py:100: UserWarning: No ev data loaded, EIO if pred_model is Prediction
#   warnings.warn("No ev data loaded, EIO if pred_model is Prediction")
# !!!!!!!!!! EV SHORT DURATION !!!!!!!!!! || drop 0 sessions
# ========================= 2019-01-01 00:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# summary saved at: 2019-01-01 00:00:00
# ========================= 2019-01-01 00:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-01-01 01:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-01-01 02:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-01-01 03:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-01-01 04:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-01-01 05:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-01-01 06:00:00 =========================
# ========================= 2019-01-01 07:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-01-01 08:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-01-01 09:00:00 =========================
# ========================= 2019-01-01 10:00:00 =========================
# ========================= 2019-01-01 11:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-01-01 12:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-01-01 13:00:00 =========================
# ========================= 2019-01-01 14:00:00 =========================
# ========================= 2019-01-01 15:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-01-01 16:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-01
00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-01-06 16:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-01-06 17:00:00 =========================
# ========================= 2019-01-06 18:00:00 =========================
# ========================= 2019-01-06 19:00:00 =========================
# ========================= 2019-01-06 20:00:00 =========================
# ========================= 2019-01-06 21:00:00 =========================
# ========================= 2019-01-06 22:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-01-06 23:00:00 =========================
# p_grid in solution is higher than execution
# ========================= FINISH =========================
# Done, trial 22
# l:\Coding_project\Energy_grid_new\src\data_loader.py:100: UserWarning: No ev data loaded, EIO if pred_model is Prediction
#   warnings.warn("No ev data loaded, EIO if pred_model is Prediction")
# !!!!!!!!!! EV SHORT DURATION !!!!!!!!!! || drop 0 sessions
# l:\Coding_project\Energy_grid_new\src\data_loader.py:100: UserWarning: No ev data loaded, EIO if pred_model is Prediction
#   warnings.warn("No ev data loaded, EIO if pred_model is Prediction")
# !!!!!!!!!! EV SHORT DURATION !!!!!!!!!! || drop 0 sessions
# ========================= 2019-02-04 00:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# summary saved at: 2019-02-04 00:00:00
# ========================= 2019-02-04 00:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-04 01:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-04 02:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-04 03:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-02-04 04:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-04 05:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-04 06:00:00 =========================
# ========================= 2019-02-04 07:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-04 08:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-04 09:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-04 10:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-04 11:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-04 12:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-04 13:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-02-04 14:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-04 15:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-02-04 16:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-04 17:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-02-04 18:00:00 =========================
# ========================= 2019-02-04 19:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-04 20:00:00 =========================
# ========================= 2019-02-04 21:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-04 22:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-02-04 23:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-02-05 00:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-02-05 01:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-05 02:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-05 03:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-02-05 04:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-02-05 05:00:00 =========================
# ========================= 2019-02-05 06:00:00 =========================
# ========================= 2019-02-05 07:00:00 =========================
# ========================= 2019-02-05 08:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-05 09:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-05 10:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-05 11:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-05 12:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-05 13:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-05 14:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-05 15:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-02-05 16:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-05 17:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-02-05 18:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-02-05 19:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-02-05 20:00:00 =========================
# ========================= 2019-02-05 21:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-05 22:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-05 23:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-02-06 00:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-06 01:00:00 =========================
# ========================= 2019-02-06 02:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-06 03:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-06 04:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-06 05:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-06 06:00:00 =========================
# ========================= 2019-02-06 07:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-02-06 08:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-06 09:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-02-06 10:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-06 11:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-06 12:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-06 13:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-02-06 14:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-06 15:00:00 =========================
# ========================= 2019-02-06 16:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-06 17:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-02-06 18:00:00 =========================
# ========================= 2019-02-06 19:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-02-06 20:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-02-06 21:00:00 =========================
# ========================= 2019-02-06 22:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-06 23:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-07 00:00:00 =========================
# ========================= 2019-02-07 01:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-07 02:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-02-07 03:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-07 04:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-02-07 05:00:00 =========================
# ========================= 2019-02-07 06:00:00 =========================
# ========================= 2019-02-07 07:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-02-07 08:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-07 09:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-07 10:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-02-07 11:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-07 12:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-07 13:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-02-07 14:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-07 15:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-02-07 16:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-07 17:00:00 =========================
# ========================= 2019-02-07 18:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-07 19:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-07 20:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-07 21:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-02-07 22:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-07 23:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-08 00:00:00 =========================
# ========================= 2019-02-08 01:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-08 02:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-02-08 03:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-08 04:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-08 05:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-02-08 06:00:00 =========================
# ========================= 2019-02-08 07:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-08 08:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-08 09:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-02-08 10:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-08 11:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-08 12:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-02-08 13:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-08 14:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-08 15:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-08 16:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-08 17:00:00 =========================
# ========================= 2019-02-08 18:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-02-08 19:00:00 =========================
# ========================= 2019-02-08 20:00:00 =========================
# ========================= 2019-02-08 21:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-02-08 22:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-08 23:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-09 00:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-09 01:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-09 02:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-02-09 03:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-09 04:00:00 =========================
# ========================= 2019-02-09 05:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-09 06:00:00 =========================
# ========================= 2019-02-09 07:00:00 =========================
# ========================= 2019-02-09 08:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-09 09:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-02-09 10:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-09 11:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-09 12:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-02-09 13:00:00 =========================
# ========================= 2019-02-09 14:00:00 =========================
# ========================= 2019-02-09 15:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-09 16:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-09 17:00:00 =========================
# ========================= 2019-02-09 18:00:00 =========================
# ========================= 2019-02-09 19:00:00 =========================
# ========================= 2019-02-09 20:00:00 =========================
# ========================= 2019-02-09 21:00:00 =========================
# ========================= 2019-02-09 22:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-09 23:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-02-10 00:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-10 01:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-10 02:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-10 03:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-10 04:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-10 05:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-10 06:00:00 =========================
# ========================= 2019-02-10 07:00:00 =========================
# ========================= 2019-02-10 08:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-10 09:00:00 =========================
# ========================= 2019-02-10 10:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-02-10 11:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-02-10 12:00:00 =========================
# ========================= 2019-02-10 13:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-10 14:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-10 15:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-02-10 16:00:00 =========================
# ========================= 2019-02-10 17:00:00 =========================
# ========================= 2019-02-10 18:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-02-10 19:00:00 =========================
# ========================= 2019-02-10 20:00:00 =========================
# ========================= 2019-02-10 21:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-10 22:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-02-10 23:00:00 =========================
# p_grid in solution is higher than execution
# ========================= FINISH =========================
# Done, trial 112
# l:\Coding_project\Energy_grid_new\src\data_loader.py:100: UserWarning: No ev data loaded, EIO if pred_model is Prediction
#   warnings.warn("No ev data loaded, EIO if pred_model is Prediction")
# !!!!!!!!!! EV SHORT DURATION !!!!!!!!!! || drop 0 sessions
# l:\Coding_project\Energy_grid_new\src\data_loader.py:100: UserWarning: No ev data loaded, EIO if pred_model is Prediction
#   warnings.warn("No ev data loaded, EIO if pred_model is Prediction")
# !!!!!!!!!! EV SHORT DURATION !!!!!!!!!! || drop 0 sessions
# ========================= 2019-03-04 00:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ...
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-04 23:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-06-05 00:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-05 01:00:00 =========================
# ========================= 2019-06-05 02:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-05 03:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-05 04:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-05 05:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-05 06:00:00 =========================
# ========================= 2019-06-05 07:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-06-05 08:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-05 09:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-06-05 10:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-05 11:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-05 12:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-05 13:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-06-05 14:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-05 15:00:00 =========================
# ========================= 2019-06-05 16:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-05 17:00:00 =========================
# ========================= 2019-06-05 18:00:00 =========================
# ========================= 2019-06-05 19:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-06-05 20:00:00 =========================
# ========================= 2019-06-05 21:00:00 =========================
# ========================= 2019-06-05 22:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-05 23:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-06 00:00:00 =========================
# ========================= 2019-06-06 01:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-06 02:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-06-06 03:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-06 04:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-06-06 05:00:00 =========================
# ========================= 2019-06-06 06:00:00 =========================
# ========================= 2019-06-06 07:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-06-06 08:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-06 09:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-06 10:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-06-06 11:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-06 12:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-06 13:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-06-06 14:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-06 15:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-06-06 16:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-06 17:00:00 =========================
# ========================= 2019-06-06 18:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-06 19:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-06-06 20:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-06-06 21:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-06-06 22:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-06 23:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-07 00:00:00 =========================
# ========================= 2019-06-07 01:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-07 02:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-06-07 03:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-07 04:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-07 05:00:00 =========================
# ========================= 2019-06-07 06:00:00 =========================
# ========================= 2019-06-07 07:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-07 08:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-07 09:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-06-07 10:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-07 11:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-07 12:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-06-07 13:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-07 14:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-07 15:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-07 16:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-07 17:00:00 =========================
# ========================= 2019-06-07 18:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-06-07 19:00:00 =========================
# ========================= 2019-06-07 20:00:00 =========================
# ========================= 2019-06-07 21:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-06-07 22:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-07 23:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-08 00:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-08 01:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-08 02:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-06-08 03:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-08 04:00:00 =========================
# ========================= 2019-06-08 05:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-08 06:00:00 =========================
# ========================= 2019-06-08 07:00:00 =========================
# ========================= 2019-06-08 08:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-08 09:00:00 =========================
# ========================= 2019-06-08 10:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-06-08 11:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-08 12:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-06-08 13:00:00 =========================
# ========================= 2019-06-08 14:00:00 =========================
# ========================= 2019-06-08 15:00:00 =========================
# ========================= 2019-06-08 16:00:00 =========================
# ========================= 2019-06-08 17:00:00 =========================
# ========================= 2019-06-08 18:00:00 =========================
# ========================= 2019-06-08 19:00:00 =========================
# ========================= 2019-06-08 20:00:00 =========================
# ========================= 2019-06-08 21:00:00 =========================
# ========================= 2019-06-08 22:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-06-08 23:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-06-09 00:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-09 01:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-09 02:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-09 03:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-09 04:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-09 05:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-09 06:00:00 =========================
# ========================= 2019-06-09 07:00:00 =========================
# ========================= 2019-06-09 08:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-06-09 09:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-06-09 10:00:00 =========================
# ========================= 2019-06-09 11:00:00 =========================
# ========================= 2019-06-09 12:00:00 =========================
# ========================= 2019-06-09 13:00:00 =========================
# ========================= 2019-06-09 14:00:00 =========================
# ========================= 2019-06-09 15:00:00 =========================
# ========================= 2019-06-09 16:00:00 =========================
# ========================= 2019-06-09 17:00:00 =========================
# ========================= 2019-06-09 18:00:00 =========================
# ========================= 2019-06-09 19:00:00 =========================
# ========================= 2019-06-09 20:00:00 =========================
# ========================= 2019-06-09 21:00:00 =========================
# ========================= 2019-06-09 22:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-06-09 23:00:00 =========================
# p_grid in solution is higher than execution
# ========================= FINISH =========================
# Done, trial 360
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
