# %%
import os
import sys
import exp
from threading import Thread
src_path = sys.path[0].replace("exp_notebook", "src")
#replace notebook as scripts
data_path = sys.path[0].replace("exp_notebook", "data")
if src_path not in sys.path:
    sys.path.append(src_path)
out_path = sys.path[0].replace("exp_notebook", "output")
log_folder=r'L:\Coding_project\Energy_grid_new_exp_local'
#log_folder=r'D:\Codes\Energy_grid_new_exp_local'

# %%
exp_suffix = "Aug2023_3"
exp_folder = os.path.join(out_path, "experiments", exp_suffix)
debug_folder = os.path.join(out_path, "debug_test")
assert os.path.exists(exp_folder)
log_fn = os.path.join(exp_folder, "LOG-MPC-MSC-bat-sensitive.xlsx")#_oneday_12months

save_path = os.path.join(log_folder,exp_suffix, "MPC-bat-sensitive")
if not os.path.exists(save_path):
    os.makedirs(save_path)
assert os.path.exists(save_path)

# %%
save_path
# Out:
# 'L:\\Coding_project\\Energy_grid_new_exp_local\\Aug2023_3\\MPC-bat-sensitive'

# %%
def parallel():
    class MPC_parallel(exp.MPC_ExperimentManager):
        None
    for i in range(15):
        try:
            em = MPC_parallel(log_fn=log_fn, save_path=save_path, save=True, exp_prefix="MPC")
            var_keys = [
                        "method", "strategy",
                        "pred_model", "deg_model_opt", "p_grid_max", 
                        "price_dc", "price_sell", 
                        "ev_charge_rule", 
                        "B_kWh",  "deg_model", 
                        "start", "end", 
                        "bld", "ev", "pv",]
            em.run(keys=var_keys, num_trials=20)
        except Exception as e:
            print('Reason_out:', e)  
            print('Failed in '+str(i)+'nd trial')
            continue

# %%
t1=Thread(target=parallel)
#t2=Thread(target=parallel)
#t3=Thread(target=parallel)

t1.start()
#t2.start()
#t3.start()

t1.join()
#t2.join()
#t3.join()
# Out:
# l:\Coding_project\Energy_grid_new\src\data_loader.py:100: UserWarning: No ev data loaded, EIO if pred_model is Prediction
#   warnings.warn("No ev data loaded, EIO if pred_model is Prediction")
# !!!!!!!!!! EV SHORT DURATION !!!!!!!!!! || drop 0 sessions
# l:\Coding_project\Energy_grid_new\src\data_loader.py:100: UserWarning: No ev data loaded, EIO if pred_model is Prediction
#   warnings.warn("No ev data loaded, EIO if pred_model is Prediction")
# !!!!!!!!!! EV SHORT DURATION !!!!!!!!!! || drop 0 sessions
# l:\Coding_project\Energy_grid_new\src\data_loader.py:184: UserWarning: No EV data loaded, EIO if pred_model is Prediction.
#   warnings.warn("No EV data loaded, EIO if pred_model is Prediction.")
# ========================= 2019-07-01 00:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# summary saved at: 2019-07-01 00:00:00
# ========================= 2019-07-01 00:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-01 01:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-01 02:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-01 03:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-01 04:00:00 =========================
# ========================= 2019-07-01 05:00:00 =========================
# ========================= 2019-07-01 06:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-07-01 07:00:00 =========================
# ========================= 2019-07-01 08:00:00 =========================
# ========================= 2019-07-01 09:00:00 =========================
# ========================= 2019-07-01 10:00:00 =========================
# ========================= 2019-07-01 11:00:00 =========================
# ========================= 2019-07-01 12:00:00 =========================
# ========================= 2019-07-01 13:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-07-01 14:00:00 =========================
# ========================= 2019-07-01 15:00:00 =========================
# ========================= 2019-07-01 16:00:00 =========================
# ========================= 2019-07-01 17:00:00 =========================
# ========================= 2019-07-01 18:00:00 =========================
# ========================= 2019-07-01 19:00:00 =========================
# ========================= 2019-07-01 20:00:00 =========================
# ========================= 2019-07-01 21:00:00 =========================
# ========================= 2019-07-01 22:00:00 =========================
# ========================= 2019-07-01 23:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-02 00:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-02 01:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-02 02:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-07-02 03:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-07-02 04:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-02 05:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-02 06:00:00 =========================
# ========================= 2019-07-02 07:00:00 =========================
# ========================= 2019-07-02 08:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-02 09:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-02 10:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-02 11:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-02 12:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-02 13:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-02 14:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-02 15:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-02 16:00:00 =========================
# ========================= 2019-07-02 17:00:00 =========================
# ========================= 2019-07-02 18:00:00 =========================
# ========================= 2019-07-02 19:00:00 =========================
# ========================= 2019-07-02 20:00:00 =========================
# ========================= 2019-07-02 21:00:00 =========================
# ========================= 2019-07-02 22:00:00 =========================
# ========================= 2019-07-02 23:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-03 00:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-03 01:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-03 02:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-03 03:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-03 04:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-03 05:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-03 06:00:00 =========================
# ========================= 2019-07-03 07:00:00 =========================
# ========================= 2019-07-03 08:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-03 09:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-03 10:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-03 11:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-03 12:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-03 13:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-03 14:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-03 15:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-03 16:00:00 =========================
# ========================= 2019-07-03 17:00:00 =========================
# ========================= 2019-07-03 18:00:00 =========================
# ========================= 2019-07-03 19:00:00 =========================
# ========================= 2019-07-03 20:00:00 =========================
# ========================= 2019-07-03 21:00:00 =========================
# ========================= 2019-07-03 22:00:00 =========================
# ========================= 2019-07-03 23:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-04 00:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-04 01:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-04 02:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-04 03:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-04 04:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-04 05:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-07-04 06:00:00 =========================
# ========================= 2019-07-04 07:00:00 =========================
# ========================= 2019-07-04 08:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-04 09:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-04 10:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-04 11:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-04 12:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-04 13:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-04 14:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-04 15:00:00 =========================
# ========================= 2019-07-04 16:00:00 =========================
# ========================= 2019-07-04 17:00:00 =========================
# ========================= 2019-07-04 18:00:00 =========================
# ========================= 2019-07-04 19:00:00 =========================
# ========================= 2019-07-04 20:00:00 =========================
# ========================= 2019-07-04 21:00:00 =========================
# ========================= 2019-07-04 22:00:00 =========================
# ========================= 2019-07-04 23:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-05 00:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-05 01:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-05 02:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-05 03:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-05 04:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-05 05:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-07-05 06:00:00 =========================
# ========================= 2019-07-05 07:00:00 =========================
# ========================= 2019-07-05 08:00:00 =========================
# ========================= 2019-07-05 09:00:00 =========================
# ========================= 2019-07-05 10:00:00 =========================
# ========================= 2019-07-05 11:00:00 =========================
# ========================= 2019-07-05 12:00:00 =========================
# ========================= 2019-07-05 13:00:00 =========================
# ========================= 2019-07-05 14:00:00 =========================
# ========================= 2019-07-05 15:00:00 =========================
# ========================= 2019-07-05 16:00:00 =========================
# ========================= 2019-07-05 17:00:00 =========================
# ========================= 2019-07-05 18:00:00 =========================
# ========================= 2019-07-05 19:00:00 =========================
# ========================= 2019-07-05 20:00:00 =========================
# ========================= 2019-07-05 21:00:00 =========================
# ========================= 2019-07-05 22:00:00 =========================
# ========================= 2019-07-05 23:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-06 00:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-06 01:00:00 =========================
# ========================= 2019-07-06 02:00:00 =========================
# ========================= 2019-07-06 03:00:00 =========================
# ========================= 2019-07-06 04:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-07-06 05:00:00 =========================
# ========================= 2019-07-06 06:00:00 =========================
# ========================= 2019-07-06 07:00:00 =========================
# ========================= 2019-07-06 08:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-06 09:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-06 10:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-06 11:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-06 12:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-06 13:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-06 14:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-06 15:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-06 16:00:00 =========================
# ========================= 2019-07-06 17:00:00 =========================
# ========================= 2019-07-06 18:00:00 =========================
# ========================= 2019-07-06 19:00:00 =========================
# ========================= 2019-07-06 20:00:00 =========================
# ========================= 2019-07-06 21:00:00 =========================
# ========================= 2019-07-06 22:00:00 =========================
# ========================= 2019-07-06 23:00:00 =========================
# ========================= 2019-07-07 00:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-07 01:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-07 02:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-07 03:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-07 04:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-07 05:00:00 =========================
# ========================= 2019-07-07 06:00:00 =========================
# ========================= 2019-07-07 07:00:00 =========================
# ========================= 2019-07-07 08:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-07 09:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-07 10:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-07 11:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-07 12:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-07 13:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-07 14:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-07 15:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-07-07 16:00:00 =========================
# ========================= 2019-07-07 17:00:00 =========================
# ========================= 2019-07-07 18:00:00 =========================
# ========================= 2019-07-07 19:00:00 =========================
# ========================= 2019-07-07 20:00:00 =========================
# ========================= 2019-07-07 21:00:00 =========================
# ========================= 2019-07-07 22:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-07 23:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= FINISH =========================
# Done, trial 27
# l:\Coding_project\Energy_grid_new\src\data_loader.py:100: UserWarning: No ev data loaded, EIO if pred_model is Prediction
#   warnings.warn("No ev data loaded, EIO if pred_model is Prediction")
# !!!!!!!!!! EV SHORT DURATION !!!!!!!!!! || drop 0 sessions
# l:\Coding_project\Energy_grid_new\src\data_loader.py:100: UserWarning: No ev data loaded, EIO if pred_model is Prediction
#   warnings.warn("No ev data loaded, EIO if pred_model is Prediction")
# !!!!!!!!!! EV SHORT DURATION !!!!!!!!!! || drop 0 sessions
# l:\Coding_project\Energy_grid_new\src\data_loader.py:184: UserWarning: No EV data loaded, EIO if pred_model is Prediction.
#   warnings.warn("No EV data loaded, EIO if pred_model is Prediction.")
# ========================= 2019-07-01 00:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# summary saved at: 2019-07-01 00:00:00
# ========================= 2019-07-01 00:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-01 01:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-01 02:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-01 03:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-01 04:00:00 =========================
# ========================= 2019-07-01 05:00:00 =========================
# ========================= 2019-07-01 06:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-07-01 07:00:00 =========================
# ========================= 2019-07-01 08:00:00 =========================
# ========================= 2019-07-01 09:00:00 =========================
# ========================= 2019-07-01 10:00:00 =========================
# ========================= 2019-07-01 11:00:00 =========================
# ========================= 2019-07-01 12:00:00 =========================
# ========================= 2019-07-01 13:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-07-01 14:00:00 =========================
# ========================= 2019-07-01 15:00:00 =========================
# ========================= 2019-07-01 16:00:00 =========================
# ========================= 2019-07-01 17:00:00 =========================
# ========================= 2019-07-01 18:00:00 =========================
# ========================= 2019-07-01 19:00:00 =========================
# ========================= 2019-07-01 20:00:00 =========================
# ========================= 2019-07-01 21:00:00 =========================
# ========================= 2019-07-01 22:00:00 =========================
# ========================= 2019-07-01 23:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-02 00:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-02 01:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-02 02:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-07-02 03:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-07-02 04:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-02 05:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-02 06:00:00 =========================
# ========================= 2019-07-02 07:00:00 =========================
# ========================= 2019-07-02 08:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-02 09:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-02 10:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-02 11:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-02 12:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-02 13:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-02 14:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-02 15:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-02 16:00:00 =========================
# ========================= 2019-07-02 17:00:00 =========================
# ========================= 2019-07-02 18:00:00 =========================
# ========================= 2019-07-02 19:00:00 =========================
# ========================= 2019-07-02 20:00:00 =========================
# ========================= 2019-07-02 21:00:00 =========================
# ========================= 2019-07-02 22:00:00 =========================
# ========================= 2019-07-02 23:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-03 00:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-03 01:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-03 02:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-03 03:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-03 04:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-03 05:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-03 06:00:00 =========================
# ========================= 2019-07-03 07:00:00 =========================
# ========================= 2019-07-03 08:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-03 09:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-03 10:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-03 11:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-03 12:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-03 13:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-03 14:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-03 15:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-03 16:00:00 =========================
# ========================= 2019-07-03 17:00:00 =========================
# ========================= 2019-07-03 18:00:00 =========================
# ========================= 2019-07-03 19:00:00 =========================
# ========================= 2019-07-03 20:00:00 =========================
# ========================= 2019-07-03 21:00:00 =========================
# ========================= 2019-07-03 22:00:00 =========================
# ========================= 2019-07-03 23:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-04 00:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-04 01:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-04 02:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-04 03:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-04 04:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-04 05:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-07-04 06:00:00 =========================
# ========================= 2019-07-04 07:00:00 =========================
# ========================= 2019-07-04 08:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-04 09:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-04 10:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-04 11:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-04 12:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-04 13:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-04 14:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-04 15:00:00 =========================
# ========================= 2019-07-04 16:00:00 =========================
# ========================= 2019-07-04 17:00:00 =========================
# ========================= 2019-07-04 18:00:00 =========================
# ========================= 2019-07-04 19:00:00 =========================
# ========================= 2019-07-04 20:00:00 =========================
# ========================= 2019-07-04 21:00:00 =========================
# ========================= 2019-07-04 22:00:00 =========================
# ========================= 2019-07-04 23:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-05 00:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-05 01:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-05 02:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-05 03:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-05 04:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-05 05:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-07-05 06:00:00 =========================
# ========================= 2019-07-05 07:00:00 =========================
# ========================= 2019-07-05 08:00:00 =========================
# ========================= 2019-07-05 09:00:00 =========================
# ========================= 2019-07-05 10:00:00 =========================
# ========================= 2019-07-05 11:00:00 =========================
# ========================= 2019-07-05 12:00:00 =========================
# ========================= 2019-07-05 13:00:00 =========================
# ========================= 2019-07-05 14:00:00 =========================
# ========================= 2019-07-05 15:00:00 =========================
# ========================= 2019-07-05 16:00:00 =========================
# ========================= 2019-07-05 17:00:00 =========================
# ========================= 2019-07-05 18:00:00 =========================
# ========================= 2019-07-05 19:00:00 =========================
# ========================= 2019-07-05 20:00:00 =========================
# ========================= 2019-07-05 21:00:00 =========================
# ========================= 2019-07-05 22:00:00 =========================
# ========================= 2019-07-05 23:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-06 00:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-06 01:00:00 =========================
# ========================= 2019-07-06 02:00:00 =========================
# ========================= 2019-07-06 03:00:00 =========================
# ========================= 2019-07-06 04:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-07-06 05:00:00 =========================
# ========================= 2019-07-06 06:00:00 =========================
# ========================= 2019-07-06 07:00:00 =========================
# ========================= 2019-07-06 08:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-06 09:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-06 10:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-06 11:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-06 12:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-06 13:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-06 14:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-06 15:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-07-06 16:00:00 =========================
# ========================= 2019-07-06 17:00:00 =========================
# ========================= 2019-07-06 18:00:00 =========================
# ========================= 2019-07-06 19:00:00 =========================
# ========================= 2019-07-06 20:00:00 =========================
# ========================= 2019-07-06 21:00:00 =========================
# ========================= 2019-07-06 22:00:00 =========================
# ========================= 2019-07-06 23:00:00 =========================
# ...
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-04 01:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-04 02:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-04 03:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-04 04:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-04 05:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-04 06:00:00 =========================
# ========================= 2019-12-04 07:00:00 =========================
# ========================= 2019-12-04 08:00:00 =========================
# ========================= 2019-12-04 09:00:00 =========================
# ========================= 2019-12-04 10:00:00 =========================
# ========================= 2019-12-04 11:00:00 =========================
# ========================= 2019-12-04 12:00:00 =========================
# ========================= 2019-12-04 13:00:00 =========================
# ========================= 2019-12-04 14:00:00 =========================
# ========================= 2019-12-04 15:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-04 16:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-04 17:00:00 =========================
# ========================= 2019-12-04 18:00:00 =========================
# ========================= 2019-12-04 19:00:00 =========================
# ========================= 2019-12-04 20:00:00 =========================
# ========================= 2019-12-04 21:00:00 =========================
# ========================= 2019-12-04 22:00:00 =========================
# ========================= 2019-12-04 23:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-05 00:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-05 01:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-05 02:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-05 03:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-05 04:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-05 05:00:00 =========================
# ========================= 2019-12-05 06:00:00 =========================
# ========================= 2019-12-05 07:00:00 =========================
# ========================= 2019-12-05 08:00:00 =========================
# ========================= 2019-12-05 09:00:00 =========================
# ========================= 2019-12-05 10:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-05 11:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-05 12:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-12-05 13:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-05 14:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-12-05 15:00:00 =========================
# ========================= 2019-12-05 16:00:00 =========================
# ========================= 2019-12-05 17:00:00 =========================
# ========================= 2019-12-05 18:00:00 =========================
# ========================= 2019-12-05 19:00:00 =========================
# ========================= 2019-12-05 20:00:00 =========================
# ========================= 2019-12-05 21:00:00 =========================
# ========================= 2019-12-05 22:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-12-05 23:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-06 00:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-06 01:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-06 02:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-06 03:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-06 04:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-06 05:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-12-06 06:00:00 =========================
# ========================= 2019-12-06 07:00:00 =========================
# ========================= 2019-12-06 08:00:00 =========================
# ========================= 2019-12-06 09:00:00 =========================
# ========================= 2019-12-06 10:00:00 =========================
# ========================= 2019-12-06 11:00:00 =========================
# ========================= 2019-12-06 12:00:00 =========================
# ========================= 2019-12-06 13:00:00 =========================
# ========================= 2019-12-06 14:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-06 15:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-06 16:00:00 =========================
# ========================= 2019-12-06 17:00:00 =========================
# ========================= 2019-12-06 18:00:00 =========================
# ========================= 2019-12-06 19:00:00 =========================
# ========================= 2019-12-06 20:00:00 =========================
# ========================= 2019-12-06 21:00:00 =========================
# ========================= 2019-12-06 22:00:00 =========================
# ========================= 2019-12-06 23:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-07 00:00:00 =========================
# ========================= 2019-12-07 01:00:00 =========================
# ========================= 2019-12-07 02:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-07 03:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-07 04:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-07 05:00:00 =========================
# ========================= 2019-12-07 06:00:00 =========================
# ========================= 2019-12-07 07:00:00 =========================
# ========================= 2019-12-07 08:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-07 09:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-07 10:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-07 11:00:00 =========================
# p_grid in solution is higher than execution
# ========================= 2019-12-07 12:00:00 =========================
# ========================= 2019-12-07 13:00:00 =========================
# ========================= 2019-12-07 14:00:00 =========================
# ========================= 2019-12-07 15:00:00 =========================
# ========================= 2019-12-07 16:00:00 =========================
# ========================= 2019-12-07 17:00:00 =========================
# ========================= 2019-12-07 18:00:00 =========================
# ========================= 2019-12-07 19:00:00 =========================
# ========================= 2019-12-07 20:00:00 =========================
# ========================= 2019-12-07 21:00:00 =========================
# ========================= 2019-12-07 22:00:00 =========================
# ========================= 2019-12-07 23:00:00 =========================
# ========================= 2019-12-08 00:00:00 =========================
# ========================= 2019-12-08 01:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-08 02:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-08 03:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-08 04:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-08 05:00:00 =========================
# ========================= 2019-12-08 06:00:00 =========================
# ========================= 2019-12-08 07:00:00 =========================
# ========================= 2019-12-08 08:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-08 09:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-08 10:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-08 11:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-08 12:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-08 13:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-08 14:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-08 15:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= 2019-12-08 16:00:00 =========================
# ========================= 2019-12-08 17:00:00 =========================
# ========================= 2019-12-08 18:00:00 =========================
# ========================= 2019-12-08 19:00:00 =========================
# ========================= 2019-12-08 20:00:00 =========================
# ========================= 2019-12-08 21:00:00 =========================
# ========================= 2019-12-08 22:00:00 =========================
# ========================= 2019-12-08 23:00:00 =========================
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# p_grid in solution is higher than execution
# ========================= FINISH =========================
# Done, trial 343
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
# ====================
# DONE
