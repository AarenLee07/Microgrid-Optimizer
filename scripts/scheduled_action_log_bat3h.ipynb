# %%
import os
import sys
src_path = sys.path[0].replace("scripts", "src")
#replace notebook as scripts
data_path = sys.path[0].replace("scripts", "data")
if src_path not in sys.path:
    sys.path.append(src_path)

out_path = sys.path[0].replace("scripts", "output")

import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import time
import copy

from grid_manager import MPC_op
from data_loader import UCSD_dataloader
from battery_model import Battery_base
from optimizer import Battery_optimizer
from predictor import *
from exp_manager import ExperimentManager

# from ev_manager import EVmanager
# import copy

# %% [markdown]
# # exp based on XGBoost prediction added bat 3h

# %%
exp_suffix = "July2023_2"
exp_folder = os.path.join(out_path, "experiments", exp_suffix)
debug_folder = os.path.join(out_path, "debug_test")
assert os.path.exists(exp_folder)

# %%
bat_params_sample ={
    "bat_capacity": None,
    "bat_p_max": 3, # i.e., capacity (kWh) / p_bat_max (kW) = 3 (h)
    "bat_p_min": 3, # can omit, then p_bat_min = p_bat_max
    "bat_price": 150, # $/kWh (old: 1000, ref: Tesla Powerwall)
    "bat_efficacy": 0.98, 
    "bat_life_0": 3650, # days.
    "bat_cycle_0": 3000, # cycles in lifetime
    # battery degradation params
    "deg_model": "throughput",  
        # valid values: "throughput", "Crate", "rainflow", "DOD"
    #   [1. degradation ~ high C-rate]
    "deg_Crate_thres": (0.25, 0.25, 0.25, 0.25),
    "deg_Crate_lambda": (0.8, 1, 1.5, 2),
    #   [2. degradation ~ large cycle depth]
    "deg_rainflow_thres": (0.2, 0.2, 0.2, 0.4),
    "deg_rainflow_lambda": (0.6, 1, 1.5, 1.8),
    #   [3. degradation ~ low SoE range]
    "deg_DOD_thres": (0.5, 0.2, 0.2, 0.1),
    "deg_DOD_lambda": (1.3, 1.15, 0.85, 0.6),
}

op_params_sample = {"K": 96,
            "dc_price": 0.6,
            "ev_efficacy": 0.98,
            "energy_price_sell": 0.6, 
            "deg_model_opt": "unconscious",
            "ev_charge_rule": "flex",
            "ev_charge_rule_default": "unif",
            "p_grid_max": "1.5",}

# %%
class MPC_ExperimentManager(ExperimentManager):
    """
    Main variable: battery size (normalized to hr: to bld_load)
    """
    def run_one_trial(self, params, save_fn):
        
        # params: keys: "pred_model", "strategy", "B_kWh", "deg_model_opt", "deg_model", 
        #   "start", "end", "p_grid_max", "price_dc", "price_sell", "ev_charge_rule"

        op_params = copy.deepcopy(op_params_sample)
        bat_params = copy.deepcopy(bat_params_sample)

        bat_params["deg_model"] = params.get("deg_model", "DOD")
        bat_params["bat_capacity"] = params.get("B_kWh", 350)
        strategy = params.get("strategy", "optimal")
        op_params["deg_model_opt"] = params.get("deg_model_opt", "rainflow") 
        op_params["ev_charge_rule"] = params.get("ev_charge_rule", "flex")
        op_params["energy_price_sell"] = params.get("price_sell", "rainflow")
        op_params["dc_price"] = params.get("price_dc", 0.6) 
        p_grid_max = params.get("p_grid_max", "1.5") 
        op_params["p_grid_max"] = None if p_grid_max is None else str(p_grid_max)
        pred_model = params.get("pred_model", "GT") 
        
        # 2023/05/30 LunLong
        # Trying to add bld pv ev into grid search parmas
        bld=params.get("bld", "Hopkins")
        pv=params.get("pv", "Hopkins")
        ev=params.get("ev","OSLER")   
        
        # 2023/07/21 LunLong
        # Check params sanity with XGBoost prediction added
        #if params.get("pred_model")=='Prediction':
        #    if not params.get("bld")=="Sum" & params.get("pv")=='Sum':
        #        raise Exception("Incompatible pred_model and bld/pv setting.")
         
        if bld is None or pv is None or ev is None:
            raise Exception("Building related params are not prepoperly initiated")

        def convert_time(s):
            idx_hyphen = s.index("-")
            month, day = int(s[:idx_hyphen]), int(s[idx_hyphen+1:])
            return datetime(2019, month, day, 0, 0)
        t_start = convert_time(params.get("start", "10-1"))
        t_end = convert_time(params.get("end", "10-8"))

        mpc = MPC_op()

        # Step 1: load data
        mpc.load_data(loader=UCSD_dataloader, 
            tstart=datetime(2019,1,1,0,0), tend=datetime(2020,1,1,0,0), delta=0.25,
            bld=bld, pv=pv, ev=ev, pv_to_bld=0.5, ev_to_bld=0.25, Pmax=10)

        # Step 2: Load historical data
        mpc.init_historical_data(loader=UCSD_dataloader,
            tstart=datetime(2018,1,1,0,0), tend=datetime(2019,12,31,23,59), delta=0.25,
            bld=bld, pv=pv, ev=ev, pv_to_bld=0.5, ev_to_bld=0.25, Pmax=10)

        # Step 3: specify other operational params
        optimizer_params = {"strategy": strategy, "language":"gurobi"}

        mpc.init_op_params(optimizer=Battery_optimizer, optimizer_params=optimizer_params, delta_0=0.25, **op_params)

        # Step 4: specify battery
        mpc.init_battery(model=Battery_base, params=bat_params, delta_0=0.25)

        # Step 5: initialize predictor
        # [Yi, 2023/03/08] modify predictor def
        mpc.init_predictor(shortcut=pred_model)

        # Step 6: initialize save_config
        mpc.init_save_config(save_fn=save_fn[:-5],  # FIXME: remove ".xlsx"
            folder_path=self.save_path, log_pred_action=True,
            checkpoints="1D", recovery=True, recovery_from=None,
            )

        mpc.run(tstart=t_start, tend=t_end, exe_K=4, save=True)
        
        stats = dict(mpc.summary["All"])
        
        return stats

# %%
log_fn = os.path.join(exp_folder, "LOG-MPC-MSC-3h-bat.xlsx")
save_path = os.path.join(exp_folder, "MPC-demo")
#save_path
log_fn
# Out:
# 'd:\\Codes\\GIthub_repo\\Energy_grid\\output\\experiments\\July2023_2\\LOG-MPC-MSC-3h-bat.xlsx'

# %%
em = MPC_ExperimentManager(log_fn=log_fn, save_path=save_path, save=True, exp_prefix="MPC")
var_keys = [
            "method", "strategy",
            "pred_model", "deg_model_opt", "p_grid_max", 
            "price_dc", "price_sell", 
            "ev_charge_rule", 
            "B_kWh",  "deg_model", 
            "start", "end", 
            "bld", "ev", "pv"]
em.run(keys=var_keys, num_trials=120)
# Out:
# !!!!!!!!!! EV SHORT DURATION !!!!!!!!!! || drop 119 sessions
# !!!!!!!!!! EV SHORT DURATION !!!!!!!!!! || drop 237 sessions
# ========================= 2019-08-01 00:00:00 =========================
# ========================= 2019-08-01 01:00:00 =========================
# ========================= 2019-08-01 02:00:00 =========================
# ========================= 2019-08-01 03:00:00 =========================
# ========================= 2019-08-01 04:00:00 =========================
# ========================= 2019-08-01 05:00:00 =========================
# ========================= 2019-08-01 06:00:00 =========================
# ========================= 2019-08-01 07:00:00 =========================
# ========================= 2019-08-01 08:00:00 =========================
# ========================= 2019-08-01 09:00:00 =========================
# ========================= 2019-08-01 10:00:00 =========================
# ========================= 2019-08-01 11:00:00 =========================
# ========================= 2019-08-01 12:00:00 =========================
# ========================= 2019-08-01 13:00:00 =========================
# ========================= 2019-08-01 14:00:00 =========================
# ========================= 2019-08-01 15:00:00 =========================
# ========================= 2019-08-01 16:00:00 =========================
# ========================= 2019-08-01 17:00:00 =========================
# ========================= 2019-08-01 18:00:00 =========================
# ========================= 2019-08-01 19:00:00 =========================
# ========================= 2019-08-01 20:00:00 =========================
# ========================= 2019-08-01 21:00:00 =========================
# ========================= 2019-08-01 22:00:00 =========================
# ========================= 2019-08-01 23:00:00 =========================
# ========================= 2019-08-02 00:00:00 =========================
# ========================= 2019-08-02 01:00:00 =========================
# ========================= 2019-08-02 02:00:00 =========================
# ========================= 2019-08-02 03:00:00 =========================
# ========================= 2019-08-02 04:00:00 =========================
# ========================= 2019-08-02 05:00:00 =========================
# ========================= 2019-08-02 06:00:00 =========================
# ========================= 2019-08-02 07:00:00 =========================
# ========================= 2019-08-02 08:00:00 =========================
# ========================= 2019-08-02 09:00:00 =========================
# ========================= 2019-08-02 10:00:00 =========================
# ========================= 2019-08-02 11:00:00 =========================
# ========================= 2019-08-02 12:00:00 =========================
# ========================= 2019-08-02 13:00:00 =========================
# ========================= 2019-08-02 14:00:00 =========================
# ========================= 2019-08-02 15:00:00 =========================
# ========================= 2019-08-02 16:00:00 =========================
# ========================= 2019-08-02 17:00:00 =========================
# ========================= 2019-08-02 18:00:00 =========================
# ========================= 2019-08-02 19:00:00 =========================
# ========================= 2019-08-02 20:00:00 =========================
# ========================= 2019-08-02 21:00:00 =========================
# ========================= 2019-08-02 22:00:00 =========================
# ========================= 2019-08-02 23:00:00 =========================
# ========================= 2019-08-03 00:00:00 =========================
# ========================= 2019-08-03 01:00:00 =========================
# ========================= 2019-08-03 02:00:00 =========================
# ========================= 2019-08-03 03:00:00 =========================
# ========================= 2019-08-03 04:00:00 =========================
# ========================= 2019-08-03 05:00:00 =========================
# ========================= 2019-08-03 06:00:00 =========================
# ========================= 2019-08-03 07:00:00 =========================
# ========================= 2019-08-03 08:00:00 =========================
# ========================= 2019-08-03 09:00:00 =========================
# ========================= 2019-08-03 10:00:00 =========================
# ========================= 2019-08-03 11:00:00 =========================
# ========================= 2019-08-03 12:00:00 =========================
# ========================= 2019-08-03 13:00:00 =========================
# ========================= 2019-08-03 14:00:00 =========================
# ========================= 2019-08-03 15:00:00 =========================
# ========================= 2019-08-03 16:00:00 =========================
# ========================= 2019-08-03 17:00:00 =========================
# ========================= 2019-08-03 18:00:00 =========================
# ========================= 2019-08-03 19:00:00 =========================
# ========================= 2019-08-03 20:00:00 =========================
# ========================= 2019-08-03 21:00:00 =========================
# ========================= 2019-08-03 22:00:00 =========================
# ========================= 2019-08-03 23:00:00 =========================
# ========================= 2019-08-04 00:00:00 =========================
# ========================= 2019-08-04 01:00:00 =========================
# ========================= 2019-08-04 02:00:00 =========================
# ========================= 2019-08-04 03:00:00 =========================
# ========================= 2019-08-04 04:00:00 =========================
# ========================= 2019-08-04 05:00:00 =========================
# ========================= 2019-08-04 06:00:00 =========================
# ========================= 2019-08-04 07:00:00 =========================
# ========================= 2019-08-04 08:00:00 =========================
# ========================= 2019-08-04 09:00:00 =========================
# ========================= 2019-08-04 10:00:00 =========================
# ========================= 2019-08-04 11:00:00 =========================
# ========================= 2019-08-04 12:00:00 =========================
# ========================= 2019-08-04 13:00:00 =========================
# ========================= 2019-08-04 14:00:00 =========================
# ========================= 2019-08-04 15:00:00 =========================
# ========================= 2019-08-04 16:00:00 =========================
# ========================= 2019-08-04 17:00:00 =========================
# ========================= 2019-08-04 18:00:00 =========================
# ========================= 2019-08-04 19:00:00 =========================
# ========================= 2019-08-04 20:00:00 =========================
# ========================= 2019-08-04 21:00:00 =========================
# ========================= 2019-08-04 22:00:00 =========================
# ========================= 2019-08-04 23:00:00 =========================
# ========================= 2019-08-05 00:00:00 =========================
# ========================= 2019-08-05 01:00:00 =========================
# ========================= 2019-08-05 02:00:00 =========================
# ========================= 2019-08-05 03:00:00 =========================
# ========================= 2019-08-05 04:00:00 =========================
# ========================= 2019-08-05 05:00:00 =========================
# ========================= 2019-08-05 06:00:00 =========================
# ========================= 2019-08-05 07:00:00 =========================
# ========================= 2019-08-05 08:00:00 =========================
# ========================= 2019-08-05 09:00:00 =========================
# ========================= 2019-08-05 10:00:00 =========================
# ========================= 2019-08-05 11:00:00 =========================
# ========================= 2019-08-05 12:00:00 =========================
# ========================= 2019-08-05 13:00:00 =========================
# ========================= 2019-08-05 14:00:00 =========================
# ========================= 2019-08-05 15:00:00 =========================
# ========================= 2019-08-05 16:00:00 =========================
# ========================= 2019-08-05 17:00:00 =========================
# ========================= 2019-08-05 18:00:00 =========================
# ========================= 2019-08-05 19:00:00 =========================
# ========================= 2019-08-05 20:00:00 =========================
# ========================= 2019-08-05 21:00:00 =========================
# ========================= 2019-08-05 22:00:00 =========================
# ========================= 2019-08-05 23:00:00 =========================
# ========================= 2019-08-06 00:00:00 =========================
# ========================= 2019-08-06 01:00:00 =========================
# ========================= 2019-08-06 02:00:00 =========================
# ========================= 2019-08-06 03:00:00 =========================
# ========================= 2019-08-06 04:00:00 =========================
# ========================= 2019-08-06 05:00:00 =========================
# ========================= 2019-08-06 06:00:00 =========================
# ========================= 2019-08-06 07:00:00 =========================
# ========================= 2019-08-06 08:00:00 =========================
# ========================= 2019-08-06 09:00:00 =========================
# ========================= 2019-08-06 10:00:00 =========================
# ========================= 2019-08-06 11:00:00 =========================
# ========================= 2019-08-06 12:00:00 =========================
# ========================= 2019-08-06 13:00:00 =========================
# ========================= 2019-08-06 14:00:00 =========================
# ========================= 2019-08-06 15:00:00 =========================
# ========================= 2019-08-06 16:00:00 =========================
# ========================= 2019-08-06 17:00:00 =========================
# ========================= 2019-08-06 18:00:00 =========================
# ========================= 2019-08-06 19:00:00 =========================
# ========================= 2019-08-06 20:00:00 =========================
# ========================= 2019-08-06 21:00:00 =========================
# ========================= 2019-08-06 22:00:00 =========================
# ========================= 2019-08-06 23:00:00 =========================
# ========================= 2019-08-07 00:00:00 =========================
# ========================= 2019-08-07 01:00:00 =========================
# ========================= 2019-08-07 02:00:00 =========================
# ========================= 2019-08-07 03:00:00 =========================
# ========================= 2019-08-07 04:00:00 =========================
# ========================= 2019-08-07 05:00:00 =========================
# ========================= 2019-08-07 06:00:00 =========================
# ========================= 2019-08-07 07:00:00 =========================
# ========================= 2019-08-07 08:00:00 =========================
# ========================= 2019-08-07 09:00:00 =========================
# ========================= 2019-08-07 10:00:00 =========================
# ========================= 2019-08-07 11:00:00 =========================
# ========================= 2019-08-07 12:00:00 =========================
# ========================= 2019-08-07 13:00:00 =========================
# ========================= 2019-08-07 14:00:00 =========================
# ========================= 2019-08-07 15:00:00 =========================
# ========================= 2019-08-07 16:00:00 =========================
# ========================= 2019-08-07 17:00:00 =========================
# ========================= 2019-08-07 18:00:00 =========================
# ========================= 2019-08-07 19:00:00 =========================
# ========================= 2019-08-07 20:00:00 =========================
# ========================= 2019-08-07 21:00:00 =========================
# ========================= 2019-08-07 22:00:00 =========================
# ========================= 2019-08-07 23:00:00 =========================
# ========================= FINISH =========================
# Done, trial 30
# !!!!!!!!!! EV SHORT DURATION !!!!!!!!!! || drop 119 sessions
# !!!!!!!!!! EV SHORT DURATION !!!!!!!!!! || drop 237 sessions
# ========================= 2019-08-01 00:00:00 =========================
# ========================= 2019-08-01 01:00:00 =========================
# ========================= 2019-08-01 02:00:00 =========================
# ========================= 2019-08-01 03:00:00 =========================
# ========================= 2019-08-01 04:00:00 =========================
# ========================= 2019-08-01 05:00:00 =========================
# ========================= 2019-08-01 06:00:00 =========================
# ========================= 2019-08-01 07:00:00 =========================
# ========================= 2019-08-01 08:00:00 =========================
# ========================= 2019-08-01 09:00:00 =========================
# ========================= 2019-08-01 10:00:00 =========================
# ========================= 2019-08-01 11:00:00 =========================
# ========================= 2019-08-01 12:00:00 =========================
# ========================= 2019-08-01 13:00:00 =========================
# ========================= 2019-08-01 14:00:00 =========================
# ========================= 2019-08-01 15:00:00 =========================
# ========================= 2019-08-01 16:00:00 =========================
# ========================= 2019-08-01 17:00:00 =========================
# ========================= 2019-08-01 18:00:00 =========================
# ========================= 2019-08-01 19:00:00 =========================
# ========================= 2019-08-01 20:00:00 =========================
# ========================= 2019-08-01 21:00:00 =========================
# ========================= 2019-08-01 22:00:00 =========================
# ========================= 2019-08-01 23:00:00 =========================
# ========================= 2019-08-02 00:00:00 =========================
# ========================= 2019-08-02 01:00:00 =========================
# ========================= 2019-08-02 02:00:00 =========================
# ========================= 2019-08-02 03:00:00 =========================
# ========================= 2019-08-02 04:00:00 =========================
# ========================= 2019-08-02 05:00:00 =========================
# ========================= 2019-08-02 06:00:00 =========================
# ========================= 2019-08-02 07:00:00 =========================
# ========================= 2019-08-02 08:00:00 =========================
# ========================= 2019-08-02 09:00:00 =========================
# ========================= 2019-08-02 10:00:00 =========================
# ========================= 2019-08-02 11:00:00 =========================
# ========================= 2019-08-02 12:00:00 =========================
# ========================= 2019-08-02 13:00:00 =========================
# ========================= 2019-08-02 14:00:00 =========================
# ========================= 2019-08-02 15:00:00 =========================
# ========================= 2019-08-02 16:00:00 =========================
# ========================= 2019-08-02 17:00:00 =========================
# ========================= 2019-08-02 18:00:00 =========================
# ========================= 2019-08-02 19:00:00 =========================
# ========================= 2019-08-02 20:00:00 =========================
# ========================= 2019-08-02 21:00:00 =========================
# ========================= 2019-08-02 22:00:00 =========================
# ========================= 2019-08-02 23:00:00 =========================
# ========================= 2019-08-03 00:00:00 =========================
# ========================= 2019-08-03 01:00:00 =========================
# ========================= 2019-08-03 02:00:00 =========================
# ========================= 2019-08-03 03:00:00 =========================
# ========================= 2019-08-03 04:00:00 =========================
# ========================= 2019-08-03 05:00:00 =========================
# ========================= 2019-08-03 06:00:00 =========================
# ========================= 2019-08-03 07:00:00 =========================
# ========================= 2019-08-03 08:00:00 =========================
# ========================= 2019-08-03 09:00:00 =========================
# ========================= 2019-08-03 10:00:00 =========================
# ========================= 2019-08-03 11:00:00 =========================
# ========================= 2019-08-03 12:00:00 =========================
# ========================= 2019-08-03 13:00:00 =========================
# ========================= 2019-08-03 14:00:00 =========================
# ========================= 2019-08-03 15:00:00 =========================
# ========================= 2019-08-03 16:00:00 =========================
# ========================= 2019-08-03 17:00:00 =========================
# ========================= 2019-08-03 18:00:00 =========================
# ========================= 2019-08-03 19:00:00 =========================
# ========================= 2019-08-03 20:00:00 =========================
# ========================= 2019-08-03 21:00:00 =========================
# ========================= 2019-08-03 22:00:00 =========================
# ========================= 2019-08-03 23:00:00 =========================
# ========================= 2019-08-04 00:00:00 =========================
# ========================= 2019-08-04 01:00:00 =========================
# ========================= 2019-08-04 02:00:00 =========================
# ========================= 2019-08-04 03:00:00 =========================
# ========================= 2019-08-04 04:00:00 =========================
# ========================= 2019-08-04 05:00:00 =========================
# ========================= 2019-08-04 06:00:00 =========================
# ========================= 2019-08-04 07:00:00 =========================
# ========================= 2019-08-04 08:00:00 =========================
# ========================= 2019-08-04 09:00:00 =========================
# ========================= 2019-08-04 10:00:00 =========================
# ========================= 2019-08-04 11:00:00 =========================
# ========================= 2019-08-04 12:00:00 =========================
# ========================= 2019-08-04 13:00:00 =========================
# ========================= 2019-08-04 14:00:00 =========================
# ========================= 2019-08-04 15:00:00 =========================
# ========================= 2019-08-04 16:00:00 =========================
# ========================= 2019-08-04 17:00:00 =========================
# ========================= 2019-08-04 18:00:00 =========================
# ========================= 2019-08-04 19:00:00 =========================
# ========================= 2019-08-04 20:00:00 =========================
# ========================= 2019-08-04 21:00:00 =========================
# ========================= 2019-08-04 22:00:00 =========================
# ========================= 2019-08-04 23:00:00 =========================
# ========================= 2019-08-05 00:00:00 =========================
# ========================= 2019-08-05 01:00:00 =========================
# ========================= 2019-08-05 02:00:00 =========================
# ========================= 2019-08-05 03:00:00 =========================
# ========================= 2019-08-05 04:00:00 =========================
# ========================= 2019-08-05 05:00:00 =========================
# ========================= 2019-08-05 06:00:00 =========================
# ========================= 2019-08-05 07:00:00 =========================
# ========================= 2019-08-05 08:00:00 =========================
# ========================= 2019-08-05 09:00:00 =========================
# ========================= 2019-08-05 10:00:00 =========================
# ========================= 2019-08-05 11:00:00 =========================
# ========================= 2019-08-05 12:00:00 =========================
# ========================= 2019-08-05 13:00:00 =========================
# ========================= 2019-08-05 14:00:00 =========================
# ========================= 2019-08-05 15:00:00 =========================
# ========================= 2019-08-05 16:00:00 =========================
# ========================= 2019-08-05 17:00:00 =========================
# ========================= 2019-08-05 18:00:00 =========================
# ========================= 2019-08-05 19:00:00 =========================
# ========================= 2019-08-05 20:00:00 =========================
# ========================= 2019-08-05 21:00:00 =========================
# ========================= 2019-08-05 22:00:00 =========================
# ========================= 2019-08-05 23:00:00 =========================
# ========================= 2019-08-06 00:00:00 =========================
# ========================= 2019-08-06 01:00:00 =========================
# ========================= 2019-08-06 02:00:00 =========================
# ========================= 2019-08-06 03:00:00 =========================
# ========================= 2019-08-06 04:00:00 =========================
# ========================= 2019-08-06 05:00:00 =========================
# ========================= 2019-08-06 06:00:00 =========================
# ========================= 2019-08-06 07:00:00 =========================
# ========================= 2019-08-06 08:00:00 =========================
# ========================= 2019-08-06 09:00:00 =========================
# ========================= 2019-08-06 10:00:00 =========================
# ========================= 2019-08-06 11:00:00 =========================
# ========================= 2019-08-06 12:00:00 =========================
# ========================= 2019-08-06 13:00:00 =========================
# ========================= 2019-08-06 14:00:00 =========================
# ========================= 2019-08-06 15:00:00 =========================
# ========================= 2019-08-06 16:00:00 =========================
# ========================= 2019-08-06 17:00:00 =========================
# ========================= 2019-08-06 18:00:00 =========================
# ========================= 2019-08-06 19:00:00 =========================
# ========================= 2019-08-06 20:00:00 =========================
# ========================= 2019-08-06 21:00:00 =========================
# ========================= 2019-08-06 22:00:00 =========================
# ========================= 2019-08-06 23:00:00 =========================
# ========================= 2019-08-07 00:00:00 =========================
# ========================= 2019-08-07 01:00:00 =========================
# ========================= 2019-08-07 02:00:00 =========================
# ========================= 2019-08-07 03:00:00 =========================
# ========================= 2019-08-07 04:00:00 =========================
# ========================= 2019-08-07 05:00:00 =========================
# ========================= 2019-08-07 06:00:00 =========================
# ========================= 2019-08-07 07:00:00 =========================
# ========================= 2019-08-07 08:00:00 =========================
# ========================= 2019-08-07 09:00:00 =========================
# ========================= 2019-08-07 10:00:00 =========================
# ========================= 2019-08-07 11:00:00 =========================
# ========================= 2019-08-07 12:00:00 =========================
# ========================= 2019-08-07 13:00:00 =========================
# ========================= 2019-08-07 14:00:00 =========================
# ========================= 2019-08-07 15:00:00 =========================
# ========================= 2019-08-07 16:00:00 =========================
# ========================= 2019-08-07 17:00:00 =========================
# ========================= 2019-08-07 18:00:00 =========================
# ========================= 2019-08-07 19:00:00 =========================
# ========================= 2019-08-07 20:00:00 =========================
# ========================= 2019-08-07 21:00:00 =========================
# ========================= 2019-08-07 22:00:00 =========================
# ========================= 2019-08-07 23:00:00 =========================
# ========================= FINISH =========================
# Done, trial 31
# !!!!!!!!!! EV SHORT DURATION !!!!!!!!!! || drop 119 sessions
# !!!!!!!!!! EV SHORT DURATION !!!!!!!!!! || drop 237 sessions
# ========================= 2019-09-01 00:00:00 =========================
# ========================= 2019-09-01 01:00:00 =========================
# ========================= 2019-09-01 02:00:00 =========================
# ========================= 2019-09-01 03:00:00 =========================
# ========================= 2019-09-01 04:00:00 =========================
# ========================= 2019-09-01 05:00:00 =========================
# ========================= 2019-09-01 06:00:00 =========================
# ========================= 2019-09-01 07:00:00 =========================
# ========================= 2019-09-01 08:00:00 =========================
# ========================= 2019-09-01 09:00:00 =========================
# ========================= 2019-09-01 10:00:00 =========================
# ========================= 2019-09-01 11:00:00 =========================
# ========================= 2019-09-01 12:00:00 =========================
# ========================= 2019-09-01 13:00:00 =========================
# ========================= 2019-09-01 14:00:00 =========================
# ========================= 2019-09-01 15:00:00 =========================
# ========================= 2019-09-01 16:00:00 =========================
# ========================= 2019-09-01 17:00:00 =========================
# ========================= 2019-09-01 18:00:00 =========================
# ========================= 2019-09-01 19:00:00 =========================
# ========================= 2019-09-01 20:00:00 =========================
# ========================= 2019-09-01 21:00:00 =========================
# ========================= 2019-09-01 22:00:00 =========================
# ========================= 2019-09-01 23:00:00 =========================
# ========================= 2019-09-02 00:00:00 =========================
# ========================= 2019-09-02 01:00:00 =========================
# ========================= 2019-09-02 02:00:00 =========================
# ========================= 2019-09-02 03:00:00 =========================
# ========================= 2019-09-02 04:00:00 =========================
# ========================= 2019-09-02 05:00:00 =========================
# ========================= 2019-09-02 06:00:00 =========================
# ========================= 2019-09-02 07:00:00 =========================
# ========================= 2019-09-02 08:00:00 =========================
# ========================= 2019-09-02 09:00:00 =========================
# ========================= 2019-09-02 10:00:00 =========================
# ========================= 2019-09-02 11:00:00 =========================
# ========================= 2019-09-02 12:00:00 =========================
# ========================= 2019-09-02 13:00:00 =========================
# ========================= 2019-09-02 14:00:00 =========================
# ========================= 2019-09-02 15:00:00 =========================
# ========================= 2019-09-02 16:00:00 =========================
# ========================= 2019-09-02 17:00:00 =========================
# ========================= 2019-09-02 18:00:00 =========================
# ========================= 2019-09-02 19:00:00 =========================
# ========================= 2019-09-02 20:00:00 =========================
# ========================= 2019-09-02 21:00:00 =========================
# ========================= 2019-09-02 22:00:00 =========================
# ========================= 2019-09-02 23:00:00 =========================
# ========================= 2019-09-03 00:00:00 =========================
# ========================= 2019-09-03 01:00:00 =========================
# ========================= 2019-09-03 02:00:00 =========================
# ========================= 2019-09-03 03:00:00 =========================
# ========================= 2019-09-03 04:00:00 =========================
# ========================= 2019-09-03 05:00:00 =========================
# ========================= 2019-09-03 06:00:00 =========================
# ========================= 2019-09-03 07:00:00 =========================
# ========================= 2019-09-03 08:00:00 =========================
# ========================= 2019-09-03 09:00:00 =========================
# ========================= 2019-09-03 10:00:00 =========================
# ========================= 2019-09-03 11:00:00 =========================
# ========================= 2019-09-03 12:00:00 =========================
# ========================= 2019-09-03 13:00:00 =========================
# ========================= 2019-09-03 14:00:00 =========================
# ========================= 2019-09-03 15:00:00 =========================
# ========================= 2019-09-03 16:00:00 =========================
# ========================= 2019-09-03 17:00:00 =========================
# ========================= 2019-09-03 18:00:00 =========================
# ========================= 2019-09-03 19:00:00 =========================
# ========================= 2019-09-03 20:00:00 =========================
# ========================= 2019-09-03 21:00:00 =========================
# ========================= 2019-09-03 22:00:00 =========================
# ========================= 2019-09-03 23:00:00 =========================
# ========================= 2019-09-04 00:00:00 =========================
# ========================= 2019-09-04 01:00:00 =========================
# ========================= 2019-09-04 02:00:00 =========================
# ========================= 2019-09-04 03:00:00 =========================
# ========================= 2019-09-04 04:00:00 =========================
# ========================= 2019-09-04 05:00:00 =========================
# ========================= 2019-09-04 06:00:00 =========================
# ========================= 2019-09-04 07:00:00 =========================
# ========================= 2019-09-04 08:00:00 =========================
# ========================= 2019-09-04 09:00:00 =========================
# ========================= 2019-09-04 10:00:00 =========================
# ========================= 2019-09-04 11:00:00 =========================
# ========================= 2019-09-04 12:00:00 =========================
# ========================= 2019-09-04 13:00:00 =========================
# ========================= 2019-09-04 14:00:00 =========================
# ========================= 2019-09-04 15:00:00 =========================
# ========================= 2019-09-04 16:00:00 =========================
# ========================= 2019-09-04 17:00:00 =========================
# ========================= 2019-09-04 18:00:00 =========================
# ========================= 2019-09-04 19:00:00 =========================
# ========================= 2019-09-04 20:00:00 =========================
# ========================= 2019-09-04 21:00:00 =========================
# ========================= 2019-09-04 22:00:00 =========================
# ========================= 2019-09-04 23:00:00 =========================
# ========================= 2019-09-05 00:00:00 =========================
# ========================= 2019-09-05 01:00:00 =========================
# ========================= 2019-09-05 02:00:00 =========================
# ========================= 2019-09-05 03:00:00 =========================
# ========================= 2019-09-05 04:00:00 =========================
# ========================= 2019-09-05 05:00:00 =========================
# ========================= 2019-09-05 06:00:00 =========================
# ========================= 2019-09-05 07:00:00 =========================
# ========================= 2019-09-05 08:00:00 =========================
# ========================= 2019-09-05 09:00:00 =========================
# ========================= 2019-09-05 10:00:00 =========================
# ========================= 2019-09-05 11:00:00 =========================
# ========================= 2019-09-05 12:00:00 =========================
# ========================= 2019-09-05 13:00:00 =========================
# ========================= 2019-09-05 14:00:00 =========================
# ========================= 2019-09-05 15:00:00 =========================
# ========================= 2019-09-05 16:00:00 =========================
# ========================= 2019-09-05 17:00:00 =========================
# ========================= 2019-09-05 18:00:00 =========================
# ========================= 2019-09-05 19:00:00 =========================
# ========================= 2019-09-05 20:00:00 =========================
# ========================= 2019-09-05 21:00:00 =========================
# ========================= 2019-09-05 22:00:00 =========================
# ========================= 2019-09-05 23:00:00 =========================
# ========================= 2019-09-06 00:00:00 =========================
# ========================= 2019-09-06 01:00:00 =========================
# ========================= 2019-09-06 02:00:00 =========================
# ========================= 2019-09-06 03:00:00 =========================
# ========================= 2019-09-06 04:00:00 =========================
# ========================= 2019-09-06 05:00:00 =========================
# ========================= 2019-09-06 06:00:00 =========================
# ========================= 2019-09-06 07:00:00 =========================
# ========================= 2019-09-06 08:00:00 =========================
# ========================= 2019-09-06 09:00:00 =========================
# ========================= 2019-09-06 10:00:00 =========================
# ========================= 2019-09-06 11:00:00 =========================
# ========================= 2019-09-06 12:00:00 =========================
# ========================= 2019-09-06 13:00:00 =========================
# ========================= 2019-09-06 14:00:00 =========================
# ========================= 2019-09-06 15:00:00 =========================
# ========================= 2019-09-06 16:00:00 =========================
# ========================= 2019-09-06 17:00:00 =========================
# ========================= 2019-09-06 18:00:00 =========================
# ========================= 2019-09-06 19:00:00 =========================
# ========================= 2019-09-06 20:00:00 =========================
# ========================= 2019-09-06 21:00:00 =========================
# ========================= 2019-09-06 22:00:00 =========================
# ========================= 2019-09-06 23:00:00 =========================
# ========================= 2019-09-07 00:00:00 =========================
# ========================= 2019-09-07 01:00:00 =========================
# ========================= 2019-09-07 02:00:00 =========================
# ========================= 2019-09-07 03:00:00 =========================
# ========================= 2019-09-07 04:00:00 =========================
# ========================= 2019-09-07 05:00:00 =========================
# ========================= 2019-09-07 06:00:00 =========================
# ========================= 2019-09-07 07:00:00 =========================
# ========================= 2019-09-07 08:00:00 =========================
# ========================= 2019-09-07 09:00:00 =========================
# ========================= 2019-09-07 10:00:00 =========================
# ========================= 2019-09-07 11:00:00 =========================
# ========================= 2019-09-07 12:00:00 =========================
# ========================= 2019-09-07 13:00:00 =========================
# ========================= 2019-09-07 14:00:00 =========================
# ========================= 2019-09-07 15:00:00 =========================
# ========================= 2019-09-07 16:00:00 =========================
# ========================= 2019-09-07 17:00:00 =========================
# ========================= 2019-09-07 18:00:00 =========================
# ========================= 2019-09-07 19:00:00 =========================
# ========================= 2019-09-07 20:00:00 =========================
# ========================= 2019-09-07 21:00:00 =========================
# ========================= 2019-09-07 22:00:00 =========================
# ========================= 2019-09-07 23:00:00 =========================
# ========================= FINISH =========================
# Done, trial 34
# !!!!!!!!!! EV SHORT DURATION !!!!!!!!!! || drop 119 sessions
# !!!!!!!!!! EV SHORT DURATION !!!!!!!!!! || drop 237 sessions
# ========================= 2019-09-01 00:00:00 =========================
# ========================= 2019-09-01 01:00:00 =========================
# ========================= 2019-09-01 02:00:00 =========================
# ========================= 2019-09-01 03:00:00 =========================
# ========================= 2019-09-01 04:00:00 =========================
# ========================= 2019-09-01 05:00:00 =========================
# ========================= 2019-09-01 06:00:00 =========================
# ========================= 2019-09-01 07:00:00 =========================
# ========================= 2019-09-01 08:00:00 =========================
# ========================= 2019-09-01 09:00:00 =========================
# ========================= 2019-09-01 10:00:00 =========================
# ========================= 2019-09-01 11:00:00 =========================
# ========================= 2019-09-01 12:00:00 =========================
# ========================= 2019-09-01 13:00:00 =========================
# ========================= 2019-09-01 14:00:00 =========================
# ========================= 2019-09-01 15:00:00 =========================
# ========================= 2019-09-01 16:00:00 =========================
# ========================= 2019-09-01 17:00:00 =========================
# ========================= 2019-09-01 18:00:00 =========================
# ========================= 2019-09-01 19:00:00 =========================
# ========================= 2019-09-01 20:00:00 =========================
# ========================= 2019-09-01 21:00:00 =========================
# ========================= 2019-09-01 22:00:00 =========================
# ========================= 2019-09-01 23:00:00 =========================
# ========================= 2019-09-02 00:00:00 =========================
# ========================= 2019-09-02 01:00:00 =========================
# ========================= 2019-09-02 02:00:00 =========================
# ========================= 2019-09-02 03:00:00 =========================
# ========================= 2019-09-02 04:00:00 =========================
# ========================= 2019-09-02 05:00:00 =========================
# ========================= 2019-09-02 06:00:00 =========================
# ========================= 2019-09-02 07:00:00 =========================
# ========================= 2019-09-02 08:00:00 =========================
# ========================= 2019-09-02 09:00:00 =========================
# ========================= 2019-09-02 10:00:00 =========================
# ========================= 2019-09-02 11:00:00 =========================
# ========================= 2019-09-02 12:00:00 =========================
# ========================= 2019-09-02 13:00:00 =========================
# ========================= 2019-09-02 14:00:00 =========================
# ========================= 2019-09-02 15:00:00 =========================
# ========================= 2019-09-02 16:00:00 =========================
# ========================= 2019-09-02 17:00:00 =========================
# ========================= 2019-09-02 18:00:00 =========================
# ========================= 2019-09-02 19:00:00 =========================
# ========================= 2019-09-02 20:00:00 =========================
# ========================= 2019-09-02 21:00:00 =========================
# ========================= 2019-09-02 22:00:00 =========================
# ========================= 2019-09-02 23:00:00 =========================
# ========================= 2019-09-03 00:00:00 =========================
# ========================= 2019-09-03 01:00:00 =========================
# ========================= 2019-09-03 02:00:00 =========================
# ========================= 2019-09-03 03:00:00 =========================
# ========================= 2019-09-03 04:00:00 =========================
# ========================= 2019-09-03 05:00:00 =========================
# ========================= 2019-09-03 06:00:00 =========================
# ========================= 2019-09-03 07:00:00 =========================
# ========================= 2019-09-03 08:00:00 =========================
# ========================= 2019-09-03 09:00:00 =========================
# ========================= 2019-09-03 10:00:00 =========================
# ========================= 2019-09-03 11:00:00 =========================
# ========================= 2019-09-03 12:00:00 =========================
# ========================= 2019-09-03 13:00:00 =========================
# ========================= 2019-09-03 14:00:00 =========================
# ========================= 2019-09-03 15:00:00 =========================
# ========================= 2019-09-03 16:00:00 =========================
# ========================= 2019-09-03 17:00:00 =========================
# ========================= 2019-09-03 18:00:00 =========================
# ========================= 2019-09-03 19:00:00 =========================
# ========================= 2019-09-03 20:00:00 =========================
# ========================= 2019-09-03 21:00:00 =========================
# ========================= 2019-09-03 22:00:00 =========================
# ========================= 2019-09-03 23:00:00 =========================
# ========================= 2019-09-04 00:00:00 =========================
# ========================= 2019-09-04 01:00:00 =========================
# ========================= 2019-09-04 02:00:00 =========================
# ========================= 2019-09-04 03:00:00 =========================
# ========================= 2019-09-04 04:00:00 =========================
# ========================= 2019-09-04 05:00:00 =========================
# ========================= 2019-09-04 06:00:00 =========================
# ========================= 2019-09-04 07:00:00 =========================
# ========================= 2019-09-04 08:00:00 =========================
# ========================= 2019-09-04 09:00:00 =========================
# ========================= 2019-09-04 10:00:00 =========================
# ========================= 2019-09-04 11:00:00 =========================
# ========================= 2019-09-04 12:00:00 =========================
# ========================= 2019-09-04 13:00:00 =========================
# ========================= 2019-09-04 14:00:00 =========================
# ========================= 2019-09-04 15:00:00 =========================
# ========================= 2019-09-04 16:00:00 =========================
# ========================= 2019-09-04 17:00:00 =========================
# ========================= 2019-09-04 18:00:00 =========================
# ========================= 2019-09-04 19:00:00 =========================
# ========================= 2019-09-04 20:00:00 =========================
# ========================= 2019-09-04 21:00:00 =========================
# ========================= 2019-09-04 22:00:00 =========================
# ========================= 2019-09-04 23:00:00 =========================
# ========================= 2019-09-05 00:00:00 =========================
# ========================= 2019-09-05 01:00:00 =========================
# ========================= 2019-09-05 02:00:00 =========================
# ========================= 2019-09-05 03:00:00 =========================
# ========================= 2019-09-05 04:00:00 =========================
# ========================= 2019-09-05 05:00:00 =========================
# ========================= 2019-09-05 06:00:00 =========================
# ========================= 2019-09-05 07:00:00 =========================
# ========================= 2019-09-05 08:00:00 =========================
# ========================= 2019-09-05 09:00:00 =========================
# ========================= 2019-09-05 10:00:00 =========================
# ========================= 2019-09-05 11:00:00 =========================
# ========================= 2019-09-05 12:00:00 =========================
# ========================= 2019-09-05 13:00:00 =========================
# ========================= 2019-09-05 14:00:00 =========================
# ========================= 2019-09-05 15:00:00 =========================
# ========================= 2019-09-05 16:00:00 =========================
# ========================= 2019-09-05 17:00:00 =========================
# ========================= 2019-09-05 18:00:00 =========================
# ========================= 2019-09-05 19:00:00 =========================
# ========================= 2019-09-05 20:00:00 =========================
# ========================= 2019-09-05 21:00:00 =========================
# ========================= 2019-09-05 22:00:00 =========================
# ========================= 2019-09-05 23:00:00 =========================
# ========================= 2019-09-06 00:00:00 =========================
# ========================= 2019-09-06 01:00:00 =========================
# ========================= 2019-09-06 02:00:00 =========================
# ========================= 2019-09-06 03:00:00 =========================
# ========================= 2019-09-06 04:00:00 =========================
# ========================= 2019-09-06 05:00:00 =========================
# ========================= 2019-09-06 06:00:00 =========================
# ========================= 2019-09-06 07:00:00 =========================
# ========================= 2019-09-06 08:00:00 =========================
# ========================= 2019-09-06 09:00:00 =========================
# ========================= 2019-09-06 10:00:00 =========================
# ========================= 2019-09-06 11:00:00 =========================
# ========================= 2019-09-06 12:00:00 =========================
# ========================= 2019-09-06 13:00:00 =========================
# ========================= 2019-09-06 14:00:00 =========================
# ========================= 2019-09-06 15:00:00 =========================
# ========================= 2019-09-06 16:00:00 =========================
# ========================= 2019-09-06 17:00:00 =========================
# ========================= 2019-09-06 18:00:00 =========================
# ========================= 2019-09-06 19:00:00 =========================
# ========================= 2019-09-06 20:00:00 =========================
# ========================= 2019-09-06 21:00:00 =========================
# ========================= 2019-09-06 22:00:00 =========================
# ========================= 2019-09-06 23:00:00 =========================
# ========================= 2019-09-07 00:00:00 =========================
# ========================= 2019-09-07 01:00:00 =========================
# ========================= 2019-09-07 02:00:00 =========================
# ========================= 2019-09-07 03:00:00 =========================
# ========================= 2019-09-07 04:00:00 =========================
# ========================= 2019-09-07 05:00:00 =========================
# ========================= 2019-09-07 06:00:00 =========================
# ========================= 2019-09-07 07:00:00 =========================
# ...
# ========================= 2019-12-02 22:00:00 =========================
# ========================= 2019-12-02 23:00:00 =========================
# ========================= 2019-12-03 00:00:00 =========================
# ========================= 2019-12-03 01:00:00 =========================
# ========================= 2019-12-03 02:00:00 =========================
# ========================= 2019-12-03 03:00:00 =========================
# ========================= 2019-12-03 04:00:00 =========================
# ========================= 2019-12-03 05:00:00 =========================
# ========================= 2019-12-03 06:00:00 =========================
# ========================= 2019-12-03 07:00:00 =========================
# ========================= 2019-12-03 08:00:00 =========================
# ========================= 2019-12-03 09:00:00 =========================
# ========================= 2019-12-03 10:00:00 =========================
# ========================= 2019-12-03 11:00:00 =========================
# ========================= 2019-12-03 12:00:00 =========================
# ========================= 2019-12-03 13:00:00 =========================
# ========================= 2019-12-03 14:00:00 =========================
# ========================= 2019-12-03 15:00:00 =========================
# ========================= 2019-12-03 16:00:00 =========================
# ========================= 2019-12-03 17:00:00 =========================
# ========================= 2019-12-03 18:00:00 =========================
# ========================= 2019-12-03 19:00:00 =========================
# ========================= 2019-12-03 20:00:00 =========================
# ========================= 2019-12-03 21:00:00 =========================
# ========================= 2019-12-03 22:00:00 =========================
# ========================= 2019-12-03 23:00:00 =========================
# ========================= 2019-12-04 00:00:00 =========================
# ========================= 2019-12-04 01:00:00 =========================
# ========================= 2019-12-04 02:00:00 =========================
# ========================= 2019-12-04 03:00:00 =========================
# ========================= 2019-12-04 04:00:00 =========================
# ========================= 2019-12-04 05:00:00 =========================
# ========================= 2019-12-04 06:00:00 =========================
# ========================= 2019-12-04 07:00:00 =========================
# ========================= 2019-12-04 08:00:00 =========================
# ========================= 2019-12-04 09:00:00 =========================
# ========================= 2019-12-04 10:00:00 =========================
# ========================= 2019-12-04 11:00:00 =========================
# ========================= 2019-12-04 12:00:00 =========================
# ========================= 2019-12-04 13:00:00 =========================
# ========================= 2019-12-04 14:00:00 =========================
# ========================= 2019-12-04 15:00:00 =========================
# ========================= 2019-12-04 16:00:00 =========================
# ========================= 2019-12-04 17:00:00 =========================
# ========================= 2019-12-04 18:00:00 =========================
# ========================= 2019-12-04 19:00:00 =========================
# ========================= 2019-12-04 20:00:00 =========================
# ========================= 2019-12-04 21:00:00 =========================
# ========================= 2019-12-04 22:00:00 =========================
# ========================= 2019-12-04 23:00:00 =========================
# ========================= 2019-12-05 00:00:00 =========================
# ========================= 2019-12-05 01:00:00 =========================
# ========================= 2019-12-05 02:00:00 =========================
# ========================= 2019-12-05 03:00:00 =========================
# ========================= 2019-12-05 04:00:00 =========================
# ========================= 2019-12-05 05:00:00 =========================
# ========================= 2019-12-05 06:00:00 =========================
# ========================= 2019-12-05 07:00:00 =========================
# ========================= 2019-12-05 08:00:00 =========================
# ========================= 2019-12-05 09:00:00 =========================
# ========================= 2019-12-05 10:00:00 =========================
# ========================= 2019-12-05 11:00:00 =========================
# ========================= 2019-12-05 12:00:00 =========================
# ========================= 2019-12-05 13:00:00 =========================
# ========================= 2019-12-05 14:00:00 =========================
# ========================= 2019-12-05 15:00:00 =========================
# ========================= 2019-12-05 16:00:00 =========================
# ========================= 2019-12-05 17:00:00 =========================
# ========================= 2019-12-05 18:00:00 =========================
# ========================= 2019-12-05 19:00:00 =========================
# ========================= 2019-12-05 20:00:00 =========================
# ========================= 2019-12-05 21:00:00 =========================
# ========================= 2019-12-05 22:00:00 =========================
# ========================= 2019-12-05 23:00:00 =========================
# ========================= 2019-12-06 00:00:00 =========================
# ========================= 2019-12-06 01:00:00 =========================
# ========================= 2019-12-06 02:00:00 =========================
# ========================= 2019-12-06 03:00:00 =========================
# ========================= 2019-12-06 04:00:00 =========================
# ========================= 2019-12-06 05:00:00 =========================
# ========================= 2019-12-06 06:00:00 =========================
# ========================= 2019-12-06 07:00:00 =========================
# ========================= 2019-12-06 08:00:00 =========================
# ========================= 2019-12-06 09:00:00 =========================
# ========================= 2019-12-06 10:00:00 =========================
# ========================= 2019-12-06 11:00:00 =========================
# ========================= 2019-12-06 12:00:00 =========================
# ========================= 2019-12-06 13:00:00 =========================
# ========================= 2019-12-06 14:00:00 =========================
# ========================= 2019-12-06 15:00:00 =========================
# ========================= 2019-12-06 16:00:00 =========================
# ========================= 2019-12-06 17:00:00 =========================
# ========================= 2019-12-06 18:00:00 =========================
# ========================= 2019-12-06 19:00:00 =========================
# ========================= 2019-12-06 20:00:00 =========================
# ========================= 2019-12-06 21:00:00 =========================
# ========================= 2019-12-06 22:00:00 =========================
# ========================= 2019-12-06 23:00:00 =========================
# ========================= 2019-12-07 00:00:00 =========================
# ========================= 2019-12-07 01:00:00 =========================
# ========================= 2019-12-07 02:00:00 =========================
# ========================= 2019-12-07 03:00:00 =========================
# ========================= 2019-12-07 04:00:00 =========================
# ========================= 2019-12-07 05:00:00 =========================
# ========================= 2019-12-07 06:00:00 =========================
# ========================= 2019-12-07 07:00:00 =========================
# ========================= 2019-12-07 08:00:00 =========================
# ========================= 2019-12-07 09:00:00 =========================
# ========================= 2019-12-07 10:00:00 =========================
# ========================= 2019-12-07 11:00:00 =========================
# ========================= 2019-12-07 12:00:00 =========================
# ========================= 2019-12-07 13:00:00 =========================
# ========================= 2019-12-07 14:00:00 =========================
# ========================= 2019-12-07 15:00:00 =========================
# ========================= 2019-12-07 16:00:00 =========================
# ========================= 2019-12-07 17:00:00 =========================
# ========================= 2019-12-07 18:00:00 =========================
# ========================= 2019-12-07 19:00:00 =========================
# ========================= 2019-12-07 20:00:00 =========================
# ========================= 2019-12-07 21:00:00 =========================
# ========================= 2019-12-07 22:00:00 =========================
# ========================= 2019-12-07 23:00:00 =========================
# ========================= FINISH =========================
# Done, trial 46
# !!!!!!!!!! EV SHORT DURATION !!!!!!!!!! || drop 119 sessions
# !!!!!!!!!! EV SHORT DURATION !!!!!!!!!! || drop 237 sessions
# ========================= 2019-12-01 00:00:00 =========================
# ========================= 2019-12-01 01:00:00 =========================
# ========================= 2019-12-01 02:00:00 =========================
# ========================= 2019-12-01 03:00:00 =========================
# ========================= 2019-12-01 04:00:00 =========================
# ========================= 2019-12-01 05:00:00 =========================
# ========================= 2019-12-01 06:00:00 =========================
# ========================= 2019-12-01 07:00:00 =========================
# ========================= 2019-12-01 08:00:00 =========================
# ========================= 2019-12-01 09:00:00 =========================
# ========================= 2019-12-01 10:00:00 =========================
# ========================= 2019-12-01 11:00:00 =========================
# ========================= 2019-12-01 12:00:00 =========================
# ========================= 2019-12-01 13:00:00 =========================
# ========================= 2019-12-01 14:00:00 =========================
# ========================= 2019-12-01 15:00:00 =========================
# ========================= 2019-12-01 16:00:00 =========================
# ========================= 2019-12-01 17:00:00 =========================
# ========================= 2019-12-01 18:00:00 =========================
# ========================= 2019-12-01 19:00:00 =========================
# ========================= 2019-12-01 20:00:00 =========================
# ========================= 2019-12-01 21:00:00 =========================
# ========================= 2019-12-01 22:00:00 =========================
# ========================= 2019-12-01 23:00:00 =========================
# ========================= 2019-12-02 00:00:00 =========================
# ========================= 2019-12-02 01:00:00 =========================
# ========================= 2019-12-02 02:00:00 =========================
# ========================= 2019-12-02 03:00:00 =========================
# ========================= 2019-12-02 04:00:00 =========================
# ========================= 2019-12-02 05:00:00 =========================
# ========================= 2019-12-02 06:00:00 =========================
# ========================= 2019-12-02 07:00:00 =========================
# ========================= 2019-12-02 08:00:00 =========================
# ========================= 2019-12-02 09:00:00 =========================
# ========================= 2019-12-02 10:00:00 =========================
# ========================= 2019-12-02 11:00:00 =========================
# ========================= 2019-12-02 12:00:00 =========================
# ========================= 2019-12-02 13:00:00 =========================
# ========================= 2019-12-02 14:00:00 =========================
# ========================= 2019-12-02 15:00:00 =========================
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 10
#       1 em = MPC_ExperimentManager(log_fn=log_fn, save_path=save_path, save=True, exp_prefix="MPC")
#       2 var_keys = [
#       3             "method", "strategy",
#       4             "pred_model", "deg_model_opt", "p_grid_max",
#    (...)
#       8             "start", "end",
#       9             "bld", "ev", "pv"]
# ---> 10 em.run(keys=var_keys, num_trials=120)
#
# File d:\Codes\GIthub_repo\Energy_grid\src\exp_manager.py:66, in ExperimentManager.run(self, keys, num_trials)
#      60 log.to_excel(self.log_fn, index=True)
#      62 # STEP 2: run experiment with corresponding params
#      63 #   [run_one_trial] method will be highly case-specific, need to override
#      64 #   save results also need to implement inside
# ---> 66 stats = self.run_one_trial(params, save_fn)
#      68 # STEP 3: record trial stats
#      69 log = pd.read_excel(self.log_fn, index_col=0)
#
# Cell In[4], line 76, in MPC_ExperimentManager.run_one_trial(self, params, save_fn)
#      70 # Step 6: initialize save_config
#      71 mpc.init_save_config(save_fn=save_fn[:-5],  # FIXME: remove ".xlsx"
#      72     folder_path=self.save_path, log_pred_action=True,
#      73     checkpoints="1D", recovery=True, recovery_from=None,
#      74     )
# ---> 76 mpc.run(tstart=t_start, tend=t_end, exe_K=4, save=True)
#      78 stats = dict(mpc.summary["All"])
#      80 return stats
#
# File d:\Codes\GIthub_repo\Energy_grid\src\grid_manager.py:138, in MPC_op.run(self, tstart, tend, exe_K, t_cut, save)
#     135     self.save()
#     137 #try:
# --> 138 self.run_k_steps(t, exe_K=exe_K, t_cut=t_cut)
#     139 '''
#     140 except Exception as e:
#     141 # ev_log has already been edited - set them back
#    (...)
#     148 raise KeyboardInterrupt()
#     149 '''
#     151 t += timedelta(hours=self.delta_0*exe_K)
#
# File d:\Codes\GIthub_repo\Energy_grid\src\grid_manager.py:309, in MPC_op.run_k_steps(self, t, exe_K, t_cut)
#     307 self.cache["opt"] = opt
#     308 # [Yi, 2023/03/19] add ".sol": get_control_sequence returns a [Battery_solution] object, here we only use the solution part
# --> 309 sol = opt.get_control_sequence(params, mute=True, **self.optimizer["params"]).sol
#     310 self.cache["opt_sol"] = copy.deepcopy(sol)
#     312 # FIXME: execution time of STEP-4 ignored
#
# File d:\Codes\GIthub_repo\Energy_grid\src\optimizer.py:450, in Battery_optimizer.get_control_sequence(self, params, strategy, mute, **kw)
#     444 self.settings["mute_solver"] = mute
#     446 if strategy == "optimal":
#     447     # update 2022/09/03: fix bug: no return
#     448     # update 2022/10/08: replace "optimize_size_optimal" with "optimize_control_sequence"
#     449     #   seems a typo
# --> 450     return self.optimize_control_sequence(params=params, **kw)
#     451 elif strategy == "MSC":
#     452     return self.rule_base_control_sequence(params=params, rule="MSC")
#
# File d:\Codes\GIthub_repo\Energy_grid\src\optimizer.py:486, in Battery_optimizer.optimize_control_sequence(self, params, language)
#     484 def optimize_control_sequence(self, params, language="gurobi"):
#     485     opt_solver = self.solvers[language]
# --> 486     sol = opt_solver(params)
#     487     # sol["TCO"] = self.estimate_daily_TCO(params, sol)
#     488     # [OLD] sol["reg"] = tuple([params["reg_lambda"], params["reg_term"]])
#     489     return Battery_solution(sol, params, self.battery_sample)
#
# File d:\Codes\GIthub_repo\Energy_grid\src\optimizer.py:1029, in Battery_optimizer.solve_model_gurobi(self, params)
#    1027 for k in range(K+1):
#    1028     if k < K:
# -> 1029         solution["p_grid"][s][k] = m.getVarByName("p_grid_{}[{}]".format(s,k)).x
#    1030         solution["bat_p"][s][k] = m.getVarByName("bat_p_{}[{}]".format(s,k)).x
#    1031     solution["bat_e"][s][k] = m.getVarByName("bat_e_{}[{}]".format(s,k)).x
#
# File src\gurobipy\var.pxi:125, in gurobipy.Var.__getattr__()
#
# File src\gurobipy\var.pxi:153, in gurobipy.Var.getAttr()
#
# File src\gurobipy\attrutil.pxi:100, in gurobipy.__getattr()
#
# AttributeError: Unable to retrieve attribute 'x'
