# %%
import os
import sys
src_path = sys.path[0].replace("paper_working", "src")
# data_path = sys.path[0].replace("notebooks", "data")
if src_path not in sys.path:
    sys.path.append(src_path)

out_path = sys.path[0].replace("paper_working", "output")

import warnings
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
import matplotlib as mpl
import pandas as pd
import sys
import calendar
import os
from matplotlib.lines import Line2D
import matplotlib.dates as mdates


from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from matplotlib.patches import ConnectionPatch

rc_={
    "figure.dpi":300,
    "font.size":10,
    "axes.facecolor":"white",
    "savefig.facecolor":"white",
    "text.usetex":False,
    "legend.frameon":False
}
plt.rcParams.update(rc_)
'''
legend_fs=10
label_fs=12
ticklabel_fs=9
'''
from plot_helper import *

from utils.plot_utils import *
customize_plt() # customize plt configs, see plot_utils

# %%
'''i=5
month=i
keys=['necessary','unnecessary']
postfix=''

merged_df_Jan=get_merged_df(
    file_folder=r'L:\Coding_project\Energy_grid_new_exp_local\thesis_track_p_grid\6h-bat-Oct-track-p-grid',
    log_fn=r'L:\Coding_project\Energy_grid_new\output\experiments\thesis_track_p_grid\6h-bat-Oct-track-p-grid.xlsx',
    id_exe_unne=1+4*(month-1), id_sol_nece=3+4*(month-1), id_mini=4+4*(month-1)
)
plot_track_p_max(df_merged=merged_df_Jan,figsize=(5.5,2.86),
                line_keys=keys,plot_error_bar=False,
                ylimit_main=[-100,200],ylimit_sub=[-80,160],
                linewidth=1.5,
                inside_start_day=0,inside_days=1,
                save_fn="fig-2-track_p_grid_max_"+str(i)+postfix+"100dpi.png")'''
# Out:
# 'i=5\nmonth=i\nkeys=[\'necessary\',\'unnecessary\']\npostfix=\'\'\n\nmerged_df_Jan=get_merged_df(\n    file_folder=r\'L:\\Coding_project\\Energy_grid_new_exp_local\thesis_track_p_grid\x06h-bat-Oct-track-p-grid\',\n    log_fn=r\'L:\\Coding_project\\Energy_grid_new\\output\\experiments\thesis_track_p_grid\x06h-bat-Oct-track-p-grid.xlsx\',\n    id_exe_unne=1+4*(month-1), id_sol_nece=3+4*(month-1), id_mini=4+4*(month-1)\n)\nplot_track_p_max(df_merged=merged_df_Jan,figsize=(5.5,2.86),\n                line_keys=keys,plot_error_bar=False,\n                ylimit_main=[-100,200],ylimit_sub=[-80,160],\n                linewidth=1.5,\n                inside_start_day=0,inside_days=1,\n                save_fn="fig-2-track_p_grid_max_"+str(i)+postfix+"100dpi.png")'

# %% [markdown]
# # Track p grid max (necessary and unnecessary)

# %%
i=5
month=i
keys=['necessary','unnecessary','unnecessary_minimized','latest_max_neg_net_load_error']
postfix=''
track_necessary=4+6*(month-1)
compensation=5+6*(month-1)
track_necessary_compensation=6+6*(month-1)
merged_df_Jan=get_merged_df(
    file_folder=r'L:\Coding_project\Energy_grid_new_exp_local\simple_debug\trend_check_new_method_enable_discharge',
    log_fn=r'L:\Coding_project\Energy_grid_new\output\experiments\simple_debug\pred_bld_pv_ev_new_method.xlsx',
    id_exe_unne=3+6*(month-1), id_sol_nece=1+6*(month-1), id_mini=track_necessary
)
plot_track_p_max(df_merged=merged_df_Jan,figsize=(5.5,4),
                line_keys=keys,plot_error_bar=True,
                ylimit_main=[-350,200],ylimit_sub=[-150,160],
                linewidth=1.5,legend_loc="lower left",
                inside_start_day=0,inside_days=1,
                save_fn="test_"+str(i)+postfix+"100dpi.png")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# l:\Coding_project\Energy_grid_new\paper_working\plot_helper.py:113: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=0,fontsize=ticklabel_fs)
# l:\Coding_project\Energy_grid_new\paper_working\plot_helper.py:134: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=0,fontsize=ticklabel_fs)
# (<Axes: xlabel='Day of month (May-2019)', ylabel='Peak demand till $t$ (kW)'>,
#  <AxesHostAxes: xlabel='Hour of day (1-May)'>)

# %%
i=5
month=i
keys=['necessary','unnecessary','unnecessary_minimized','latest_max_neg_net_load_error']
postfix=''
track_necessary=4+6*(month-1)
compensation=5+6*(month-1)
track_necessary_compensation=6+6*(month-1)
merged_df_Jan=get_merged_df(
    file_folder=r'L:\Coding_project\Energy_grid_new_exp_local\simple_debug\trend_check_new_method_enable_discharge',
    log_fn=r'L:\Coding_project\Energy_grid_new\output\experiments\simple_debug\pred_bld_pv_ev_new_method.xlsx',
    id_exe_unne=3+6*(month-1), id_sol_nece=1+6*(month-1), id_mini=track_necessary_compensation
)
plot_track_p_max(df_merged=merged_df_Jan,figsize=(5.5,4),
                line_keys=keys,plot_error_bar=True,
                ylimit_main=[-350,200],ylimit_sub=[-150,160],
                linewidth=1.5,legend_loc="lower left",
                inside_start_day=0,inside_days=1,
                save_fn="test_2"+str(i)+postfix+"100dpi.png")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# l:\Coding_project\Energy_grid_new\paper_working\plot_helper.py:113: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=0,fontsize=ticklabel_fs)
# l:\Coding_project\Energy_grid_new\paper_working\plot_helper.py:134: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=0,fontsize=ticklabel_fs)
# (<Axes: xlabel='Day of month (May-2019)', ylabel='Peak demand till $t$ (kW)'>,
#  <AxesHostAxes: xlabel='Hour of day (1-May)'>)

# %%
merged_df_Jan
# Out:
#                      actual_p_max   necessary   minimized  net_load_error
# 2019-07-01 00:00:00           NaN         NaN         NaN        0.936389  \
# 2019-07-01 00:15:00     95.822797   66.921140   95.822797        1.907442
# 2019-07-01 00:30:00     95.822797   66.921140   95.822797        0.849730
# 2019-07-01 00:45:00     95.909456   66.921140   95.909456        1.488122
# 2019-07-01 01:00:00     95.909456   66.921140   95.909456        0.764421
# ...                           ...         ...         ...             ...
# 2019-07-31 23:00:00    328.993254  107.084976  236.521808        1.415161
# 2019-07-31 23:15:00    328.993254  107.084976  236.521808        7.680815
# 2019-07-31 23:30:00    328.993254  107.084976  236.521808        8.520064
# 2019-07-31 23:45:00    328.993254  107.084976  236.521808        9.157965
# 2019-08-01 00:00:00    328.993254  107.084976  236.521808        9.157965
#
#                      unnecessary  unnecessary_minimized
# 2019-07-01 00:00:00          NaN                    NaN  \
# 2019-07-01 00:15:00   -28.901658             -28.901658
# 2019-07-01 00:30:00   -28.901658             -28.901658
# 2019-07-01 00:45:00   -28.988317             -28.988317
# 2019-07-01 01:00:00   -28.988317             -28.988317
# ...                          ...                    ...
# 2019-07-31 23:00:00  -221.908278            -129.436832
# 2019-07-31 23:15:00  -221.908278            -129.436832
# 2019-07-31 23:30:00  -221.908278            -129.436832
# 2019-07-31 23:45:00  -221.908278            -129.436832
# 2019-08-01 00:00:00  -221.908278            -129.436832
#
#                      latest_max_neg_net_load_error
# 2019-07-01 00:00:00                       0.000000
# 2019-07-01 00:15:00                       0.000000
# 2019-07-01 00:30:00                       0.000000
# 2019-07-01 00:45:00                       0.000000
# 2019-07-01 01:00:00                       0.000000
# ...                                            ...
# 2019-07-31 23:00:00                    -180.254735
# 2019-07-31 23:15:00                    -180.254735
# 2019-07-31 23:30:00                    -180.254735
# 2019-07-31 23:45:00                    -180.254735
# 2019-08-01 00:00:00                    -180.254735
#
# [2977 rows x 7 columns]

# %%
i=5
month=i
keys=['necessary','unnecessary','unnecessary_minimized','latest_max_neg_net_load_error']
postfix=''
track_necessary=4+6*(month-1)
compensation=5+6*(month-1)
track_necessary_compensation=6+6*(month-1)
merged_df_Jan=get_merged_df(
    file_folder=r'L:\Coding_project\Energy_grid_new_exp_local\simple_debug\pred_bld_pv_ev_new_ev_pred_3_validday_new_sol_exe',
    log_fn=r'L:\Coding_project\Energy_grid_new\output\experiments\simple_debug\pred_bld_pv_ev_new_ev_pred_3_validday_new_sol_exe.xlsx',
    id_exe_unne=3+6*(month-1), id_sol_nece=1+6*(month-1), id_mini=track_necessary
)
plot_track_p_max(df_merged=merged_df_Jan,figsize=(5.5,4),
                line_keys=keys,plot_error_bar=True,
                ylimit_main=[-350,200],ylimit_sub=[-150,160],
                linewidth=1.5,legend_loc="lower left",
                inside_start_day=0,inside_days=1,
                save_fn="test_"+str(i)+postfix+"100dpi.png")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# l:\Coding_project\Energy_grid_new\paper_working\plot_helper.py:113: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=0,fontsize=ticklabel_fs)
# l:\Coding_project\Energy_grid_new\paper_working\plot_helper.py:134: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=0,fontsize=ticklabel_fs)
# (<Axes: xlabel='Day of month (May-2019)', ylabel='Peak demand till $t$ (kW)'>,
#  <AxesHostAxes: xlabel='Hour of day (1-May)'>)

# %%
i=5
month=i
keys=['necessary','unnecessary','unnecessary_minimized','latest_max_neg_net_load_error']
postfix=''
track_necessary=4+6*(month-1)
compensation=5+6*(month-1)
track_necessary_compensation=6+6*(month-1)
merged_df_Jan=get_merged_df(
    file_folder=r'L:\Coding_project\Energy_grid_new_exp_local\simple_debug\pred_bld_pv_ev_alap_only',
    log_fn=r'L:\Coding_project\Energy_grid_new\output\experiments\simple_debug\pred_bld_pv_ev_alap_only.xlsx',
    id_exe_unne=3+6*(month-1), id_sol_nece=1+6*(month-1), id_mini=track_necessary
)
plot_track_p_max(df_merged=merged_df_Jan,figsize=(5.5,4),
                line_keys=keys,plot_error_bar=True,
                ylimit_main=[-350,200],ylimit_sub=[-150,160],
                linewidth=1.5,legend_loc="lower left",
                inside_start_day=0,inside_days=1,
                save_fn="test_"+str(i)+postfix+"100dpi.png")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# l:\Coding_project\Energy_grid_new\paper_working\plot_helper.py:113: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=0,fontsize=ticklabel_fs)
# l:\Coding_project\Energy_grid_new\paper_working\plot_helper.py:134: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=0,fontsize=ticklabel_fs)
# (<Axes: xlabel='Day of month (May-2019)', ylabel='Peak demand till $t$ (kW)'>,
#  <AxesHostAxes: xlabel='Hour of day (1-May)'>)

# %%
i=7
month=i
keys=['necessary','unnecessary','unnecessary_minimized','latest_max_neg_net_load_error']
postfix=''
track_necessary=4+6*(month-1)
compensation=5+6*(month-1)
track_necessary_compensation=6+6*(month-1)
merged_df_Jan=get_merged_df(
    file_folder=r'L:\Coding_project\Energy_grid_new_exp_local\simple_debug\pred_bld_pv_ev_alap_only',
    log_fn=r'L:\Coding_project\Energy_grid_new\output\experiments\simple_debug\pred_bld_pv_ev_alap_only.xlsx',
    id_exe_unne=3+6*(month-1), id_sol_nece=1+6*(month-1), id_mini=track_necessary
)
plot_track_p_max(df_merged=merged_df_Jan,figsize=(5.5,4),
                line_keys=keys,plot_error_bar=True,month='Jul',
                ylimit_main=[-350,200],ylimit_sub=[-150,160],
                linewidth=1.5,legend_loc="lower left",
                inside_start_day=0,inside_days=1,
                save_fn="test_"+str(i)+postfix+"100dpi.png")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# l:\Coding_project\Energy_grid_new\paper_working\plot_helper.py:113: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=0,fontsize=ticklabel_fs)
# l:\Coding_project\Energy_grid_new\paper_working\plot_helper.py:134: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=0,fontsize=ticklabel_fs)
# (<Axes: xlabel='Day of month (Jul-2019)', ylabel='Peak demand till $t$ (kW)'>,
#  <AxesHostAxes: xlabel='Hour of day (1-Jul)'>)

# %%
i=1
month=i
keys=['necessary','unnecessary','unnecessary_minimized','latest_max_neg_net_load_error']
postfix=''
track_necessary=4+6*(month-1)
compensation=5+6*(month-1)
track_necessary_compensation=6+6*(month-1)
merged_df_Jan=get_merged_df(
    file_folder=r'L:\Coding_project\Energy_grid_new_exp_local\simple_debug\pred_bld_pv_ev_alap_only',
    log_fn=r'L:\Coding_project\Energy_grid_new\output\experiments\simple_debug\pred_bld_pv_ev_alap_only.xlsx',
    id_exe_unne=3+6*(month-1), id_sol_nece=1+6*(month-1), id_mini=track_necessary
)
plot_track_p_max(df_merged=merged_df_Jan,figsize=(5.5,4),
                line_keys=keys,plot_error_bar=True,month='Jan',
                ylimit_main=[-350,200],ylimit_sub=[-150,160],
                linewidth=1.5,legend_loc="lower left",
                inside_start_day=0,inside_days=1,
                save_fn="test_"+str(i)+postfix+"100dpi.png")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# l:\Coding_project\Energy_grid_new\paper_working\plot_helper.py:113: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=0,fontsize=ticklabel_fs)
# l:\Coding_project\Energy_grid_new\paper_working\plot_helper.py:134: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=0,fontsize=ticklabel_fs)
# (<Axes: xlabel='Day of month (Jan-2019)', ylabel='Peak demand till $t$ (kW)'>,
#  <AxesHostAxes: xlabel='Hour of day (1-Jan)'>)

# %% [markdown]
# # For journal paper

# %%
i=1
month=i
keys=['actual_p_max','unnecessary','accumated_neg']
postfix=''
track_necessary=4+6*(month-1)
compensation=5+6*(month-1)
track_necessary_compensation=6+6*(month-1)
merged_df_Jan=get_merged_df(
    file_folder=r'L:\Coding_project\Energy_grid_new_exp_local\Multiple_model_compare',
    log_fn=r"L:\Coding_project\Energy_grid_new\output\experiments\Multiple_model_compare\DeepAR_optuna.xlsx",
    id_exe_unne=17, id_sol_nece=161, id_mini=161
)
last=0
for i in merged_df_Jan.index:
    if merged_df_Jan.loc[i,'net_load_error']<0:
        last+=merged_df_Jan.loc[i,'net_load_error']
    merged_df_Jan.loc[i,'accumated_neg']=last
merged_df_Jan['accumated_neg']=merged_df_Jan['accumated_neg']/30

plot_track_p_max(df_merged=merged_df_Jan,figsize=(10,6),
                line_keys=keys,plot_error_bar=True,month='Jan',
                ylimit_main=[-300,250],ylimit_sub=[-40,160],
                linewidth=1.5,legend_loc="lower left",
                ylabel='Power (kW)', xlabel_l='Day of month (May-2019)',xlabel_r='Hour of day (4-May to 6-May)',
                inside_start_day=3,inside_days=3,shadow=True,
                save_fn="test_"+str(i)+postfix+"100dpi.png")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# l:\Coding_project\Energy_grid_new\paper_working\plot_helper.py:117: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=0,fontsize=ticklabel_fs)
# l:\Coding_project\Energy_grid_new\paper_working\plot_helper.py:138: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=0,fontsize=ticklabel_fs)
# (<Axes: xlabel='Day of month (May-2019)', ylabel='Power (kW)'>,
#  <AxesHostAxes: xlabel='Hour of day (4-May to 6-May)'>)

# %%
merged_df_Jan
# Out:
#                      actual_p_max   necessary   minimized  net_load_error  \
# 2019-05-01 00:00:00           NaN         NaN         NaN        0.748655
# 2019-05-01 00:15:00     65.520400   65.520400   65.520400        0.985457
# 2019-05-01 00:30:00     65.520400   65.520400   65.520400       -1.460629
# 2019-05-01 00:45:00     67.729683   65.520400   65.520400       -0.234223
# 2019-05-01 01:00:00     67.729683   65.520400   65.520400       -1.443868
# ...                           ...         ...         ...             ...
# 2019-05-31 23:00:00    221.331593  105.593769  105.593769       -1.620965
# 2019-05-31 23:15:00    221.331593  105.593769  105.593769       -0.164229
# 2019-05-31 23:30:00    221.331593  105.593769  105.593769        1.565541
# 2019-05-31 23:45:00    221.331593  105.593769  105.593769        1.286277
# 2019-06-01 00:00:00    221.331593  105.593769  105.593769        1.286277
#
#                      unnecessary  unnecessary_minimized  \
# 2019-05-01 00:00:00          NaN                    NaN
# 2019-05-01 00:15:00     0.000000                    0.0
# 2019-05-01 00:30:00     0.000000                    0.0
# 2019-05-01 00:45:00    -2.209283                    0.0
# 2019-05-01 01:00:00    -2.209283                    0.0
# ...                          ...                    ...
# 2019-05-31 23:00:00  -115.737824                    0.0
# 2019-05-31 23:15:00  -115.737824                    0.0
# 2019-05-31 23:30:00  -115.737824                    0.0
# 2019-05-31 23:45:00  -115.737824                    0.0
# 2019-06-01 00:00:00  -115.737824                    0.0
#
#                      latest_max_neg_net_load_error  accumated_neg
# 2019-05-01 00:00:00                       0.000000       0.000000
# 2019-05-01 00:15:00                       0.000000       0.000000
# 2019-05-01 00:30:00                      -1.460629      -0.048688
# 2019-05-01 00:45:00                      -1.460629      -0.056495
# 2019-05-01 01:00:00                      -1.460629      -0.104624
# ...                                            ...            ...
# 2019-05-31 23:00:00                     -21.141136    -262.279442
# 2019-05-31 23:15:00                     -21.141136    -262.284916
# 2019-05-31 23:30:00                     -21.141136    -262.284916
# 2019-05-31 23:45:00                     -21.141136    -262.284916
# 2019-06-01 00:00:00                     -21.141136    -262.284916
#
# [2977 rows x 8 columns]
