# %%
import os
import sys
src_path = sys.path[0].replace("paper_working", "src")
# data_path = sys.path[0].replace("notebooks", "data")
if src_path not in sys.path:
    sys.path.append(src_path)

out_path = sys.path[0].replace("paper_working", "output")

import warnings
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
import matplotlib as mpl
import pandas as pd
import sys
import calendar
import os
from matplotlib.lines import Line2D
import matplotlib.dates as mdates


from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from matplotlib.patches import ConnectionPatch

rc_={
    "figure.dpi":300,
    "font.size":10,
    "axes.facecolor":"white",
    "savefig.facecolor":"white",
    "text.usetex":False,
    "legend.frameon":False
}
plt.rcParams.update(rc_)
'''
legend_fs=10
label_fs=12
ticklabel_fs=9
'''
from plot_helper import *

from utils.plot_utils import *
customize_plt() # customize plt configs, see plot_utils

# %%
'''i=5
month=i
keys=['necessary','unnecessary']
postfix=''

merged_df_Jan=get_merged_df(
    file_folder=r'L:\Coding_project\Energy_grid_new_exp_local\thesis_track_p_grid\6h-bat-Oct-track-p-grid',
    log_fn=r'L:\Coding_project\Energy_grid_new\output\experiments\thesis_track_p_grid\6h-bat-Oct-track-p-grid.xlsx',
    id_exe_unne=1+4*(month-1), id_sol_nece=3+4*(month-1), id_mini=4+4*(month-1)
)
plot_track_p_max(df_merged=merged_df_Jan,figsize=(5.5,2.86),
                line_keys=keys,plot_error_bar=False,
                ylimit_main=[-100,200],ylimit_sub=[-80,160],
                linewidth=1.5,
                inside_start_day=0,inside_days=1,
                save_fn="fig-2-track_p_grid_max_"+str(i)+postfix+"100dpi.png")'''
# Out:
# 'i=5\nmonth=i\nkeys=[\'necessary\',\'unnecessary\']\npostfix=\'\'\n\nmerged_df_Jan=get_merged_df(\n    file_folder=r\'L:\\Coding_project\\Energy_grid_new_exp_local\thesis_track_p_grid\x06h-bat-Oct-track-p-grid\',\n    log_fn=r\'L:\\Coding_project\\Energy_grid_new\\output\\experiments\thesis_track_p_grid\x06h-bat-Oct-track-p-grid.xlsx\',\n    id_exe_unne=1+4*(month-1), id_sol_nece=3+4*(month-1), id_mini=4+4*(month-1)\n)\nplot_track_p_max(df_merged=merged_df_Jan,figsize=(5.5,2.86),\n                line_keys=keys,plot_error_bar=False,\n                ylimit_main=[-100,200],ylimit_sub=[-80,160],\n                linewidth=1.5,\n                inside_start_day=0,inside_days=1,\n                save_fn="fig-2-track_p_grid_max_"+str(i)+postfix+"100dpi.png")'

# %% [markdown]
# # Track p grid max (necessary and unnecessary)

# %%
i=5
month=i
keys=['necessary','unnecessary','unnecessary_minimized','latest_max_neg_net_load_error']
postfix=''
track_necessary=4+6*(month-1)
compensation=5+6*(month-1)
track_necessary_compensation=6+6*(month-1)
merged_df_Jan=get_merged_df(
    file_folder=r'L:\Coding_project\Energy_grid_new_exp_local\simple_debug\trend_check_new_method_enable_discharge',
    log_fn=r'L:\Coding_project\Energy_grid_new\output\experiments\simple_debug\pred_bld_pv_ev_new_method.xlsx',
    id_exe_unne=3+6*(month-1), id_sol_nece=1+6*(month-1), id_mini=track_necessary
)
plot_track_p_max(df_merged=merged_df_Jan,figsize=(5.5,4),
                line_keys=keys,plot_error_bar=True,
                ylimit_main=[-350,200],ylimit_sub=[-150,160],
                linewidth=1.5,legend_loc="lower left",
                inside_start_day=0,inside_days=1,
                save_fn="test_"+str(i)+postfix+"100dpi.png")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# l:\Coding_project\Energy_grid_new\paper_working\plot_helper.py:272: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=0,fontsize=ticklabel_fs)
# l:\Coding_project\Energy_grid_new\paper_working\plot_helper.py:295: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=0,fontsize=ticklabel_fs)
# (<Axes: >, <AxesHostAxes: >)

# %%
i=5
month=i
keys=['necessary','unnecessary','unnecessary_minimized','latest_max_neg_net_load_error']
postfix=''
track_necessary=4+6*(month-1)
compensation=5+6*(month-1)
track_necessary_compensation=6+6*(month-1)
merged_df_Jan=get_merged_df(
    file_folder=r'L:\Coding_project\Energy_grid_new_exp_local\simple_debug\trend_check_new_method_enable_discharge',
    log_fn=r'L:\Coding_project\Energy_grid_new\output\experiments\simple_debug\pred_bld_pv_ev_new_method.xlsx',
    id_exe_unne=3+6*(month-1), id_sol_nece=1+6*(month-1), id_mini=track_necessary_compensation
)
plot_track_p_max(df_merged=merged_df_Jan,figsize=(5.5,4),
                line_keys=keys,plot_error_bar=True,
                ylimit_main=[-350,200],ylimit_sub=[-150,160],
                linewidth=1.5,legend_loc="lower left",
                inside_start_day=0,inside_days=1,
                save_fn="test_2"+str(i)+postfix+"100dpi.png")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# l:\Coding_project\Energy_grid_new\paper_working\plot_helper.py:272: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=0,fontsize=ticklabel_fs)
# l:\Coding_project\Energy_grid_new\paper_working\plot_helper.py:295: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=0,fontsize=ticklabel_fs)
# (<Axes: >, <AxesHostAxes: >)

# %%
merged_df_Jan
# Out:
#                      actual_p_max   necessary   minimized  net_load_error  \
# 2019-05-01 00:00:00           NaN         NaN         NaN        1.861002
# 2019-05-01 00:15:00    127.409777  106.824548  127.409777        5.662057
# 2019-05-01 00:30:00    127.409777  106.824548  127.409777        4.298574
# 2019-05-01 00:45:00    127.409777  106.824548  127.409777        6.253103
# 2019-05-01 01:00:00    127.409777  106.824548  127.409777        0.117564
# ...                           ...         ...         ...             ...
# 2019-05-31 23:00:00    365.416228  145.461595  165.804895        5.821408
# 2019-05-31 23:15:00    365.416228  145.461595  165.804895       14.121080
# 2019-05-31 23:30:00    365.416228  145.461595  165.804895       15.920149
# 2019-05-31 23:45:00    365.416228  145.461595  165.804895       15.716815
# 2019-06-01 00:00:00    365.416228  145.461595  165.804895       15.716815
#
#                      unnecessary  unnecessary_minimized  \
# ...

# %%
i=5
month=i
keys=['necessary','unnecessary','unnecessary_minimized','latest_max_neg_net_load_error']
postfix=''
track_necessary=4+6*(month-1)
compensation=5+6*(month-1)
track_necessary_compensation=6+6*(month-1)
merged_df_Jan=get_merged_df(
    file_folder=r'L:\Coding_project\Energy_grid_new_exp_local\simple_debug\pred_bld_pv_ev_new_ev_pred_3_validday_new_sol_exe',
    log_fn=r'L:\Coding_project\Energy_grid_new\output\experiments\simple_debug\pred_bld_pv_ev_new_ev_pred_3_validday_new_sol_exe.xlsx',
    id_exe_unne=3+6*(month-1), id_sol_nece=1+6*(month-1), id_mini=track_necessary
)
plot_track_p_max(df_merged=merged_df_Jan,figsize=(5.5,4),
                line_keys=keys,plot_error_bar=True,
                ylimit_main=[-350,200],ylimit_sub=[-150,160],
                linewidth=1.5,legend_loc="lower left",
                inside_start_day=0,inside_days=1,
                save_fn="test_"+str(i)+postfix+"100dpi.png")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# l:\Coding_project\Energy_grid_new\paper_working\plot_helper.py:272: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=0,fontsize=ticklabel_fs)
# l:\Coding_project\Energy_grid_new\paper_working\plot_helper.py:295: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=0,fontsize=ticklabel_fs)
# (<Axes: >, <AxesHostAxes: >)

# %%
i=5
month=i
keys=['necessary','unnecessary','unnecessary_minimized','latest_max_neg_net_load_error']
postfix=''
track_necessary=4+6*(month-1)
compensation=5+6*(month-1)
track_necessary_compensation=6+6*(month-1)
merged_df_Jan=get_merged_df(
    file_folder=r'L:\Coding_project\Energy_grid_new_exp_local\simple_debug\pred_bld_pv_ev_alap_only',
    log_fn=r'L:\Coding_project\Energy_grid_new\output\experiments\simple_debug\pred_bld_pv_ev_alap_only.xlsx',
    id_exe_unne=3+6*(month-1), id_sol_nece=1+6*(month-1), id_mini=track_necessary
)
plot_track_p_max(df_merged=merged_df_Jan,figsize=(5.5,4),
                line_keys=keys,plot_error_bar=True,
                ylimit_main=[-350,200],ylimit_sub=[-150,160],
                linewidth=1.5,legend_loc="lower left",
                inside_start_day=0,inside_days=1,
                save_fn="test_"+str(i)+postfix+"100dpi.png")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# l:\Coding_project\Energy_grid_new\paper_working\plot_helper.py:272: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=0,fontsize=ticklabel_fs)
# l:\Coding_project\Energy_grid_new\paper_working\plot_helper.py:295: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=0,fontsize=ticklabel_fs)
# (<Axes: >, <AxesHostAxes: >)

# %%
i=7
month=i
keys=['necessary','unnecessary','unnecessary_minimized','latest_max_neg_net_load_error']
postfix=''
track_necessary=4+6*(month-1)
compensation=5+6*(month-1)
track_necessary_compensation=6+6*(month-1)
merged_df_Jan=get_merged_df(
    file_folder=r'L:\Coding_project\Energy_grid_new_exp_local\simple_debug\pred_bld_pv_ev_alap_only',
    log_fn=r'L:\Coding_project\Energy_grid_new\output\experiments\simple_debug\pred_bld_pv_ev_alap_only.xlsx',
    id_exe_unne=3+6*(month-1), id_sol_nece=1+6*(month-1), id_mini=track_necessary
)
plot_track_p_max(df_merged=merged_df_Jan,figsize=(5.5,4),
                line_keys=keys,plot_error_bar=True,month='Jul',
                ylimit_main=[-350,200],ylimit_sub=[-150,160],
                linewidth=1.5,legend_loc="lower left",
                inside_start_day=0,inside_days=1,
                save_fn="test_"+str(i)+postfix+"100dpi.png")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# l:\Coding_project\Energy_grid_new\paper_working\plot_helper.py:272: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=0,fontsize=ticklabel_fs)
# l:\Coding_project\Energy_grid_new\paper_working\plot_helper.py:295: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=0,fontsize=ticklabel_fs)
# (<Axes: >, <AxesHostAxes: >)

# %%
i=1
month=i
keys=['necessary','unnecessary','unnecessary_minimized','latest_max_neg_net_load_error']
postfix=''
track_necessary=4+6*(month-1)
compensation=5+6*(month-1)
track_necessary_compensation=6+6*(month-1)
merged_df_Jan=get_merged_df(
    file_folder=r'L:\Coding_project\Energy_grid_new_exp_local\simple_debug\pred_bld_pv_ev_alap_only',
    log_fn=r'L:\Coding_project\Energy_grid_new\output\experiments\simple_debug\pred_bld_pv_ev_alap_only.xlsx',
    id_exe_unne=3+6*(month-1), id_sol_nece=1+6*(month-1), id_mini=track_necessary
)
plot_track_p_max(df_merged=merged_df_Jan,figsize=(5.5,4),
                line_keys=keys,plot_error_bar=True,month='Jan',
                ylimit_main=[-350,200],ylimit_sub=[-150,160],
                linewidth=1.5,legend_loc="lower left",
                inside_start_day=0,inside_days=1,
                save_fn="test_"+str(i)+postfix+"100dpi.png")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# l:\Coding_project\Energy_grid_new\paper_working\plot_helper.py:272: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=0,fontsize=ticklabel_fs)
# l:\Coding_project\Energy_grid_new\paper_working\plot_helper.py:295: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=0,fontsize=ticklabel_fs)
# (<Axes: >, <AxesHostAxes: >)

# %% [markdown]
# # For journal paper

# %% [markdown]
# # DeepAR

# %%
i=1
month=i
keys=['actual_p_max','unnecessary'] #,'accumated_neg','hourly_net_load_error'
postfix=''
track_necessary=4+6*(month-1)
compensation=5+6*(month-1)
track_necessary_compensation=6+6*(month-1)
merged_df_Jan=get_merged_df(
    file_folder=r'L:\Coding_project\Energy_grid_new_exp_local\Multiple_model_compare',
    log_fn=r"L:\Coding_project\Energy_grid_new\output\experiments\Multiple_model_compare\DeepAR_optuna.xlsx",
    id_exe_unne=17, id_sol_nece=161, id_mini=161
)
last=0
for i in merged_df_Jan.index:
    if merged_df_Jan.loc[i,'net_load_error']<0:
        last+=merged_df_Jan.loc[i,'net_load_error']
    merged_df_Jan.loc[i,'accumated_neg']=last
merged_df_Jan['accumated_neg']=-merged_df_Jan['accumated_neg']/30

# cal the hourly peak neg error
i=0
peak_neg_error=0
merged_df_Jan=merged_df_Jan.reset_index()
acc_step=4
while i < len(merged_df_Jan.index)-1:
    #k=0
    neg_sum=0
    for j in range(0,acc_step):
        try:
            neg_sum+=min(0,merged_df_Jan.loc[i+j,'net_load_error'])
        except:
            ...
    peak_neg_error=min(neg_sum,peak_neg_error)
    for j in range(0,acc_step):
        try:
            merged_df_Jan.loc[i+j,'hourly_net_load_error']=peak_neg_error
        except:
            ...
    i=i+acc_step
last=0
i=0
while i < len(merged_df_Jan.index)-1:
    if merged_df_Jan.loc[i,'unnecessary']<last or merged_df_Jan.loc[i,'unnecessary']==None:
        merged_df_Jan.loc[i,'increasing']=1
    else:
        merged_df_Jan.loc[i,'increasing']=0
    last=merged_df_Jan.loc[i,'unnecessary']
    i+=1
merged_df_Jan.index=(pd.to_datetime(merged_df_Jan['index']))
merged_df_Jan['net_load_error']=merged_df_Jan['net_load_error']

line_clr_dic={
    'actual_p_max':'teal',
    'necessary':'green',
    'unnecessary':'coral',
    'unnecessary_minimized':'purple',
    "latest_max_neg_net_load_error":'red',
    'accumated_neg':'indianred',  
    'hourly_net_load_error':'crimson'   
    }
label_dic={
    'actual_p_max':'Peak demand till t',
    'necessary':'green',
    'unnecessary':'discr. w/GT',
    'unnecessary_minimized':'purple',
    "latest_max_neg_net_load_error":'Peak error- till t',
    'accumated_neg':'Normalized acc. error(-) ',
    'hourly_net_load_error':'Peak hourly error- till t',
    'gray':'Forecast error (5-times scaled)',
    'red':'Forecast error at suboptimal (5-times scaled)'
    }

plot_track_p_max(df_merged=merged_df_Jan,figsize=(12/1.4,4),
                line_keys=keys,plot_error_bar=True,month='Jan',
                ylimit_main=[-200,300],ylimit_sub=[-100,200],
                linewidth=1.5, legend_loc="lower left", all_positive=True,
                ylabel='Power (kW)', xlabel_l='Day of month (May-2019)',xlabel_r='Hour of day (4-May to 6-May)',
                inside_start_day=3,inside_days=3,shadow=True,bbox_to_anchor=(1.04, -0.025, 1, 1),
                line_clr_dic=line_clr_dic,label_dic=label_dic,
                save_fn="test_"+str(i)+postfix+"100dpi.png")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# label added
# label added
# l:\Coding_project\Energy_grid_new\paper_working\plot_helper.py:331: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=0,fontsize=ticklabel_fs)
# label added
# label added
# l:\Coding_project\Energy_grid_new\paper_working\plot_helper.py:414: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=0,fontsize=ticklabel_fs)
# (<Axes: xlabel='Day of month (May-2019)', ylabel='Power (kW)'>,
#  <AxesHostAxes: xlabel='Hour of day (4-May to 6-May)'>)

# %%
i=1
month=i
keys=['actual_p_max','unnecessary'] #,'accumated_neg','hourly_net_load_error'
postfix=''
track_necessary=4+6*(month-1)
compensation=5+6*(month-1)
track_necessary_compensation=6+6*(month-1)
merged_df_Jan=get_merged_df(
    file_folder=r'L:\Coding_project\Energy_grid_new_exp_local\Multiple_model_compare',
    log_fn=r"L:\Coding_project\Energy_grid_new\output\experiments\Multiple_model_compare\DeepAR_optuna.xlsx",
    id_exe_unne=17+5, id_sol_nece=161+5, id_mini=161+5
)
last=0
for i in merged_df_Jan.index:
    if merged_df_Jan.loc[i,'net_load_error']<0:
        last+=merged_df_Jan.loc[i,'net_load_error']
    merged_df_Jan.loc[i,'accumated_neg']=last
merged_df_Jan['accumated_neg']=-merged_df_Jan['accumated_neg']/30

# cal the hourly peak neg error
i=0
peak_neg_error=0
merged_df_Jan=merged_df_Jan.reset_index()
acc_step=4
while i < len(merged_df_Jan.index)-1:
    #k=0
    neg_sum=0
    for j in range(0,acc_step):
        try:
            neg_sum+=min(0,merged_df_Jan.loc[i+j,'net_load_error'])
        except:
            ...
    peak_neg_error=min(neg_sum,peak_neg_error)
    for j in range(0,acc_step):
        try:
            merged_df_Jan.loc[i+j,'hourly_net_load_error']=peak_neg_error
        except:
            ...
    i=i+acc_step
last=0
i=0
while i < len(merged_df_Jan.index)-1:
    if merged_df_Jan.loc[i,'unnecessary']<last or merged_df_Jan.loc[i,'unnecessary']==None:
        merged_df_Jan.loc[i,'increasing']=1
    else:
        merged_df_Jan.loc[i,'increasing']=0
    last=merged_df_Jan.loc[i,'unnecessary']
    i+=1
merged_df_Jan.index=(pd.to_datetime(merged_df_Jan['index']))
merged_df_Jan['net_load_error']=merged_df_Jan['net_load_error']

line_clr_dic={
    'actual_p_max':'teal',
    'necessary':'green',
    'unnecessary':'coral',
    'unnecessary_minimized':'purple',
    "latest_max_neg_net_load_error":'red',
    'accumated_neg':'indianred',  
    'hourly_net_load_error':'crimson'   
    }
label_dic={
    'actual_p_max':'Peak demand till t',
    'necessary':'green',
    'unnecessary':'discr. w/GT',
    'unnecessary_minimized':'purple',
    "latest_max_neg_net_load_error":'Peak error- till t',
    'accumated_neg':'Normalized acc. error(-) ',
    'hourly_net_load_error':'Peak hourly error- till t',
    'gray':'Forecast error (right axis)',
    'red':'Forecast error at suboptimal (right axis)'
    }

plot_track_p_max(df_merged=merged_df_Jan,figsize=(12/1.6,4),
                line_keys=keys,plot_error_bar=True,month='Jan',
                ylimit_main=[-200,300],ylimit_sub=[-100,200],
                linewidth=1.5, legend_loc="lower left", all_positive=False,
                ylabel='Power (kW)', xlabel_l='Day of month (Oct-2019)',xlabel_r='Hour of day (4-Oct to 6-Oct)',
                inside_start_day=3,inside_days=3,shadow=True,
                line_clr_dic=line_clr_dic,label_dic=label_dic,
                save_fn="test_"+str(i)+postfix+"100dpi.png")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# label added
# label added
# l:\Coding_project\Energy_grid_new\paper_working\plot_helper.py:285: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.bar(b, df_merged.loc[b,"net_load_error"],width=error_bar_width,color=color,alpha=0.6,label=label_dic[color])
# l:\Coding_project\Energy_grid_new\paper_working\plot_helper.py:297: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_yticklabels([])
# label added
# label added
# l:\Coding_project\Energy_grid_new\paper_working\plot_helper.py:380: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xlabel(xlabel_l,fontsize=label_fs,loc='center')
# (<Axes: xlabel='Day of month (Oct-2019)', ylabel='Power (kW)'>,
#  <AxesHostAxes: xlabel='Hour of day (4-Oct to 6-Oct)'>)

# %% [markdown]
# # LR

# %%
i=1
month=i
keys=['actual_p_max','unnecessary'] #,'accumated_neg','hourly_net_load_error'
postfix=''
track_necessary=4+6*(month-1)
compensation=5+6*(month-1)
track_necessary_compensation=6+6*(month-1)
merged_df_Jan=get_merged_df(
    file_folder=r'L:\Coding_project\Energy_grid_new_exp_local\Multiple_model_compare',
    log_fn=r"L:\Coding_project\Energy_grid_new\output\experiments\Multiple_model_compare\LR_NAIVE.xlsx",
    id_exe_unne=17+5, id_sol_nece=161+5, id_mini=161+5
)
last=0
for i in merged_df_Jan.index:
    if merged_df_Jan.loc[i,'net_load_error']<0:
        last+=merged_df_Jan.loc[i,'net_load_error']
    merged_df_Jan.loc[i,'accumated_neg']=last
merged_df_Jan['accumated_neg']=-merged_df_Jan['accumated_neg']/30

# cal the hourly peak neg error
i=0
peak_neg_error=0
merged_df_Jan=merged_df_Jan.reset_index()
acc_step=4
while i < len(merged_df_Jan.index)-1:
    #k=0
    neg_sum=0
    for j in range(0,acc_step):
        try:
            neg_sum+=min(0,merged_df_Jan.loc[i+j,'net_load_error'])
        except:
            ...
    peak_neg_error=min(neg_sum,peak_neg_error)
    for j in range(0,acc_step):
        try:
            merged_df_Jan.loc[i+j,'hourly_net_load_error']=peak_neg_error
        except:
            ...
    i=i+acc_step
last=0
i=0
while i < len(merged_df_Jan.index)-1:
    if merged_df_Jan.loc[i,'unnecessary']<last or merged_df_Jan.loc[i,'unnecessary']==None:
        merged_df_Jan.loc[i,'increasing']=1
    else:
        merged_df_Jan.loc[i,'increasing']=0
    last=merged_df_Jan.loc[i,'unnecessary']
    i+=1
merged_df_Jan.index=(pd.to_datetime(merged_df_Jan['index']))
merged_df_Jan['net_load_error']=merged_df_Jan['net_load_error']

line_clr_dic={
    'actual_p_max':'teal',
    'necessary':'green',
    'unnecessary':'coral',
    'unnecessary_minimized':'purple',
    "latest_max_neg_net_load_error":'red',
    'accumated_neg':'indianred',  
    'hourly_net_load_error':'crimson'   
    }
label_dic={
    'actual_p_max':'Peak demand till t',
    'necessary':'green',
    'unnecessary':'discr. w/GT',
    'unnecessary_minimized':'purple',
    "latest_max_neg_net_load_error":'Peak error- till t',
    'accumated_neg':'Normalized acc. error(-) ',
    'hourly_net_load_error':'Peak hourly error- till t',
    'gray':'Forecast error (right axis)',
    'red':'Forecast error at suboptimal (right axis)'
    }

plot_track_p_max(df_merged=merged_df_Jan,figsize=(12/1.6,4),
                line_keys=keys,plot_error_bar=True,month='Jan',
                ylimit_main=[-200,300],ylimit_sub=[-100,200],
                linewidth=1.5, legend_loc="lower left", all_positive=False,
                ylabel='Power (kW)', xlabel_l='Day of month (Oct-2019)',xlabel_r='Hour of day (4-Oct to 6-Oct)',
                inside_start_day=3,inside_days=3,shadow=True,
                line_clr_dic=line_clr_dic,label_dic=label_dic,
                save_fn="test_"+str(i)+postfix+"100dpi.png")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# label added
# label added
# l:\Coding_project\Energy_grid_new\paper_working\plot_helper.py:285: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.bar(b, df_merged.loc[b,"net_load_error"],width=error_bar_width,color=color,alpha=0.6,label=label_dic[color])
# l:\Coding_project\Energy_grid_new\paper_working\plot_helper.py:297: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_yticklabels([])
# label added
# label added
# l:\Coding_project\Energy_grid_new\paper_working\plot_helper.py:380: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xlabel(xlabel_l,fontsize=label_fs,loc='center')
# (<Axes: xlabel='Day of month (Oct-2019)', ylabel='Power (kW)'>,
#  <AxesHostAxes: xlabel='Hour of day (4-Oct to 6-Oct)'>)

# %% [markdown]
# # Heuristic

# %%
i=1
month=i
keys=['actual_p_max','unnecessary'] #,'accumated_neg','hourly_net_load_error'
postfix=''
track_necessary=4+6*(month-1)
compensation=5+6*(month-1)
track_necessary_compensation=6+6*(month-1)
merged_df_Jan=get_merged_df(
    file_folder=r'L:\Coding_project\Energy_grid_new_exp_local\Multiple_model_compare',
    log_fn=r"L:\Coding_project\Energy_grid_new\output\experiments\Multiple_model_compare\Heuristic.xlsx",
    id_exe_unne=17+5, id_sol_nece=161+5, id_mini=161+5
)
last=0
for i in merged_df_Jan.index:
    if merged_df_Jan.loc[i,'net_load_error']<0:
        last+=merged_df_Jan.loc[i,'net_load_error']
    merged_df_Jan.loc[i,'accumated_neg']=last
merged_df_Jan['accumated_neg']=-merged_df_Jan['accumated_neg']/30

# cal the hourly peak neg error
i=0
peak_neg_error=0
merged_df_Jan=merged_df_Jan.reset_index()
acc_step=4
while i < len(merged_df_Jan.index)-1:
    #k=0
    neg_sum=0
    for j in range(0,acc_step):
        try:
            neg_sum+=min(0,merged_df_Jan.loc[i+j,'net_load_error'])
        except:
            ...
    peak_neg_error=min(neg_sum,peak_neg_error)
    for j in range(0,acc_step):
        try:
            merged_df_Jan.loc[i+j,'hourly_net_load_error']=peak_neg_error
        except:
            ...
    i=i+acc_step
last=0
i=0
while i < len(merged_df_Jan.index)-1:
    if merged_df_Jan.loc[i,'unnecessary']<last or merged_df_Jan.loc[i,'unnecessary']==None:
        merged_df_Jan.loc[i,'increasing']=1
    else:
        merged_df_Jan.loc[i,'increasing']=0
    last=merged_df_Jan.loc[i,'unnecessary']
    i+=1
merged_df_Jan.index=(pd.to_datetime(merged_df_Jan['index']))
merged_df_Jan['net_load_error']=merged_df_Jan['net_load_error']

line_clr_dic={
    'actual_p_max':'teal',
    'necessary':'green',
    'unnecessary':'coral',
    'unnecessary_minimized':'purple',
    "latest_max_neg_net_load_error":'red',
    'accumated_neg':'indianred',  
    'hourly_net_load_error':'crimson'   
    }
label_dic={
    'actual_p_max':'Peak demand till t',
    'necessary':'green',
    'unnecessary':'discr. w/GT',
    'unnecessary_minimized':'purple',
    "latest_max_neg_net_load_error":'Peak error- till t',
    'accumated_neg':'Normalized acc. error(-) ',
    'hourly_net_load_error':'Peak hourly error- till t',
    'gray':'Forecast error (right axis)',
    'red':'Forecast error at suboptimal (right axis)'
    }

plot_track_p_max(df_merged=merged_df_Jan,figsize=(12/1.6,4),
                line_keys=keys,plot_error_bar=True,month='Jan',
                ylimit_main=[-200,300],ylimit_sub=[-100,200],
                linewidth=1.5, legend_loc="lower left", all_positive=False,
                ylabel='Power (kW)', xlabel_l='Day of month (Oct-2019)',xlabel_r='Hour of day (4-Oct to 6-Oct)',
                inside_start_day=3,inside_days=3,shadow=True,
                line_clr_dic=line_clr_dic,label_dic=label_dic,
                save_fn="test_"+str(i)+postfix+"100dpi.png")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# label added
# label added
# l:\Coding_project\Energy_grid_new\paper_working\plot_helper.py:331: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=0,fontsize=ticklabel_fs)
# label added
# label added
# l:\Coding_project\Energy_grid_new\paper_working\plot_helper.py:414: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=0,fontsize=ticklabel_fs)
# (<Axes: xlabel='Day of month (Oct-2019)', ylabel='Power (kW)'>,
#  <AxesHostAxes: xlabel='Hour of day (4-Oct to 6-Oct)'>)

# %%
i=1
month=i
keys=['actual_p_max','unnecessary'] #,'accumated_neg','hourly_net_load_error'
postfix=''
track_necessary=4+6*(month-1)
compensation=5+6*(month-1)
track_necessary_compensation=6+6*(month-1)
merged_df_Jan=get_merged_df(
    file_folder=r'L:\Coding_project\Energy_grid_new_exp_local\Multiple_model_compare',
    log_fn=r"L:\Coding_project\Energy_grid_new\output\experiments\Multiple_model_compare\Heuristic.xlsx",
    id_exe_unne=17, id_sol_nece=161, id_mini=161
)
last=0
for i in merged_df_Jan.index:
    if merged_df_Jan.loc[i,'net_load_error']<0:
        last+=merged_df_Jan.loc[i,'net_load_error']
    merged_df_Jan.loc[i,'accumated_neg']=last
merged_df_Jan['accumated_neg']=-merged_df_Jan['accumated_neg']/30

# cal the hourly peak neg error
i=0
peak_neg_error=0
merged_df_Jan=merged_df_Jan.reset_index()
acc_step=4
while i < len(merged_df_Jan.index)-1:
    #k=0
    neg_sum=0
    for j in range(0,acc_step):
        try:
            neg_sum+=min(0,merged_df_Jan.loc[i+j,'net_load_error'])
        except:
            ...
    peak_neg_error=min(neg_sum,peak_neg_error)
    for j in range(0,acc_step):
        try:
            merged_df_Jan.loc[i+j,'hourly_net_load_error']=peak_neg_error
        except:
            ...
    i=i+acc_step
last=0
i=0
while i < len(merged_df_Jan.index)-1:
    if merged_df_Jan.loc[i,'unnecessary']<last or merged_df_Jan.loc[i,'unnecessary']==None:
        merged_df_Jan.loc[i,'increasing']=1
    else:
        merged_df_Jan.loc[i,'increasing']=0
    last=merged_df_Jan.loc[i,'unnecessary']
    i+=1
merged_df_Jan.index=(pd.to_datetime(merged_df_Jan['index']))
merged_df_Jan['net_load_error']=merged_df_Jan['net_load_error']

line_clr_dic={
    'actual_p_max':'teal',
    'necessary':'green',
    'unnecessary':'coral',
    'unnecessary_minimized':'purple',
    "latest_max_neg_net_load_error":'red',
    'accumated_neg':'indianred',  
    'hourly_net_load_error':'crimson'   
    }
label_dic={
    'actual_p_max':'Peak demand till t',
    'necessary':'green',
    'unnecessary':'discr. w/GT',
    'unnecessary_minimized':'purple',
    "latest_max_neg_net_load_error":'Peak error- till t',
    'accumated_neg':'Normalized acc. error(-) ',
    'hourly_net_load_error':'Peak hourly error- till t',
    'gray':'Forecast error (5-times scaled)',
    'red':'Forecast error at suboptimal (5-times scaled)'
    }

plot_track_p_max(df_merged=merged_df_Jan,figsize=(12/1.4,4),
                line_keys=keys,plot_error_bar=True,month='Jan',
                ylimit_main=[-200,300],ylimit_sub=[-100,200],
                linewidth=1.5, legend_loc="lower left", all_positive=True,
                ylabel='Power (kW)', xlabel_l='Day of month (May-2019)',xlabel_r='Hour of day (4-May to 6-May)',
                inside_start_day=3,inside_days=3,shadow=True,bbox_to_anchor=(1.04, -0.025, 1, 1),
                line_clr_dic=line_clr_dic,label_dic=label_dic,
                save_fn="test_"+str(i)+postfix+"100dpi.png")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# label added
# label added
# l:\Coding_project\Energy_grid_new\paper_working\plot_helper.py:331: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=0,fontsize=ticklabel_fs)
# label added
# label added
# l:\Coding_project\Energy_grid_new\paper_working\plot_helper.py:414: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=0,fontsize=ticklabel_fs)
# (<Axes: xlabel='Day of month (May-2019)', ylabel='Power (kW)'>,
#  <AxesHostAxes: xlabel='Hour of day (4-May to 6-May)'>)
